# %% [markdown]
# # The Logistic Regression

# %% [markdown]
# Before moving on to decision trees, aggregation methods and other modelling methods, we start by looking for a logistic model.
#
# This model will allow us to:
# * obtain an initial score grid
# * provide a reference point, in terms of discriminant variables and area under the ROC curve, for the other score models.

# %% [markdown]
# Logistic regression :
# * It is used when the variable to be predicted, Y, is qualitative with 2 modalities: 1 and 0.
# * It is also referred to as the target variable and the binomial variable.
# * Instead of predicting the variable Y, we predict the ‘probability of occurrence’ of the variable Y :
# $$
# P(Y=1)
# $$
# * P(Y=1) can therefore be modelled by a monotonic function operating from [0,1].
# * Usual function: logistic function

# %% [markdown]
# $$
# \pi (X)=Pr(Y=1|X) =\frac {e^{\beta_0 + \beta_1 X}} {1 + e^{\beta_0 + \beta_1 X}}
# $$

# %% [markdown]
# In logistic regression, we consider a binary variable to be explained, Y = 0 or 1, and a vector
# $$
# X = (X_1, X_2, ... X_p)
# $$
# of p eplicative variables
# $
# X_j
# $
# continuous, binary or qualitative.
#
# * As in any regression problem, we want to write the conditional expectation of the variable to be explained Y as a linear combination of X.
# * We want to know the mean value of Y for any value of X.
# * For a Y value of 0 or 1 (Bernoulli distribution), this mean value is the probability that Y = 1.
#
#
# We have :
#
# $$
# E(Y|X=x) = P(Y=1|X=x)
# $$

# %% [markdown]
# In linear regression, we try to pass a hyperplane through the middle of the point cloud
# $$
# (x_1, x_2, ... X_p, y)
# $$
# so that the set of mean values of Y for all values of X is approximated by this hyperplane, of equation :
#
# $$
# E(Y/X) = \beta_0 + \beta_1 X_1 + ... + \beta_p X_p
# $$
#
# This approximation is obviously no longer appropriate when Y = 0 or 1, since the term
# $$
# \beta_0 + \beta_1 X_1 + ... + \beta_p X_p
# $$
# is unbounded, whereas
# $$
# P(Y=1/X=x) \: \epsilon \: [0,1]
# $$
# for all x

# %% [markdown]
# The solution consists in using the generalized linear model and writing the expectation in the form :
# $$
# g(E(Y|X)=\beta_0 + \underset{i}{\sum}\:\beta_i\: X_i)
# $$
#
# where g is a monotone differentiable function, which in the framework of the logit logistic model, the most commonly used, is the function
# $$
# g(u) = log(u/1-u)
# $$
# a function aptly named ‘logit’.

# %% [markdown]
# $$ (y; X\beta + \sigma^2I) $$

# %% [markdown]
# ### Creation of training and test samples

# %%
# raw Python mode

## each time a new model is launched, reload here the dataframe credit2, train and test sample 

import pandas as pd

credit2 = pd.read_csv('credit2.csv') 


test_size = 0.3

shuffled_data = credit2.sample(frac=1, random_state=42)

split_point = int(len(shuffled_data) * (1 - test_size))

train = shuffled_data.iloc[:split_point].reset_index(drop=True)
test = shuffled_data.iloc[split_point:].reset_index(drop=True)

# %%
train.head(1000)
# Out:
#            accounts history_credit object_credit      savings  \
# 0      CC < 0 euros            A32    Video-HIFI  < 500 euros
# 1      CC < 0 euros            A32       New car  < 500 euros
# 2      CC < 0 euros            A31       New car  < 500 euros
# 3    CC > 200 euros            A32    Video-HIFI  < 500 euros
# 4        No account            A34      Used car  < 500 euros
# ..              ...            ...           ...          ...
# 695    CC < 0 euros            A34       New car  < 500 euros
# 696    CC < 0 euros            A32      Interior  < 500 euros
# 697      No account            A32       New car   No savings
# 698    CC < 0 euros            A32       New car   No savings
# 699      No account            A32    Video-HIFI  < 500 euros
#
#              employment_old  effort_rate                      family_status  \
# 0     between 1 and 4 years            2  Female divorced/separated/married
# 1     between 1 and 4 years            3        Male single/married/widowed
# 2      for at least 4 years            2        Male single/married/widowed
# 3     between 1 and 4 years            3        Male single/married/widowed
# 4      for at least 4 years            3        Male single/married/widowed
# ..                      ...          ...                                ...
# 695    for at least 4 years            2        Male single/married/widowed
# 696  Unemployed or < 1 year            4  Female divorced/separated/married
# 697    for at least 4 years            4        Male single/married/widowed
# 698   between 1 and 4 years            4  Female divorced/separated/married
# 699    for at least 4 years            2        Male single/married/widowed
#
#             guarantees  home_old         property       other_credits  \
# 0    Without guarantor         2         Property  No external credit
# 1    Without guarantor         4     Non-property  No external credit
# 2    Without guarantor         3     Non-property    External credits
# 3    Without guarantor         4         Property  No external credit
# 4    Without guarantor         2     Non-property  No external credit
# ..                 ...       ...              ...                 ...
# 695  Without guarantor         4      No property  No external credit
# 696  Without guarantor         3  Not real estate  No external credit
# 697  Without guarantor         2  Not real estate  No external credit
# 698  Without guarantor         2  Not real estate  No external credit
# 699  Without guarantor         4      No property    External credits
#
#     home_status  nb_credits job_type  nb_of_dependants telephone          age  \
# 0         owner           1     A173                 1      A191  [0.0, 25.0)
# 1         owner           1     A172                 2      A192  [25.0, inf)
# 2         owner           1     A173                 1      A191  [25.0, inf)
# 3     Not owner           1     A173                 1      A191  [0.0, 25.0)
# 4         owner           2     A174                 1      A192  [25.0, inf)
# ..          ...         ...      ...               ...       ...          ...
# 695   Not owner           3     A174                 1      A192  [25.0, inf)
# 696       owner           1     A173                 1      A191  [0.0, 25.0)
# 697       owner           1     A172                 1      A191  [25.0, inf)
# 698       owner           1     A173                 1      A191  [25.0, inf)
# 699   Not owner           1     A173                 2      A192  [25.0, inf)
#
#     duration_credit  amount_credit  presence_unpaid
# 0      [15.0, 36.0)  [0.0, 4000.0)                1
# 1      [15.0, 36.0)  [4000.0, inf)                0
# 2      [15.0, 36.0)  [0.0, 4000.0)                0
# 3       [0.0, 15.0)  [0.0, 4000.0)                0
# 4      [15.0, 36.0)  [4000.0, inf)                0
# ..              ...            ...              ...
# 695    [15.0, 36.0)  [4000.0, inf)                0
# 696     [0.0, 15.0)  [0.0, 4000.0)                1
# 697     [0.0, 15.0)  [0.0, 4000.0)                0
# 698    [15.0, 36.0)  [0.0, 4000.0)                1
# 699     [0.0, 15.0)  [0.0, 4000.0)                0
#
# [700 rows x 20 columns]

# %%
len(train)
# Out:
# 700

# %% [markdown]
# > *From here on, you have to choose whether to run one method or the other*.

# %% [markdown]
# ## Logistic Regression with step-by-step variable selection

# %% [markdown]
# ### Forward selection

# %%
import statsmodels.api as sm
import statsmodels.formula.api as smf
import pandas as pd
from sklearn.metrics import roc_auc_score


predictors = train.columns.difference(['presence_unpaid']).tolist()
predictors_in_model = []
best_aic = float('inf')
best_bic = float('inf')

best_models = {}

while len(predictors) > 0:
    changed = False
    best_predictor = None
    best_aic_in_iteration = float('inf')
    best_bic_in_iteration = float('inf')
    
    for predictor in predictors:
        trial_predictors = predictors_in_model + [predictor]
        trial_formula = 'presence_unpaid ~ ' + ' + '.join(trial_predictors)
        trial_model = smf.glm(formula=trial_formula, data=train, family=sm.families.Binomial()).fit()
        trial_aic = trial_model.aic
        trial_bic = trial_model.bic_llf
        
        if trial_bic < best_bic_in_iteration:
            best_aic_in_iteration = trial_aic
            best_bic_in_iteration = trial_bic
            best_predictor = predictor
            best_model = trial_model
            changed = True

    if changed and best_predictor:
        predictors_in_model.append(best_predictor)
        predictors.remove(best_predictor)
        best_aic = best_aic_in_iteration
        best_bic = best_bic_in_iteration
        
        y_pred_prob = best_model.predict(train)
        auc = roc_auc_score(train['presence_unpaid'], y_pred_prob)
        
        best_models[len(predictors_in_model)] = (best_aic, best_bic, auc, best_model)
    else:
        print("No further improvement in BIC. Stopping selection process.")
        break

min_bic_key = min(best_models, key=lambda k: best_models[k][1])

for num_vars in sorted(best_models.keys(), reverse=True):
    aic, bic, auc, model = best_models[num_vars]
    print(f"\nBest model with {num_vars} variables:")
    print(model.summary())
    print(f"AIC: {aic}, BIC: {bic}, AUC: {auc:.4f}")
    
    if num_vars == min_bic_key:
        print("Reached the model with the smallest BIC. Stopping summary display.")
        break
# Out:
# Best model with 19 variables:
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:        presence_unpaid   No. Observations:                  700
# Model:                            GLM   Df Residuals:                      661
# Model Family:                Binomial   Df Model:                           38
# Link Function:                  Logit   Scale:                          1.0000
# Method:                          IRLS   Log-Likelihood:                -325.58
# Date:                Sun, 09 Feb 2025   Deviance:                       651.16
# Time:                        11:57:36   Pearson chi2:                     651.
# No. Iterations:                     5   Pseudo R-squ. (CS):             0.2492
# Covariance Type:            nonrobust
# ================================================================================================================
#                                                    coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------------------
# Intercept                                       -0.8503      1.279     -0.665      0.506      -3.357       1.656
# accounts[T.CC > 200 euros]                      -0.7254      0.430     -1.688      0.091      -1.568       0.117
# accounts[T.CC [0-200 euros]]                    -0.2114      0.243     -0.870      0.385      -0.688       0.265
# accounts[T.No account]                          -1.7710      0.273     -6.479      0.000      -2.307      -1.235
# duration_credit[T.[15.0, 36.0)]                  0.6035      0.243      2.488      0.013       0.128       1.079
# duration_credit[T.[36.0, inf)]                   1.1317      0.345      3.285      0.001       0.456       1.807
# other_credits[T.No external credit]             -0.7339      0.248     -2.962      0.003      -1.220      -0.248
# family_status[T.Male divorced/separated]         0.6639      0.438      1.515      0.130      -0.195       1.523
# family_status[T.Male single/married/widowed]    -0.5964      0.231     -2.586      0.010      -1.048      -0.144
# guarantees[T.Without guarantor]                  0.9343      0.490      1.909      0.056      -0.025       1.894
# savings[T.> 500 euros]                          -0.6162      0.361     -1.705      0.088      -1.324       0.092
# savings[T.No savings]                           -0.9525      0.302     -3.155      0.002      -1.544      -0.361
# amount_credit[T.[4000.0, inf)]                   0.5730      0.294      1.949      0.051      -0.003       1.149
# age[T.[25.0, inf)]                              -0.2869      0.298     -0.964      0.335      -0.870       0.297
# home_status[T.owner]                            -0.1647      0.270     -0.610      0.542      -0.694       0.364
# telephone[T.A192]                               -0.2192      0.227     -0.964      0.335      -0.665       0.226
# employment_old[T.between 1 and 4 years]          0.0703      0.268      0.263      0.793      -0.454       0.595
# employment_old[T.for at least 4 years]          -0.2776      0.276     -1.007      0.314      -0.818       0.263
# history_credit[T.A31]                           -0.0119      0.669     -0.018      0.986      -1.324       1.300
# history_credit[T.A32]                           -0.4434      0.562     -0.788      0.430      -1.546       0.659
# history_credit[T.A33]                           -0.8894      0.597     -1.489      0.137      -2.060       0.281
# history_credit[T.A34]                           -1.2930      0.563     -2.298      0.022      -2.396      -0.190
# property[T.Non-property]                        -0.1789      0.359     -0.498      0.619      -0.883       0.525
# property[T.Not real estate]                      0.1350      0.377      0.358      0.721      -0.605       0.875
# property[T.Property]                            -0.1566      0.393     -0.399      0.690      -0.926       0.613
# job_type[T.A172]                                -0.4933      0.708     -0.696      0.486      -1.882       0.895
# job_type[T.A173]                                -0.5330      0.693     -0.769      0.442      -1.891       0.825
# job_type[T.A174]                                -0.2146      0.732     -0.293      0.769      -1.649       1.219
# object_credit[T.Education]                      -0.2534      1.257     -0.202      0.840      -2.716       2.210
# object_credit[T.Interior]                        0.2030      0.389      0.522      0.602      -0.559       0.965
# object_credit[T.New car]                         0.5968      0.385      1.551      0.121      -0.157       1.351
# object_credit[T.Other]                          -0.7834      0.902     -0.869      0.385      -2.551       0.984
# object_credit[T.Studies]                         0.6189      0.527      1.174      0.240      -0.414       1.652
# object_credit[T.Used car]                       -0.5954      0.516     -1.154      0.248      -1.607       0.416
# object_credit[T.Video-HIFI]                      0.0478      0.393      0.122      0.903      -0.723       0.819
# effort_rate                                      0.2633      0.097      2.720      0.007       0.074       0.453
# nb_of_dependants                                 0.2472      0.282      0.878      0.380      -0.305       0.799
# nb_credits                                       0.3871      0.221      1.753      0.080      -0.046       0.820
# home_old                                         0.0433      0.097      0.445      0.656      -0.148       0.234
# ================================================================================================================
# AIC: 729.1554543506244, BIC: 906.6475874173171, AUC: 0.8151
#
# Best model with 18 variables:
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:        presence_unpaid   No. Observations:                  700
# Model:                            GLM   Df Residuals:                      668
# Model Family:                Binomial   Df Model:                           31
# Link Function:                  Logit   Scale:                          1.0000
# Method:                          IRLS   Log-Likelihood:                -331.33
# Date:                Sun, 09 Feb 2025   Deviance:                       662.66
# Time:                        11:57:36   Pearson chi2:                     652.
# No. Iterations:                     5   Pseudo R-squ. (CS):             0.2368
# Covariance Type:            nonrobust
# ================================================================================================================
#                                                    coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------------------
# Intercept                                       -0.8386      1.251     -0.670      0.503      -3.291       1.614
# accounts[T.CC > 200 euros]                      -0.7104      0.426     -1.670      0.095      -1.544       0.124
# accounts[T.CC [0-200 euros]]                    -0.2297      0.237     -0.970      0.332      -0.694       0.234
# accounts[T.No account]                          -1.8253      0.271     -6.745      0.000      -2.356      -1.295
# duration_credit[T.[15.0, 36.0)]                  0.4998      0.234      2.136      0.033       0.041       0.958
# duration_credit[T.[36.0, inf)]                   1.0562      0.338      3.123      0.002       0.393       1.719
# other_credits[T.No external credit]             -0.6799      0.242     -2.815      0.005      -1.153      -0.206
# family_status[T.Male divorced/separated]         0.6789      0.430      1.578      0.115      -0.164       1.522
# family_status[T.Male single/married/widowed]    -0.6240      0.227     -2.745      0.006      -1.070      -0.178
# guarantees[T.Without guarantor]                  1.0588      0.484      2.190      0.029       0.111       2.007
# savings[T.> 500 euros]                          -0.6148      0.357     -1.724      0.085      -1.314       0.084
# savings[T.No savings]                           -0.9422      0.296     -3.182      0.001      -1.522      -0.362
# amount_credit[T.[4000.0, inf)]                   0.4161      0.284      1.465      0.143      -0.141       0.973
# age[T.[25.0, inf)]                              -0.2471      0.290     -0.851      0.395      -0.816       0.322
# home_status[T.owner]                            -0.1444      0.264     -0.547      0.585      -0.662       0.373
# telephone[T.A192]                               -0.1903      0.222     -0.858      0.391      -0.625       0.245
# employment_old[T.between 1 and 4 years]          0.0397      0.264      0.150      0.880      -0.477       0.556
# employment_old[T.for at least 4 years]          -0.3209      0.269     -1.194      0.232      -0.848       0.206
# history_credit[T.A31]                           -0.0563      0.656     -0.086      0.932      -1.342       1.229
# history_credit[T.A32]                           -0.4755      0.547     -0.870      0.385      -1.547       0.596
# history_credit[T.A33]                           -0.8777      0.587     -1.495      0.135      -2.028       0.273
# history_credit[T.A34]                           -1.2569      0.546     -2.304      0.021      -2.326      -0.188
# property[T.Non-property]                        -0.2158      0.351     -0.615      0.538      -0.903       0.472
# property[T.Not real estate]                      0.1847      0.368      0.501      0.616      -0.538       0.907
# property[T.Property]                            -0.1664      0.380     -0.438      0.662      -0.912       0.579
# job_type[T.A172]                                -0.4512      0.716     -0.630      0.528      -1.854       0.951
# job_type[T.A173]                                -0.4796      0.700     -0.686      0.493      -1.851       0.891
# job_type[T.A174]                                -0.2857      0.739     -0.387      0.699      -1.734       1.163
# effort_rate                                      0.2687      0.095      2.836      0.005       0.083       0.454
# nb_of_dependants                                 0.2988      0.278      1.073      0.283      -0.247       0.844
# nb_credits                                       0.4104      0.219      1.875      0.061      -0.019       0.839
# home_old                                         0.0410      0.096      0.428      0.669      -0.147       0.229
# ================================================================================================================
# AIC: 726.6638186207457, BIC: 872.2983893421347, AUC: 0.8066
#
# Best model with 17 variables:
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:        presence_unpaid   No. Observations:                  700
# Model:                            GLM   Df Residuals:                      671
# Model Family:                Binomial   Df Model:                           28
# Link Function:                  Logit   Scale:                          1.0000
# Method:                          IRLS   Log-Likelihood:                -331.71
# Date:                Sun, 09 Feb 2025   Deviance:                       663.42
# Time:                        11:57:36   Pearson chi2:                     651.
# No. Iterations:                     5   Pseudo R-squ. (CS):             0.2359
# Covariance Type:            nonrobust
# ================================================================================================================
#                                                    coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------------------
# Intercept                                       -1.2931      1.054     -1.226      0.220      -3.359       0.773
# accounts[T.CC > 200 euros]                      -0.6850      0.422     -1.624      0.104      -1.512       0.142
# accounts[T.CC [0-200 euros]]                    -0.2215      0.236     -0.937      0.349      -0.685       0.242
# accounts[T.No account]                          -1.8233      0.270     -6.742      0.000      -2.353      -1.293
# duration_credit[T.[15.0, 36.0)]                  0.4818      0.232      2.081      0.037       0.028       0.936
# duration_credit[T.[36.0, inf)]                   1.0301      0.334      3.082      0.002       0.375       1.685
# other_credits[T.No external credit]             -0.6706      0.240     -2.794      0.005      -1.141      -0.200
# family_status[T.Male divorced/separated]         0.6664      0.429      1.552      0.121      -0.175       1.508
# family_status[T.Male single/married/widowed]    -0.6203      0.227     -2.735      0.006      -1.065      -0.176
# guarantees[T.Without guarantor]                  1.0722      0.482      2.222      0.026       0.127       2.018
# savings[T.> 500 euros]                          -0.6297      0.356     -1.770      0.077      -1.327       0.068
# savings[T.No savings]                           -0.9313      0.294     -3.165      0.002      -1.508      -0.355
# amount_credit[T.[4000.0, inf)]                   0.4460      0.277      1.612      0.107      -0.096       0.988
# age[T.[25.0, inf)]                              -0.2186      0.288     -0.760      0.447      -0.782       0.345
# home_status[T.owner]                            -0.1506      0.262     -0.575      0.565      -0.664       0.363
# telephone[T.A192]                               -0.1537      0.210     -0.733      0.464      -0.565       0.257
# employment_old[T.between 1 and 4 years]         -0.0157      0.255     -0.061      0.951      -0.516       0.485
# employment_old[T.for at least 4 years]          -0.3736      0.260     -1.434      0.151      -0.884       0.137
# history_credit[T.A31]                           -0.0114      0.653     -0.017      0.986      -1.292       1.269
# history_credit[T.A32]                           -0.4509      0.545     -0.828      0.408      -1.519       0.617
# history_credit[T.A33]                           -0.8584      0.584     -1.470      0.141      -2.003       0.286
# history_credit[T.A34]                           -1.2286      0.543     -2.263      0.024      -2.293      -0.164
# property[T.Non-property]                        -0.2374      0.349     -0.680      0.496      -0.921       0.447
# property[T.Not real estate]                      0.1425      0.364      0.391      0.696      -0.572       0.857
# property[T.Property]                            -0.1944      0.374     -0.519      0.603      -0.928       0.539
# effort_rate                                      0.2702      0.094      2.869      0.004       0.086       0.455
# nb_of_dependants                                 0.2926      0.274      1.068      0.286      -0.244       0.830
# nb_credits                                       0.4237      0.217      1.954      0.051      -0.001       0.849
# home_old                                         0.0372      0.095      0.391      0.696      -0.150       0.224
# ================================================================================================================
# AIC: 721.4227747551399, BIC: 853.4041044713987, AUC: 0.8059
#
# Best model with 16 variables:
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:        presence_unpaid   No. Observations:                  700
# Model:                            GLM   Df Residuals:                      674
# Model Family:                Binomial   Df Model:                           25
# Link Function:                  Logit   Scale:                          1.0000
# Method:                          IRLS   Log-Likelihood:                -333.00
# Date:                Sun, 09 Feb 2025   Deviance:                       666.00
# Time:                        11:57:36   Pearson chi2:                     654.
# No. Iterations:                     5   Pseudo R-squ. (CS):             0.2331
# Covariance Type:            nonrobust
# ================================================================================================================
#                                                    coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------------------
# Intercept                                       -1.2939      1.001     -1.293      0.196      -3.256       0.668
# accounts[T.CC > 200 euros]                      -0.7183      0.420     -1.712      0.087      -1.541       0.104
# accounts[T.CC [0-200 euros]]                    -0.2536      0.235     -1.081      0.280      -0.713       0.206
# accounts[T.No account]                          -1.8457      0.270     -6.844      0.000      -2.374      -1.317
# duration_credit[T.[15.0, 36.0)]                  0.4599      0.226      2.034      0.042       0.017       0.903
# duration_credit[T.[36.0, inf)]                   0.9912      0.327      3.035      0.002       0.351       1.631
# other_credits[T.No external credit]             -0.6701      0.238     -2.811      0.005      -1.137      -0.203
# family_status[T.Male divorced/separated]         0.6454      0.425      1.518      0.129      -0.188       1.479
# family_status[T.Male single/married/widowed]    -0.6127      0.224     -2.730      0.006      -1.053      -0.173
# guarantees[T.Without guarantor]                  1.0279      0.475      2.164      0.030       0.097       1.959
# savings[T.> 500 euros]                          -0.6401      0.355     -1.805      0.071      -1.335       0.055
# savings[T.No savings]                           -0.8955      0.292     -3.063      0.002      -1.468      -0.323
# amount_credit[T.[4000.0, inf)]                   0.4720      0.272      1.738      0.082      -0.060       1.004
# age[T.[25.0, inf)]                              -0.2199      0.281     -0.782      0.434      -0.771       0.331
# home_status[T.owner]                            -0.1831      0.228     -0.804      0.421      -0.630       0.263
# telephone[T.A192]                               -0.1422      0.208     -0.684      0.494      -0.550       0.265
# employment_old[T.between 1 and 4 years]         -0.0739      0.251     -0.295      0.768      -0.566       0.418
# employment_old[T.for at least 4 years]          -0.4032      0.258     -1.562      0.118      -0.909       0.103
# history_credit[T.A31]                           -0.0158      0.653     -0.024      0.981      -1.295       1.264
# history_credit[T.A32]                           -0.4451      0.545     -0.816      0.414      -1.514       0.624
# history_credit[T.A33]                           -0.8261      0.582     -1.420      0.156      -1.967       0.315
# history_credit[T.A34]                           -1.2144      0.542     -2.241      0.025      -2.276      -0.152
# effort_rate                                      0.2764      0.093      2.966      0.003       0.094       0.459
# nb_of_dependants                                 0.2864      0.272      1.052      0.293      -0.247       0.820
# nb_credits                                       0.4183      0.218      1.922      0.055      -0.008       0.845
# home_old                                         0.0412      0.095      0.434      0.664      -0.145       0.227
# ================================================================================================================
# AIC: 717.9993756977834, BIC: 836.327464408912, AUC: 0.8040
#
# Best model with 15 variables:
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:        presence_unpaid   No. Observations:                  700
# Model:                            GLM   Df Residuals:                      678
# Model Family:                Binomial   Df Model:                           21
# Link Function:                  Logit   Scale:                          1.0000
# Method:                          IRLS   Log-Likelihood:                -338.96
# Date:                Sun, 09 Feb 2025   Deviance:                       677.92
# Time:                        11:57:36   Pearson chi2:                     657.
# No. Iterations:                     5   Pseudo R-squ. (CS):             0.2199
# Covariance Type:            nonrobust
# ================================================================================================================
#                                                    coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------------------
# Intercept                                       -1.2678      0.776     -1.634      0.102      -2.788       0.253
# accounts[T.CC > 200 euros]                      -0.7988      0.411     -1.945      0.052      -1.604       0.006
# accounts[T.CC [0-200 euros]]                    -0.2903      0.228     -1.273      0.203      -0.737       0.157
# accounts[T.No account]                          -1.9464      0.267     -7.288      0.000      -2.470      -1.423
# duration_credit[T.[15.0, 36.0)]                  0.4714      0.223      2.118      0.034       0.035       0.908
# duration_credit[T.[36.0, inf)]                   1.0339      0.322      3.207      0.001       0.402       1.666
# other_credits[T.No external credit]             -0.7762      0.227     -3.421      0.001      -1.221      -0.332
# family_status[T.Male divorced/separated]         0.5492      0.417      1.317      0.188      -0.268       1.366
# family_status[T.Male single/married/widowed]    -0.6260      0.221     -2.829      0.005      -1.060      -0.192
# guarantees[T.Without guarantor]                  1.0655      0.471      2.263      0.024       0.143       1.988
# savings[T.> 500 euros]                          -0.6118      0.345     -1.775      0.076      -1.287       0.064
# savings[T.No savings]                           -0.8540      0.288     -2.965      0.003      -1.419      -0.289
# amount_credit[T.[4000.0, inf)]                   0.4704      0.266      1.770      0.077      -0.050       0.991
# age[T.[25.0, inf)]                              -0.2278      0.276     -0.825      0.410      -0.769       0.314
# home_status[T.owner]                            -0.2295      0.223     -1.027      0.304      -0.667       0.208
# telephone[T.A192]                               -0.1318      0.204     -0.645      0.519      -0.532       0.269
# employment_old[T.between 1 and 4 years]         -0.0523      0.247     -0.211      0.833      -0.537       0.433
# employment_old[T.for at least 4 years]          -0.4175      0.254     -1.645      0.100      -0.915       0.080
# effort_rate                                      0.2715      0.092      2.955      0.003       0.091       0.452
# nb_of_dependants                                 0.3016      0.270      1.118      0.263      -0.227       0.830
# nb_credits                                       0.1039      0.172      0.602      0.547      -0.234       0.442
# home_old                                         0.0019      0.093      0.020      0.984      -0.181       0.185
# ================================================================================================================
# AIC: 721.91577226005, BIC: 822.0395396310048, AUC: 0.7952
#
# Best model with 14 variables:
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:        presence_unpaid   No. Observations:                  700
# Model:                            GLM   Df Residuals:                      680
# Model Family:                Binomial   Df Model:                           19
# Link Function:                  Logit   Scale:                          1.0000
# Method:                          IRLS   Log-Likelihood:                -340.72
# Date:                Sun, 09 Feb 2025   Deviance:                       681.44
# Time:                        11:57:36   Pearson chi2:                     656.
# No. Iterations:                     5   Pseudo R-squ. (CS):             0.2160
# Covariance Type:            nonrobust
# ================================================================================================================
#                                                    coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------------------
# Intercept                                       -1.1905      0.753     -1.581      0.114      -2.666       0.285
# accounts[T.CC > 200 euros]                      -0.7918      0.411     -1.926      0.054      -1.597       0.014
# accounts[T.CC [0-200 euros]]                    -0.2799      0.227     -1.234      0.217      -0.724       0.165
# accounts[T.No account]                          -1.9575      0.265     -7.382      0.000      -2.477      -1.438
# duration_credit[T.[15.0, 36.0)]                  0.4796      0.222      2.163      0.031       0.045       0.914
# duration_credit[T.[36.0, inf)]                   1.0186      0.321      3.173      0.002       0.389       1.648
# other_credits[T.No external credit]             -0.7842      0.226     -3.463      0.001      -1.228      -0.340
# family_status[T.Male divorced/separated]         0.5192      0.416      1.247      0.212      -0.297       1.335
# family_status[T.Male single/married/widowed]    -0.6581      0.219     -3.004      0.003      -1.087      -0.229
# guarantees[T.Without guarantor]                  1.1223      0.469      2.394      0.017       0.203       2.041
# savings[T.> 500 euros]                          -0.6244      0.341     -1.830      0.067      -1.293       0.044
# savings[T.No savings]                           -0.8766      0.287     -3.058      0.002      -1.438      -0.315
# amount_credit[T.[4000.0, inf)]                   0.4803      0.265      1.812      0.070      -0.039       1.000
# age[T.[25.0, inf)]                              -0.3085      0.272     -1.133      0.257      -0.842       0.225
# home_status[T.owner]                            -0.2410      0.223     -1.082      0.279      -0.678       0.196
# telephone[T.A192]                               -0.1469      0.203     -0.723      0.470      -0.545       0.251
# effort_rate                                      0.2604      0.092      2.841      0.004       0.081       0.440
# nb_of_dependants                                 0.2868      0.269      1.066      0.286      -0.240       0.814
# nb_credits                                       0.0731      0.171      0.427      0.670      -0.263       0.409
# home_old                                        -0.0376      0.090     -0.417      0.677      -0.214       0.139
# ================================================================================================================
# AIC: 721.4422647858323, BIC: 812.4638714867004, AUC: 0.7918
#
# Best model with 13 variables:
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:        presence_unpaid   No. Observations:                  700
# Model:                            GLM   Df Residuals:                      681
# Model Family:                Binomial   Df Model:                           18
# Link Function:                  Logit   Scale:                          1.0000
# Method:                          IRLS   Log-Likelihood:                -340.81
# Date:                Sun, 09 Feb 2025   Deviance:                       681.62
# Time:                        11:57:36   Pearson chi2:                     656.
# No. Iterations:                     5   Pseudo R-squ. (CS):             0.2158
# Covariance Type:            nonrobust
# ================================================================================================================
#                                                    coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------------------
# Intercept                                       -1.3025      0.704     -1.851      0.064      -2.682       0.077
# accounts[T.CC > 200 euros]                      -0.7824      0.410     -1.908      0.056      -1.586       0.021
# accounts[T.CC [0-200 euros]]                    -0.2724      0.226     -1.205      0.228      -0.715       0.171
# accounts[T.No account]                          -1.9520      0.265     -7.374      0.000      -2.471      -1.433
# duration_credit[T.[15.0, 36.0)]                  0.4773      0.222      2.154      0.031       0.043       0.912
# duration_credit[T.[36.0, inf)]                   1.0263      0.321      3.202      0.001       0.398       1.655
# other_credits[T.No external credit]             -0.7846      0.226     -3.465      0.001      -1.228      -0.341
# family_status[T.Male divorced/separated]         0.5315      0.415      1.281      0.200      -0.282       1.345
# family_status[T.Male single/married/widowed]    -0.6574      0.219     -3.002      0.003      -1.087      -0.228
# guarantees[T.Without guarantor]                  1.1270      0.469      2.404      0.016       0.208       2.046
# savings[T.> 500 euros]                          -0.6299      0.341     -1.848      0.065      -1.298       0.038
# savings[T.No savings]                           -0.8849      0.286     -3.095      0.002      -1.445      -0.325
# amount_credit[T.[4000.0, inf)]                   0.4748      0.265      1.793      0.073      -0.044       0.994
# age[T.[25.0, inf)]                              -0.3065      0.272     -1.126      0.260      -0.840       0.227
# home_status[T.owner]                            -0.2119      0.212     -1.002      0.316      -0.627       0.203
# telephone[T.A192]                               -0.1544      0.202     -0.763      0.446      -0.551       0.242
# effort_rate                                      0.2582      0.092      2.821      0.005       0.079       0.438
# nb_of_dependants                                 0.2817      0.269      1.049      0.294      -0.245       0.808
# nb_credits                                       0.0679      0.171      0.398      0.691      -0.267       0.403
# ================================================================================================================
# AIC: 719.6163065095259, BIC: 806.0868328753505, AUC: 0.7913
#
# Best model with 12 variables:
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:        presence_unpaid   No. Observations:                  700
# Model:                            GLM   Df Residuals:                      682
# Model Family:                Binomial   Df Model:                           17
# Link Function:                  Logit   Scale:                          1.0000
# Method:                          IRLS   Log-Likelihood:                -340.89
# Date:                Sun, 09 Feb 2025   Deviance:                       681.77
# Time:                        11:57:36   Pearson chi2:                     659.
# No. Iterations:                     5   Pseudo R-squ. (CS):             0.2156
# Covariance Type:            nonrobust
# ================================================================================================================
#                                                    coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------------------
# Intercept                                       -1.2272      0.678     -1.811      0.070      -2.556       0.101
# accounts[T.CC > 200 euros]                      -0.7874      0.410     -1.920      0.055      -1.591       0.017
# accounts[T.CC [0-200 euros]]                    -0.2748      0.226     -1.216      0.224      -0.718       0.168
# accounts[T.No account]                          -1.9422      0.263     -7.374      0.000      -2.458      -1.426
# duration_credit[T.[15.0, 36.0)]                  0.4790      0.222      2.162      0.031       0.045       0.913
# duration_credit[T.[36.0, inf)]                   1.0193      0.320      3.187      0.001       0.392       1.646
# other_credits[T.No external credit]             -0.7868      0.226     -3.476      0.001      -1.231      -0.343
# family_status[T.Male divorced/separated]         0.5308      0.415      1.280      0.201      -0.282       1.344
# family_status[T.Male single/married/widowed]    -0.6538      0.219     -2.990      0.003      -1.082      -0.225
# guarantees[T.Without guarantor]                  1.1299      0.469      2.411      0.016       0.211       2.049
# savings[T.> 500 euros]                          -0.6313      0.341     -1.852      0.064      -1.299       0.037
# savings[T.No savings]                           -0.8921      0.285     -3.126      0.002      -1.451      -0.333
# amount_credit[T.[4000.0, inf)]                   0.4820      0.264      1.825      0.068      -0.036       1.000
# age[T.[25.0, inf)]                              -0.2952      0.271     -1.091      0.275      -0.826       0.235
# home_status[T.owner]                            -0.2115      0.211     -1.000      0.317      -0.626       0.203
# telephone[T.A192]                               -0.1519      0.202     -0.751      0.453      -0.548       0.245
# effort_rate                                      0.2563      0.091      2.806      0.005       0.077       0.435
# nb_of_dependants                                 0.2898      0.268      1.083      0.279      -0.235       0.814
# ================================================================================================================
# AIC: 717.7740466395505, BIC: 799.6934926703318, AUC: 0.7909
#
# Best model with 11 variables:
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:        presence_unpaid   No. Observations:                  700
# Model:                            GLM   Df Residuals:                      683
# Model Family:                Binomial   Df Model:                           16
# Link Function:                  Logit   Scale:                          1.0000
# Method:                          IRLS   Log-Likelihood:                -341.17
# Date:                Sun, 09 Feb 2025   Deviance:                       682.34
# Time:                        11:57:36   Pearson chi2:                     658.
# No. Iterations:                     5   Pseudo R-squ. (CS):             0.2150
# Covariance Type:            nonrobust
# ================================================================================================================
#                                                    coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------------------
# Intercept                                       -1.2423      0.677     -1.836      0.066      -2.569       0.084
# accounts[T.CC > 200 euros]                      -0.7709      0.408     -1.888      0.059      -1.571       0.029
# accounts[T.CC [0-200 euros]]                    -0.2767      0.226     -1.225      0.221      -0.720       0.166
# accounts[T.No account]                          -1.9423      0.263     -7.380      0.000      -2.458      -1.427
# duration_credit[T.[15.0, 36.0)]                  0.4672      0.221      2.115      0.034       0.034       0.900
# duration_credit[T.[36.0, inf)]                   1.0118      0.320      3.164      0.002       0.385       1.638
# other_credits[T.No external credit]             -0.7832      0.226     -3.464      0.001      -1.226      -0.340
# family_status[T.Male divorced/separated]         0.5186      0.413      1.254      0.210      -0.292       1.329
# family_status[T.Male single/married/widowed]    -0.6580      0.219     -3.010      0.003      -1.086      -0.230
# guarantees[T.Without guarantor]                  1.1154      0.468      2.384      0.017       0.198       2.032
# savings[T.> 500 euros]                          -0.6452      0.341     -1.894      0.058      -1.313       0.022
# savings[T.No savings]                           -0.9031      0.285     -3.169      0.002      -1.462      -0.345
# amount_credit[T.[4000.0, inf)]                   0.4553      0.262      1.740      0.082      -0.058       0.968
# age[T.[25.0, inf)]                              -0.3247      0.268     -1.213      0.225      -0.849       0.200
# home_status[T.owner]                            -0.1999      0.211     -0.949      0.343      -0.613       0.213
# effort_rate                                      0.2550      0.091      2.792      0.005       0.076       0.434
# nb_of_dependants                                 0.2967      0.267      1.110      0.267      -0.227       0.821
# ================================================================================================================
# AIC: 716.3398300527329, BIC: 793.7081957484708, AUC: 0.7908
#
# Best model with 10 variables:
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:        presence_unpaid   No. Observations:                  700
# Model:                            GLM   Df Residuals:                      684
# Model Family:                Binomial   Df Model:                           15
# Link Function:                  Logit   Scale:                          1.0000
# Method:                          IRLS   Log-Likelihood:                -341.62
# Date:                Sun, 09 Feb 2025   Deviance:                       683.23
# Time:                        11:57:36   Pearson chi2:                     661.
# No. Iterations:                     5   Pseudo R-squ. (CS):             0.2140
# Covariance Type:            nonrobust
# ================================================================================================================
#                                                    coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------------------
# Intercept                                       -1.3402      0.668     -2.007      0.045      -2.649      -0.031
# accounts[T.CC > 200 euros]                      -0.7923      0.408     -1.941      0.052      -1.592       0.008
# accounts[T.CC [0-200 euros]]                    -0.2903      0.225     -1.289      0.197      -0.732       0.151
# accounts[T.No account]                          -1.9661      0.262     -7.497      0.000      -2.480      -1.452
# duration_credit[T.[15.0, 36.0)]                  0.4727      0.221      2.143      0.032       0.040       0.905
# duration_credit[T.[36.0, inf)]                   1.0284      0.319      3.226      0.001       0.404       1.653
# other_credits[T.No external credit]             -0.7732      0.226     -3.426      0.001      -1.215      -0.331
# family_status[T.Male divorced/separated]         0.4997      0.413      1.211      0.226      -0.309       1.309
# family_status[T.Male single/married/widowed]    -0.6779      0.217     -3.119      0.002      -1.104      -0.252
# guarantees[T.Without guarantor]                  1.1195      0.465      2.407      0.016       0.208       2.031
# savings[T.> 500 euros]                          -0.6586      0.340     -1.935      0.053      -1.326       0.009
# savings[T.No savings]                           -0.9034      0.284     -3.176      0.001      -1.461      -0.346
# amount_credit[T.[4000.0, inf)]                   0.4669      0.261      1.789      0.074      -0.045       0.978
# age[T.[25.0, inf)]                              -0.3721      0.263     -1.416      0.157      -0.887       0.143
# effort_rate                                      0.2523      0.091      2.768      0.006       0.074       0.431
# nb_of_dependants                                 0.3079      0.267      1.154      0.249      -0.215       0.831
# ================================================================================================================
# AIC: 715.2348944748212, BIC: 788.0521798355156, AUC: 0.7898
#
# Best model with 9 variables:
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:        presence_unpaid   No. Observations:                  700
# Model:                            GLM   Df Residuals:                      685
# Model Family:                Binomial   Df Model:                           14
# Link Function:                  Logit   Scale:                          1.0000
# Method:                          IRLS   Log-Likelihood:                -342.28
# Date:                Sun, 09 Feb 2025   Deviance:                       684.55
# Time:                        11:57:36   Pearson chi2:                     665.
# No. Iterations:                     5   Pseudo R-squ. (CS):             0.2125
# Covariance Type:            nonrobust
# ================================================================================================================
#                                                    coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------------------
# Intercept                                       -1.0036      0.600     -1.673      0.094      -2.180       0.172
# accounts[T.CC > 200 euros]                      -0.8068      0.408     -1.976      0.048      -1.607      -0.007
# accounts[T.CC [0-200 euros]]                    -0.3044      0.225     -1.356      0.175      -0.744       0.136
# accounts[T.No account]                          -1.9669      0.262     -7.511      0.000      -2.480      -1.454
# duration_credit[T.[15.0, 36.0)]                  0.4634      0.220      2.105      0.035       0.032       0.895
# duration_credit[T.[36.0, inf)]                   1.0243      0.318      3.221      0.001       0.401       1.648
# other_credits[T.No external credit]             -0.7775      0.225     -3.449      0.001      -1.219      -0.336
# family_status[T.Male divorced/separated]         0.5027      0.412      1.219      0.223      -0.305       1.311
# family_status[T.Male single/married/widowed]    -0.6286      0.212     -2.959      0.003      -1.045      -0.212
# guarantees[T.Without guarantor]                  1.1262      0.465      2.422      0.015       0.215       2.038
# savings[T.> 500 euros]                          -0.6557      0.339     -1.932      0.053      -1.321       0.009
# savings[T.No savings]                           -0.8949      0.284     -3.153      0.002      -1.451      -0.339
# amount_credit[T.[4000.0, inf)]                   0.4511      0.260      1.735      0.083      -0.058       0.961
# age[T.[25.0, inf)]                              -0.3358      0.260     -1.291      0.197      -0.846       0.174
# effort_rate                                      0.2424      0.091      2.671      0.008       0.065       0.420
# ================================================================================================================
# AIC: 714.5503741060957, BIC: 782.8165791317467, AUC: 0.7888
#
# Best model with 8 variables:
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:        presence_unpaid   No. Observations:                  700
# Model:                            GLM   Df Residuals:                      686
# Model Family:                Binomial   Df Model:                           13
# Link Function:                  Logit   Scale:                          1.0000
# Method:                          IRLS   Log-Likelihood:                -343.10
# Date:                Sun, 09 Feb 2025   Deviance:                       686.20
# Time:                        11:57:36   Pearson chi2:                     668.
# No. Iterations:                     5   Pseudo R-squ. (CS):             0.2107
# Covariance Type:            nonrobust
# ================================================================================================================
#                                                    coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------------------
# Intercept                                       -1.2099      0.579     -2.089      0.037      -2.345      -0.075
# accounts[T.CC > 200 euros]                      -0.8348      0.406     -2.056      0.040      -1.631      -0.039
# accounts[T.CC [0-200 euros]]                    -0.3205      0.224     -1.431      0.152      -0.760       0.119
# accounts[T.No account]                          -2.0053      0.260     -7.712      0.000      -2.515      -1.496
# duration_credit[T.[15.0, 36.0)]                  0.4650      0.220      2.116      0.034       0.034       0.896
# duration_credit[T.[36.0, inf)]                   1.0232      0.318      3.219      0.001       0.400       1.646
# other_credits[T.No external credit]             -0.7738      0.225     -3.441      0.001      -1.214      -0.333
# family_status[T.Male divorced/separated]         0.4179      0.406      1.028      0.304      -0.379       1.214
# family_status[T.Male single/married/widowed]    -0.6792      0.208     -3.260      0.001      -1.088      -0.271
# guarantees[T.Without guarantor]                  1.1290      0.466      2.422      0.015       0.215       2.043
# savings[T.> 500 euros]                          -0.6477      0.338     -1.918      0.055      -1.310       0.014
# savings[T.No savings]                           -0.9173      0.283     -3.236      0.001      -1.473      -0.362
# amount_credit[T.[4000.0, inf)]                   0.4337      0.259      1.673      0.094      -0.074       0.942
# effort_rate                                      0.2354      0.090      2.603      0.009       0.058       0.413
# ================================================================================================================
# AIC: 714.2043863212825, BIC: 777.9195110118902, AUC: 0.7865
#
# Best model with 7 variables:
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:        presence_unpaid   No. Observations:                  700
# Model:                            GLM   Df Residuals:                      687
# Model Family:                Binomial   Df Model:                           12
# Link Function:                  Logit   Scale:                          1.0000
# Method:                          IRLS   Log-Likelihood:                -344.49
# Date:                Sun, 09 Feb 2025   Deviance:                       688.99
# Time:                        11:57:36   Pearson chi2:                     678.
# No. Iterations:                     5   Pseudo R-squ. (CS):             0.2075
# Covariance Type:            nonrobust
# ================================================================================================================
#                                                    coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------------------
# Intercept                                       -1.1037      0.574     -1.923      0.054      -2.229       0.021
# accounts[T.CC > 200 euros]                      -0.8785      0.402     -2.183      0.029      -1.667      -0.090
# accounts[T.CC [0-200 euros]]                    -0.3159      0.224     -1.413      0.158      -0.754       0.122
# accounts[T.No account]                          -2.0100      0.259     -7.747      0.000      -2.518      -1.501
# duration_credit[T.[15.0, 36.0)]                  0.5360      0.215      2.493      0.013       0.115       0.957
# duration_credit[T.[36.0, inf)]                   1.2975      0.273      4.756      0.000       0.763       1.832
# other_credits[T.No external credit]             -0.7743      0.224     -3.453      0.001      -1.214      -0.335
# family_status[T.Male divorced/separated]         0.4135      0.404      1.022      0.307      -0.379       1.206
# family_status[T.Male single/married/widowed]    -0.6574      0.207     -3.173      0.002      -1.064      -0.251
# guarantees[T.Without guarantor]                  1.1743      0.465      2.526      0.012       0.263       2.086
# savings[T.> 500 euros]                          -0.6551      0.337     -1.944      0.052      -1.315       0.005
# savings[T.No savings]                           -0.8963      0.283     -3.170      0.002      -1.451      -0.342
# effort_rate                                      0.1912      0.086      2.221      0.026       0.022       0.360
# ================================================================================================================
# AIC: 714.9890047653034, BIC: 774.1530491208676, AUC: 0.7842
#
# Best model with 6 variables:
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:        presence_unpaid   No. Observations:                  700
# Model:                            GLM   Df Residuals:                      688
# Model Family:                Binomial   Df Model:                           11
# Link Function:                  Logit   Scale:                          1.0000
# Method:                          IRLS   Log-Likelihood:                -347.01
# Date:                Sun, 09 Feb 2025   Deviance:                       694.02
# Time:                        11:57:36   Pearson chi2:                     676.
# No. Iterations:                     5   Pseudo R-squ. (CS):             0.2018
# Covariance Type:            nonrobust
# ================================================================================================================
#                                                    coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------------------
# Intercept                                       -0.5908      0.525     -1.125      0.261      -1.620       0.439
# accounts[T.CC > 200 euros]                      -0.9177      0.400     -2.293      0.022      -1.702      -0.133
# accounts[T.CC [0-200 euros]]                    -0.3454      0.222     -1.554      0.120      -0.781       0.090
# accounts[T.No account]                          -2.0019      0.258     -7.753      0.000      -2.508      -1.496
# duration_credit[T.[15.0, 36.0)]                  0.5528      0.214      2.584      0.010       0.134       0.972
# duration_credit[T.[36.0, inf)]                   1.2876      0.270      4.762      0.000       0.758       1.817
# other_credits[T.No external credit]             -0.7611      0.223     -3.407      0.001      -1.199      -0.323
# family_status[T.Male divorced/separated]         0.3590      0.401      0.894      0.371      -0.428       1.146
# family_status[T.Male single/married/widowed]    -0.6020      0.204     -2.944      0.003      -1.003      -0.201
# guarantees[T.Without guarantor]                  1.1909      0.467      2.552      0.011       0.276       2.105
# savings[T.> 500 euros]                          -0.6379      0.337     -1.895      0.058      -1.298       0.022
# savings[T.No savings]                           -0.8702      0.281     -3.102      0.002      -1.420      -0.320
# ================================================================================================================
# AIC: 718.0219662391758, BIC: 772.6349302596966, AUC: 0.7833
#
# Best model with 5 variables:
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:        presence_unpaid   No. Observations:                  700
# Model:                            GLM   Df Residuals:                      690
# Model Family:                Binomial   Df Model:                            9
# Link Function:                  Logit   Scale:                          1.0000
# Method:                          IRLS   Log-Likelihood:                -353.32
# Date:                Sun, 09 Feb 2025   Deviance:                       706.64
# Time:                        11:57:36   Pearson chi2:                     683.
# No. Iterations:                     5   Pseudo R-squ. (CS):             0.1873
# Covariance Type:            nonrobust
# ================================================================================================================
#                                                    coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------------------
# Intercept                                       -0.5353      0.523     -1.023      0.306      -1.561       0.490
# accounts[T.CC > 200 euros]                      -0.9806      0.393     -2.493      0.013      -1.752      -0.210
# accounts[T.CC [0-200 euros]]                    -0.4234      0.218     -1.939      0.053      -0.851       0.005
# accounts[T.No account]                          -2.1595      0.254     -8.496      0.000      -2.658      -1.661
# duration_credit[T.[15.0, 36.0)]                  0.5241      0.212      2.469      0.014       0.108       0.940
# duration_credit[T.[36.0, inf)]                   1.2465      0.265      4.708      0.000       0.728       1.765
# other_credits[T.No external credit]             -0.7685      0.221     -3.474      0.001      -1.202      -0.335
# family_status[T.Male divorced/separated]         0.3718      0.392      0.949      0.342      -0.396       1.139
# family_status[T.Male single/married/widowed]    -0.6194      0.202     -3.059      0.002      -1.016      -0.223
# guarantees[T.Without guarantor]                  1.0389      0.464      2.241      0.025       0.130       1.948
# ================================================================================================================
# AIC: 726.644237950761, BIC: 772.155041301195, AUC: 0.7701
#
# Best model with 4 variables:
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:        presence_unpaid   No. Observations:                  700
# Model:                            GLM   Df Residuals:                      691
# Model Family:                Binomial   Df Model:                            8
# Link Function:                  Logit   Scale:                          1.0000
# Method:                          IRLS   Log-Likelihood:                -356.16
# Date:                Sun, 09 Feb 2025   Deviance:                       712.32
# Time:                        11:57:36   Pearson chi2:                     690.
# No. Iterations:                     5   Pseudo R-squ. (CS):             0.1806
# Covariance Type:            nonrobust
# ================================================================================================================
#                                                    coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------------------
# Intercept                                        0.4105      0.304      1.350      0.177      -0.185       1.006
# accounts[T.CC > 200 euros]                      -0.9228      0.392     -2.354      0.019      -1.691      -0.155
# accounts[T.CC [0-200 euros]]                    -0.4151      0.217     -1.915      0.056      -0.840       0.010
# accounts[T.No account]                          -2.0916      0.252     -8.311      0.000      -2.585      -1.598
# duration_credit[T.[15.0, 36.0)]                  0.5318      0.211      2.519      0.012       0.118       0.946
# duration_credit[T.[36.0, inf)]                   1.2392      0.263      4.716      0.000       0.724       1.754
# other_credits[T.No external credit]             -0.7427      0.220     -3.383      0.001      -1.173      -0.312
# family_status[T.Male divorced/separated]         0.4160      0.390      1.068      0.286      -0.348       1.180
# family_status[T.Male single/married/widowed]    -0.6278      0.202     -3.113      0.002      -1.023      -0.233
# ================================================================================================================
# AIC: 730.3241107228237, BIC: 771.2838337382143, AUC: 0.7670
# Reached the model with the smallest BIC. Stopping summary display.

# %% [markdown]
# Finally, the selection process stops at the smallest BIC (771.28) and we obtain a model with the variables 'accounts', 'duration_credit' and 'other_credit' and 'family_status'
#
#
# The model has a deviance equal to 712.32, a AIC criterion equal to 730.32 and so a BIC criterion equal to 771.28.

# %%
from sklearn.metrics import roc_auc_score

selected_variables = ['accounts', 'duration_credit', 'other_credits', 'family_status']

X_train = train[selected_variables]
X_test = test[selected_variables]

train['predicted_prob'] = model.predict(X_train)
test['predicted_prob'] = model.predict(X_test)

auc_train = roc_auc_score(train['presence_unpaid'], train['predicted_prob'])
auc_test = roc_auc_score(test['presence_unpaid'], test['predicted_prob'])

print(f'AUC on the train sample : {auc_train}')
print(f'AUC on the test sample : {auc_test}')
# Out:
# AUC on the train sample : 0.7670174718574109
# AUC on the test sample : 0.7394439799331103

# %% [markdown]
# We found 0.767 in learning and 0.739 in testing for this model obtained on the basis of the BIC criterion. This is not a very good result, both because of the low value in the test, and because of its significant deviation from the training.
#
# As the model selected is very simple, with just 4 variables, we can look for a more complex model, substituting the AIC criterion for the BIC. We therefore set k=2.

# %%
import statsmodels.api as sm
import statsmodels.formula.api as smf
import pandas as pd
from sklearn.metrics import roc_auc_score
from itertools import combinations


predictors = train.columns.difference(['presence_unpaid']).tolist()
predictors_in_model = []
best_aic = float('inf')
best_bic = float('inf')

best_models = {}

while len(predictors) > 1:
    changed = False
    best_combination = None
    best_aic_in_iteration = float('inf')
    
    for combo in combinations(predictors, 2):
        trial_predictors = predictors_in_model + list(combo)
        trial_formula = 'presence_unpaid ~ ' + ' + '.join(trial_predictors)
        trial_model = smf.glm(formula=trial_formula, data=train, family=sm.families.Binomial()).fit()
        trial_aic = trial_model.aic
        
        if trial_aic < best_aic_in_iteration:
            best_aic_in_iteration = trial_aic
            best_combination = combo
            best_model = trial_model
            changed = True

    if changed and best_combination:
        for predictor in best_combination:
            predictors_in_model.append(predictor)
            predictors.remove(predictor)
        best_aic = best_aic_in_iteration
        
        y_pred_prob = best_model.predict(train)
        auc = roc_auc_score(train['presence_unpaid'], y_pred_prob)
        
        best_models[len(predictors_in_model)] = (best_aic, auc, best_model)
    else:
        print("No further improvement in AIC. Stopping selection process.")
        break

min_aic_key = min(best_models, key=lambda k: best_models[k][0])

for num_vars in sorted(best_models.keys(), reverse=True):
    aic, auc, model = best_models[num_vars]
    print(f"\nBest model with {num_vars} variables:")
    print(model.summary())
    print(f"AIC: {aic}, AUC: {auc:.4f}")
    
    if num_vars == min_aic_key:
        print("Reached the model with the smallest AIC. Stopping summary display.")
        break
# Out:
# Best model with 20 variables:
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:        presence_unpaid   No. Observations:                  700
# Model:                            GLM   Df Residuals:                      660
# Model Family:                Binomial   Df Model:                           39
# Link Function:                  Logit   Scale:                          1.0000
# Method:                          IRLS   Log-Likelihood:                -325.41
# Date:                Sun, 09 Feb 2025   Deviance:                       650.82
# Time:                        11:57:53   Pearson chi2:                     657.
# No. Iterations:                     6   Pseudo R-squ. (CS):             0.2496
# Covariance Type:            nonrobust
# ================================================================================================================
#                                                    coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------------------
# Intercept                                        0.2980      2.378      0.125      0.900      -4.363       4.959
# savings[T.> 500 euros]                          -0.6194      0.361     -1.717      0.086      -1.326       0.088
# savings[T.No savings]                           -0.9565      0.302     -3.167      0.002      -1.548      -0.365
# guarantees[T.Without guarantor]                  0.9193      0.489      1.880      0.060      -0.039       1.878
# history_credit[T.A31]                           -0.0141      0.669     -0.021      0.983      -1.325       1.297
# history_credit[T.A32]                           -0.4526      0.563     -0.804      0.421      -1.556       0.651
# history_credit[T.A33]                           -0.8983      0.597     -1.504      0.133      -2.069       0.272
# history_credit[T.A34]                           -1.3119      0.564     -2.327      0.020      -2.417      -0.207
# amount_credit[T.[4000.0, inf)]                   0.5638      0.294      1.919      0.055      -0.012       1.140
# employment_old[T.between 1 and 4 years]          0.0650      0.267      0.243      0.808      -0.459       0.589
# employment_old[T.for at least 4 years]          -0.2724      0.275     -0.989      0.323      -0.812       0.267
# home_status[T.owner]                            -0.1608      0.270     -0.596      0.551      -0.690       0.368
# age[T.[25.0, inf)]                              -0.2871      0.297     -0.967      0.334      -0.869       0.295
# telephone[T.A192]                               -0.2175      0.227     -0.958      0.338      -0.662       0.227
# object_credit[T.Education]                      -0.2534      1.265     -0.200      0.841      -2.732       2.225
# object_credit[T.Interior]                        0.2025      0.388      0.522      0.602      -0.559       0.964
# object_credit[T.New car]                         0.5926      0.384      1.542      0.123      -0.161       1.346
# object_credit[T.Other]                          -0.7636      0.899     -0.850      0.396      -2.525       0.998
# object_credit[T.Studies]                         0.6163      0.527      1.170      0.242      -0.416       1.649
# object_credit[T.Used car]                       -0.6020      0.515     -1.170      0.242      -1.611       0.407
# object_credit[T.Video-HIFI]                      0.0445      0.393      0.113      0.910      -0.726       0.815
# family_status[T.Male divorced/separated]         0.8302      0.523      1.587      0.113      -0.195       1.856
# family_status[T.Male single/married/widowed]    -0.8350      0.478     -1.746      0.081      -1.772       0.102
# other_credits[T.No external credit]             -1.0104      0.544     -1.856      0.063      -2.078       0.057
# accounts[T.CC > 200 euros]                      -1.1082      0.795     -1.394      0.163      -2.666       0.450
# accounts[T.CC [0-200 euros]]                    -0.3892      0.394     -0.988      0.323      -1.161       0.383
# accounts[T.No account]                          -2.5005      1.310     -1.909      0.056      -5.068       0.067
# duration_credit[T.[15.0, 36.0)]                  0.8077      0.434      1.862      0.063      -0.043       1.658
# duration_credit[T.[36.0, inf)]                   1.6077      0.903      1.781      0.075      -0.162       3.377
# job_type[T.A172]                                -0.4927      0.709     -0.695      0.487      -1.883       0.897
# job_type[T.A173]                                -0.5368      0.694     -0.774      0.439      -1.896       0.823
# job_type[T.A174]                                -0.2197      0.732     -0.300      0.764      -1.655       1.216
# property[T.Non-property]                        -0.1875      0.359     -0.522      0.601      -0.891       0.516
# property[T.Not real estate]                      0.1229      0.377      0.326      0.745      -0.617       0.863
# property[T.Property]                            -0.1704      0.393     -0.433      0.665      -0.941       0.600
# predicted_prob                                  -1.9117      3.338     -0.573      0.567      -8.453       4.630
# effort_rate                                      0.2593      0.097      2.674      0.007       0.069       0.449
# nb_credits                                       0.3883      0.221      1.753      0.080      -0.046       0.822
# nb_of_dependants                                 0.2448      0.282      0.868      0.385      -0.308       0.797
# home_old                                         0.0445      0.097      0.457      0.647      -0.146       0.235
# ================================================================================================================
# AIC: 730.8204340800539, AUC: 0.8146
#
# Best model with 18 variables:
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:        presence_unpaid   No. Observations:                  700
# Model:                            GLM   Df Residuals:                      666
# Model Family:                Binomial   Df Model:                           33
# Link Function:                  Logit   Scale:                          1.0000
# Method:                          IRLS   Log-Likelihood:                -326.87
# Date:                Sun, 09 Feb 2025   Deviance:                       653.75
# Time:                        11:57:53   Pearson chi2:                     659.
# No. Iterations:                     6   Pseudo R-squ. (CS):             0.2464
# Covariance Type:            nonrobust
# ================================================================================================================
#                                                    coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------------------
# Intercept                                       -0.2978      2.221     -0.134      0.893      -4.651       4.056
# savings[T.> 500 euros]                          -0.6535      0.359     -1.822      0.069      -1.357       0.050
# savings[T.No savings]                           -0.9237      0.298     -3.102      0.002      -1.507      -0.340
# guarantees[T.Without guarantor]                  0.9066      0.478      1.895      0.058      -0.031       1.844
# history_credit[T.A31]                            0.0517      0.664      0.078      0.938      -1.251       1.354
# history_credit[T.A32]                           -0.4037      0.560     -0.720      0.471      -1.502       0.695
# history_credit[T.A33]                           -0.8344      0.592     -1.409      0.159      -1.995       0.326
# history_credit[T.A34]                           -1.2605      0.559     -2.256      0.024      -2.356      -0.165
# amount_credit[T.[4000.0, inf)]                   0.6371      0.284      2.245      0.025       0.081       1.193
# employment_old[T.between 1 and 4 years]         -0.0561      0.255     -0.220      0.826      -0.555       0.443
# employment_old[T.for at least 4 years]          -0.3611      0.264     -1.367      0.172      -0.879       0.157
# home_status[T.owner]                            -0.1992      0.237     -0.842      0.400      -0.663       0.264
# age[T.[25.0, inf)]                              -0.2410      0.288     -0.837      0.403      -0.805       0.323
# telephone[T.A192]                               -0.1480      0.214     -0.693      0.488      -0.567       0.271
# object_credit[T.Education]                      -0.2486      1.262     -0.197      0.844      -2.723       2.226
# object_credit[T.Interior]                        0.2351      0.385      0.610      0.542      -0.520       0.990
# object_credit[T.New car]                         0.6209      0.382      1.623      0.104      -0.129       1.370
# object_credit[T.Other]                          -0.6183      0.873     -0.708      0.479      -2.329       1.093
# object_credit[T.Studies]                         0.6519      0.513      1.270      0.204      -0.354       1.658
# object_credit[T.Used car]                       -0.5524      0.506     -1.093      0.275      -1.543       0.439
# object_credit[T.Video-HIFI]                      0.0216      0.388      0.056      0.956      -0.739       0.782
# family_status[T.Male divorced/separated]         0.7995      0.518      1.544      0.123      -0.215       1.814
# family_status[T.Male single/married/widowed]    -0.8140      0.473     -1.722      0.085      -1.740       0.112
# other_credits[T.No external credit]             -0.9892      0.541     -1.827      0.068      -2.050       0.072
# accounts[T.CC > 200 euros]                      -1.0920      0.786     -1.389      0.165      -2.633       0.449
# accounts[T.CC [0-200 euros]]                    -0.3954      0.390     -1.013      0.311      -1.160       0.370
# accounts[T.No account]                          -2.4892      1.299     -1.916      0.055      -5.036       0.057
# duration_credit[T.[15.0, 36.0)]                  0.7573      0.426      1.780      0.075      -0.077       1.591
# duration_credit[T.[36.0, inf)]                   1.5350      0.893      1.719      0.086      -0.215       3.285
# predicted_prob                                  -1.8655      3.312     -0.563      0.573      -8.356       4.625
# effort_rate                                      0.2710      0.095      2.840      0.005       0.084       0.458
# nb_credits                                       0.3957      0.220      1.799      0.072      -0.035       0.827
# nb_of_dependants                                 0.2161      0.276      0.783      0.433      -0.325       0.757
# home_old                                         0.0434      0.097      0.449      0.653      -0.146       0.233
# ================================================================================================================
# AIC: 721.748785421006, AUC: 0.8128
#
# Best model with 16 variables:
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:        presence_unpaid   No. Observations:                  700
# Model:                            GLM   Df Residuals:                      671
# Model Family:                Binomial   Df Model:                           28
# Link Function:                  Logit   Scale:                          1.0000
# Method:                          IRLS   Log-Likelihood:                -329.67
# Date:                Sun, 09 Feb 2025   Deviance:                       659.33
# Time:                        11:57:53   Pearson chi2:                     652.
# No. Iterations:                     5   Pseudo R-squ. (CS):             0.2404
# Covariance Type:            nonrobust
# ================================================================================================================
#                                                    coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------------------
# Intercept                                       -3.8305      1.086     -3.528      0.000      -5.959      -1.702
# savings[T.> 500 euros]                          -0.6248      0.356     -1.754      0.079      -1.323       0.073
# savings[T.No savings]                           -0.9159      0.296     -3.095      0.002      -1.496      -0.336
# guarantees[T.Without guarantor]                  0.9283      0.484      1.916      0.055      -0.021       1.878
# history_credit[T.A31]                            0.0609      0.660      0.092      0.927      -1.234       1.355
# history_credit[T.A32]                           -0.3786      0.552     -0.686      0.493      -1.461       0.704
# history_credit[T.A33]                           -0.7689      0.584     -1.318      0.188      -1.913       0.375
# history_credit[T.A34]                           -1.2045      0.551     -2.185      0.029      -2.285      -0.124
# amount_credit[T.[4000.0, inf)]                   0.6404      0.258      2.480      0.013       0.134       1.147
# employment_old[T.between 1 and 4 years]         -0.0859      0.252     -0.341      0.733      -0.580       0.408
# employment_old[T.for at least 4 years]          -0.4241      0.262     -1.616      0.106      -0.939       0.090
# home_status[T.owner]                            -0.1988      0.236     -0.844      0.399      -0.660       0.263
# age[T.[25.0, inf)]                              -0.2517      0.290     -0.868      0.385      -0.820       0.317
# telephone[T.A192]                               -0.1493      0.213     -0.700      0.484      -0.567       0.269
# object_credit[T.Education]                      -0.3795      1.230     -0.308      0.758      -2.791       2.032
# object_credit[T.Interior]                        0.1957      0.381      0.513      0.608      -0.552       0.943
# object_credit[T.New car]                         0.6089      0.377      1.613      0.107      -0.131       1.349
# object_credit[T.Other]                          -0.6643      0.877     -0.757      0.449      -2.383       1.055
# object_credit[T.Studies]                         0.6013      0.509      1.181      0.238      -0.396       1.599
# object_credit[T.Used car]                       -0.5655      0.507     -1.115      0.265      -1.560       0.429
# object_credit[T.Video-HIFI]                     -0.0077      0.387     -0.020      0.984      -0.767       0.752
# family_status[T.Male divorced/separated]         0.2536      0.442      0.573      0.566      -0.613       1.121
# family_status[T.Male single/married/widowed]    -0.0304      0.234     -0.130      0.897      -0.489       0.428
# other_credits[T.No external credit]             -0.0654      0.253     -0.258      0.796      -0.562       0.431
# predicted_prob                                   4.5127      0.617      7.312      0.000       3.303       5.722
# effort_rate                                      0.2796      0.094      2.975      0.003       0.095       0.464
# nb_credits                                       0.3762      0.215      1.746      0.081      -0.046       0.798
# nb_of_dependants                                 0.2026      0.272      0.744      0.457      -0.331       0.737
# home_old                                         0.0362      0.095      0.379      0.704      -0.151       0.223
# ================================================================================================================
# AIC: 717.3335425213329, AUC: 0.8106
#
# Best model with 14 variables:
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:        presence_unpaid   No. Observations:                  700
# Model:                            GLM   Df Residuals:                      674
# Model Family:                Binomial   Df Model:                           25
# Link Function:                  Logit   Scale:                          1.0000
# Method:                          IRLS   Log-Likelihood:                -329.89
# Date:                Sun, 09 Feb 2025   Deviance:                       659.78
# Time:                        11:57:53   Pearson chi2:                     652.
# No. Iterations:                     5   Pseudo R-squ. (CS):             0.2399
# Covariance Type:            nonrobust
# ===========================================================================================================
#                                               coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------------
# Intercept                                  -3.9149      1.045     -3.747      0.000      -5.963      -1.867
# savings[T.> 500 euros]                     -0.6151      0.356     -1.726      0.084      -1.314       0.083
# savings[T.No savings]                      -0.9117      0.296     -3.084      0.002      -1.491      -0.332
# guarantees[T.Without guarantor]             0.9539      0.483      1.975      0.048       0.007       1.901
# history_credit[T.A31]                       0.0802      0.658      0.122      0.903      -1.209       1.370
# history_credit[T.A32]                      -0.3660      0.552     -0.663      0.508      -1.448       0.716
# history_credit[T.A33]                      -0.7514      0.582     -1.291      0.197      -1.892       0.389
# history_credit[T.A34]                      -1.1769      0.550     -2.141      0.032      -2.254      -0.099
# amount_credit[T.[4000.0, inf)]              0.6210      0.255      2.436      0.015       0.121       1.121
# employment_old[T.between 1 and 4 years]    -0.0840      0.251     -0.335      0.738      -0.576       0.408
# employment_old[T.for at least 4 years]     -0.4219      0.261     -1.619      0.106      -0.933       0.089
# home_status[T.owner]                       -0.1964      0.234     -0.839      0.401      -0.655       0.262
# age[T.[25.0, inf)]                         -0.2308      0.287     -0.805      0.421      -0.793       0.331
# telephone[T.A192]                          -0.1462      0.213     -0.686      0.493      -0.564       0.272
# object_credit[T.Education]                 -0.3968      1.230     -0.323      0.747      -2.808       2.014
# object_credit[T.Interior]                   0.1825      0.379      0.481      0.630      -0.560       0.925
# object_credit[T.New car]                    0.5852      0.375      1.561      0.118      -0.149       1.320
# object_credit[T.Other]                     -0.6881      0.868     -0.793      0.428      -2.389       1.013
# object_credit[T.Studies]                    0.5808      0.506      1.147      0.251      -0.412       1.573
# object_credit[T.Used car]                  -0.5970      0.505     -1.183      0.237      -1.586       0.392
# object_credit[T.Video-HIFI]                -0.0293      0.385     -0.076      0.939      -0.783       0.724
# predicted_prob                              4.6459      0.566      8.210      0.000       3.537       5.755
# effort_rate                                 0.2704      0.092      2.934      0.003       0.090       0.451
# nb_credits                                  0.3751      0.215      1.747      0.081      -0.046       0.796
# nb_of_dependants                            0.1896      0.267      0.711      0.477      -0.333       0.713
# home_old                                    0.0317      0.095      0.333      0.739      -0.155       0.218
# ===========================================================================================================
# AIC: 711.7833803147521, AUC: 0.8106
#
# Best model with 12 variables:
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:        presence_unpaid   No. Observations:                  700
# Model:                            GLM   Df Residuals:                      682
# Model Family:                Binomial   Df Model:                           17
# Link Function:                  Logit   Scale:                          1.0000
# Method:                          IRLS   Log-Likelihood:                -336.12
# Date:                Sun, 09 Feb 2025   Deviance:                       672.24
# Time:                        11:57:53   Pearson chi2:                     654.
# No. Iterations:                     5   Pseudo R-squ. (CS):             0.2262
# Covariance Type:            nonrobust
# ===========================================================================================================
#                                               coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------------
# Intercept                                  -3.7885      0.978     -3.875      0.000      -5.705      -1.872
# savings[T.> 500 euros]                     -0.6182      0.351     -1.760      0.078      -1.307       0.070
# savings[T.No savings]                      -0.8970      0.290     -3.096      0.002      -1.465      -0.329
# guarantees[T.Without guarantor]             1.0599      0.480      2.209      0.027       0.120       2.000
# history_credit[T.A31]                      -0.0127      0.643     -0.020      0.984      -1.272       1.247
# history_credit[T.A32]                      -0.4148      0.537     -0.773      0.440      -1.467       0.637
# history_credit[T.A33]                      -0.7685      0.571     -1.345      0.179      -1.889       0.352
# history_credit[T.A34]                      -1.1411      0.532     -2.145      0.032      -2.184      -0.098
# amount_credit[T.[4000.0, inf)]              0.4195      0.239      1.755      0.079      -0.049       0.888
# employment_old[T.between 1 and 4 years]    -0.1085      0.247     -0.440      0.660      -0.592       0.375
# employment_old[T.for at least 4 years]     -0.4435      0.249     -1.780      0.075      -0.932       0.045
# home_status[T.owner]                       -0.2055      0.214     -0.960      0.337      -0.625       0.214
# age[T.[25.0, inf)]                         -0.2218      0.278     -0.797      0.425      -0.767       0.323
# telephone[T.A192]                          -0.1388      0.206     -0.673      0.501      -0.543       0.265
# predicted_prob                              4.6826      0.556      8.426      0.000       3.593       5.772
# effort_rate                                 0.2663      0.090      2.954      0.003       0.090       0.443
# nb_credits                                  0.3933      0.213      1.846      0.065      -0.024       0.811
# nb_of_dependants                            0.2601      0.264      0.984      0.325      -0.258       0.778
# ===========================================================================================================
# AIC: 708.241841073953, AUC: 0.8024
#
# Best model with 10 variables:
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:        presence_unpaid   No. Observations:                  700
# Model:                            GLM   Df Residuals:                      684
# Model Family:                Binomial   Df Model:                           15
# Link Function:                  Logit   Scale:                          1.0000
# Method:                          IRLS   Log-Likelihood:                -336.75
# Date:                Sun, 09 Feb 2025   Deviance:                       673.50
# Time:                        11:57:53   Pearson chi2:                     655.
# No. Iterations:                     5   Pseudo R-squ. (CS):             0.2248
# Covariance Type:            nonrobust
# ===========================================================================================================
#                                               coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------------
# Intercept                                  -3.9109      0.964     -4.057      0.000      -5.800      -2.021
# savings[T.> 500 euros]                     -0.6231      0.350     -1.780      0.075      -1.309       0.063
# savings[T.No savings]                      -0.9249      0.289     -3.200      0.001      -1.491      -0.358
# guarantees[T.Without guarantor]             1.0448      0.479      2.181      0.029       0.106       1.984
# history_credit[T.A31]                      -0.0128      0.641     -0.020      0.984      -1.269       1.244
# history_credit[T.A32]                      -0.3968      0.534     -0.744      0.457      -1.443       0.649
# history_credit[T.A33]                      -0.7821      0.570     -1.372      0.170      -1.900       0.335
# history_credit[T.A34]                      -1.1309      0.531     -2.131      0.033      -2.171      -0.091
# amount_credit[T.[4000.0, inf)]              0.3740      0.234      1.598      0.110      -0.085       0.833
# employment_old[T.between 1 and 4 years]    -0.1069      0.247     -0.433      0.665      -0.590       0.377
# employment_old[T.for at least 4 years]     -0.4832      0.246     -1.961      0.050      -0.966      -0.000
# home_status[T.owner]                       -0.2379      0.208     -1.144      0.253      -0.645       0.170
# predicted_prob                              4.7033      0.554      8.494      0.000       3.618       5.789
# effort_rate                                 0.2596      0.090      2.889      0.004       0.084       0.436
# nb_credits                                  0.3807      0.212      1.794      0.073      -0.035       0.797
# nb_of_dependants                            0.2350      0.261      0.899      0.369      -0.277       0.747
# ===========================================================================================================
# AIC: 705.5049845302298, AUC: 0.8016
#
# Best model with 8 variables:
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:        presence_unpaid   No. Observations:                  700
# Model:                            GLM   Df Residuals:                      686
# Model Family:                Binomial   Df Model:                           13
# Link Function:                  Logit   Scale:                          1.0000
# Method:                          IRLS   Log-Likelihood:                -337.80
# Date:                Sun, 09 Feb 2025   Deviance:                       675.60
# Time:                        11:57:53   Pearson chi2:                     663.
# No. Iterations:                     5   Pseudo R-squ. (CS):             0.2225
# Covariance Type:            nonrobust
# ===========================================================================================================
#                                               coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------------
# Intercept                                  -3.8191      0.901     -4.237      0.000      -5.586      -2.052
# savings[T.> 500 euros]                     -0.6394      0.349     -1.835      0.067      -1.323       0.044
# savings[T.No savings]                      -0.9195      0.288     -3.191      0.001      -1.484      -0.355
# guarantees[T.Without guarantor]             1.0474      0.476      2.203      0.028       0.115       1.980
# history_credit[T.A31]                       0.0377      0.639      0.059      0.953      -1.214       1.290
# history_credit[T.A32]                      -0.3790      0.532     -0.712      0.476      -1.422       0.664
# history_credit[T.A33]                      -0.7837      0.569     -1.378      0.168      -1.899       0.331
# history_credit[T.A34]                      -1.1203      0.529     -2.118      0.034      -2.157      -0.084
# amount_credit[T.[4000.0, inf)]              0.3775      0.233      1.619      0.106      -0.080       0.835
# employment_old[T.between 1 and 4 years]    -0.1166      0.246     -0.473      0.636      -0.599       0.366
# employment_old[T.for at least 4 years]     -0.4725      0.245     -1.928      0.054      -0.953       0.008
# predicted_prob                              4.7272      0.547      8.635      0.000       3.654       5.800
# effort_rate                                 0.2495      0.089      2.788      0.005       0.074       0.425
# nb_credits                                  0.3946      0.212      1.863      0.062      -0.020       0.810
# ===========================================================================================================
# AIC: 703.5956994335256, AUC: 0.8004
# Reached the model with the smallest AIC. Stopping summary display.

# %% [markdown]
# We can see that the lower penalty of the AIC criterion has enabled us to select a much larger number of predictors: the model selected has increased from 4 to 10 variables.

# %%
from sklearn.metrics import roc_auc_score

selected_variables = ['accounts', 'duration_credit', 'family_status', 'other_credits','guarantees', 'savings', 'history_credit', 'amount_credit', 'effort_rate', 'nb_credits']

X_train = train[selected_variables]
X_test = test[selected_variables]

train['predicted_prob'] = model.predict(X_train)
test['predicted_prob'] = model.predict(X_test)

auc_train = roc_auc_score(train['presence_unpaid'], train['predicted_prob'])
auc_test = roc_auc_score(test['presence_unpaid'], test['predicted_prob'])

print(f'AUC on the train sample : {auc_train}')
print(f'AUC on the test sample : {auc_test}')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# File /var/data/python/lib/python3.12/site-packages/patsy/compat.py:40, in call_and_wrap_exc(msg, origin, f, *args, **kwargs)
#      39 try:
# ---> 40     return f(*args, **kwargs)
#      41 except Exception as e:
#
# File /var/data/python/lib/python3.12/site-packages/patsy/eval.py:179, in EvalEnvironment.eval(self, expr, source_name, inner_namespace)
#     178 code = compile(expr, source_name, "eval", self.flags, False)
# --> 179 return eval(code, {}, VarLookupDict([inner_namespace] + self._namespaces))
#
# File <string>:1
#
# NameError: name 'predicted_prob' is not defined
#
# The above exception was the direct cause of the following exception:
#
# PatsyError                                Traceback (most recent call last)
# File /var/data/python/lib/python3.12/site-packages/statsmodels/base/model.py:1102, in Results._transform_predict_exog(self, exog, transform)
#    1101 try:
# -> 1102     exog = dmatrix(design_info, exog, return_type="dataframe")
#    1103 except Exception as exc:
#
# File /var/data/python/lib/python3.12/site-packages/patsy/highlevel.py:296, in dmatrix(formula_like, data, eval_env, NA_action, return_type)
#     295 eval_env = EvalEnvironment.capture(eval_env, reference=1)
# --> 296 (lhs, rhs) = _do_highlevel_design(
#     297     formula_like, data, eval_env, NA_action, return_type
#     298 )
#     299 if lhs.shape[1] != 0:
#
# File /var/data/python/lib/python3.12/site-packages/patsy/highlevel.py:168, in _do_highlevel_design(formula_like, data, eval_env, NA_action, return_type)
#     167 if design_infos is not None:
# --> 168     return build_design_matrices(
#     169         design_infos, data, NA_action=NA_action, return_type=return_type
#     170     )
#     171 else:
#     172     # No builders, but maybe we can still get matrices
#
# File /var/data/python/lib/python3.12/site-packages/patsy/build.py:954, in build_design_matrices(design_infos, data, NA_action, return_type, dtype)
#     953 if factor_info not in factor_info_to_values:
# --> 954     value, is_NA = _eval_factor(factor_info, data, NA_action)
#     955     factor_info_to_isNAs[factor_info] = is_NA
#
# File /var/data/python/lib/python3.12/site-packages/patsy/build.py:68, in _eval_factor(factor_info, data, NA_action)
#      67 factor = factor_info.factor
# ---> 68 result = factor.eval(factor_info.state, data)
#      69 # Returns either a 2d ndarray, or a DataFrame, plus is_NA mask
#
# File /var/data/python/lib/python3.12/site-packages/patsy/eval.py:599, in EvalFactor.eval(self, memorize_state, data)
#     598 def eval(self, memorize_state, data):
# --> 599     return self._eval(memorize_state["eval_code"], memorize_state, data)
#
# File /var/data/python/lib/python3.12/site-packages/patsy/eval.py:582, in EvalFactor._eval(self, code, memorize_state, data)
#     581 inner_namespace = VarLookupDict([data, memorize_state["transforms"]])
# --> 582 return call_and_wrap_exc(
#     583     "Error evaluating factor",
#     584     self,
#     585     memorize_state["eval_env"].eval,
#     586     code,
#     587     inner_namespace=inner_namespace,
#     588 )
#
# File /var/data/python/lib/python3.12/site-packages/patsy/compat.py:43, in call_and_wrap_exc(msg, origin, f, *args, **kwargs)
#      42 new_exc = PatsyError("%s: %s: %s" % (msg, e.__class__.__name__, e), origin)
# ---> 43 raise new_exc from e
#
# PatsyError: Error evaluating factor: NameError: name 'predicted_prob' is not defined
#     presence_unpaid ~ predicted_prob + savings + effort_rate + guarantees + history_credit + nb_credits + amount_credit + employment_old
#                       ^^^^^^^^^^^^^^
#
# During handling of the above exception, another exception occurred:
#
# PatsyError                                Traceback (most recent call last)
# Cell In[9], line 8
#       5 X_train = train[selected_variables]
#       6 X_test = test[selected_variables]
# ----> 8 train['predicted_prob'] = model.predict(X_train)
#       9 test['predicted_prob'] = model.predict(X_test)
#      11 auc_train = roc_auc_score(train['presence_unpaid'], train['predicted_prob'])
#
# File /var/data/python/lib/python3.12/site-packages/statsmodels/base/model.py:1171, in Results.predict(self, exog, transform, *args, **kwargs)
#    1126 def predict(self, exog=None, transform=True, *args, **kwargs):
#    1127     """
#    1128     Call self.model.predict with self.params as the first argument.
#    1129
#    (...)
#    1169     returned prediction.
#    1170     """
# -> 1171     exog, exog_index = self._transform_predict_exog(exog,
#    1172                                                     transform=transform)
#    1174     predict_results = self.model.predict(self.params, exog, *args,
#    1175                                          **kwargs)
#    1177     if exog_index is not None and not hasattr(predict_results,
#    1178                                               'predicted_values'):
#
# File /var/data/python/lib/python3.12/site-packages/statsmodels/base/model.py:1109, in Results._transform_predict_exog(self, exog, transform)
#    1103 except Exception as exc:
#    1104     msg = ('predict requires that you use a DataFrame when '
#    1105            'predicting from a model\nthat was created using the '
#    1106            'formula api.'
#    1107            '\n\nThe original error message returned by patsy is:\n'
#    1108            '{}'.format(str(str(exc))))
# -> 1109     raise exc.__class__(msg)
#    1110 if orig_exog_len > len(exog) and not is_dict:
#    1111     if exog_index is None:
#
# PatsyError: predict requires that you use a DataFrame when predicting from a model
# that was created using the formula api.
#
# The original error message returned by patsy is:
# Error evaluating factor: NameError: name 'predicted_prob' is not defined
#     presence_unpaid ~ predicted_prob + savings + effort_rate + guarantees + history_credit + nb_credits + amount_credit + employment_old
#                       ^^^^^^^^^^^^^^

# %% [markdown]
# We measured the area under the ROC curve of the model selected using the AIC criterion: 0.798 in learning and 0.799 in testing.
# The discriminating power in test has increased slightly, the new model don't have over-learned even more than its predecessor, the two Area Under Curve are pretty the same.
#
# A step-by-step selection carried out completely automatically does not therefore provide sufficiently satisfactory results. We therefore need to analyse the model parameters in more detail.
#
# We note that a certain number of the model's coef are not significantly different from 0 and even have a p-value of their Wald stat that is sometimes too high, close to 1 for the 'history_credit'.
#
# A forward selection based on the AIC is re-launched by setting the maximum model from which the credit object has been excluded.

# %%
import statsmodels.api as sm
import statsmodels.formula.api as smf
import pandas as pd
from sklearn.metrics import roc_auc_score
from itertools import combinations


# Exclude the ‘history_credit’ variable
predictors = [p for p in train.columns.difference(['presence_unpaid']) if p != 'history_credit'] 
predictors_in_model = []
best_aic = float('inf')
best_bic = float('inf')

best_models = {}

while len(predictors) > 1:
    changed = False
    best_combination = None
    best_aic_in_iteration = float('inf')
    
    for combo in combinations(predictors, 2):
        trial_predictors = predictors_in_model + list(combo)
        trial_formula = 'presence_unpaid ~ ' + ' + '.join(trial_predictors)
        trial_model = smf.glm(formula=trial_formula, data=train, family=sm.families.Binomial()).fit()
        trial_aic = trial_model.aic
        
        if trial_aic < best_aic_in_iteration:
            best_aic_in_iteration = trial_aic
            best_combination = combo
            best_model = trial_model
            changed = True

    if changed and best_combination:
        for predictor in best_combination:
            predictors_in_model.append(predictor)
            predictors.remove(predictor)
        best_aic = best_aic_in_iteration
        
        y_pred_prob = best_model.predict(train)
        auc = roc_auc_score(train['presence_unpaid'], y_pred_prob)
        
        best_models[len(predictors_in_model)] = (best_aic, auc, best_model)
    else:
        print("No further improvement in AIC. Stopping selection process.")
        break

min_aic_key = min(best_models, key=lambda k: best_models[k][0])

for num_vars in sorted(best_models.keys(), reverse=True):
    aic, auc, model = best_models[num_vars]
    print(f"\nBest model with {num_vars} variables:")
    print(model.summary())
    print(f"AIC: {aic}, AUC: {auc:.4f}")
    
    if num_vars == min_aic_key:
        print("Reached the model with the smallest AIC. Stopping summary display.")
        break
# Out:
# Best model with 18 variables:
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:        presence_unpaid   No. Observations:                  700
# Model:                            GLM   Df Residuals:                      667
# Model Family:                Binomial   Df Model:                           32
# Link Function:                  Logit   Scale:                          1.0000
# Method:                          IRLS   Log-Likelihood:                -332.77
# Date:                Sun, 09 Feb 2025   Deviance:                       665.54
# Time:                        11:58:16   Pearson chi2:                     658.
# No. Iterations:                     6   Pseudo R-squ. (CS):             0.2336
# Covariance Type:            nonrobust
# ================================================================================================================
#                                                    coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------------------
# Intercept                                       -0.5348      2.178     -0.246      0.806      -4.803       3.733
# savings[T.> 500 euros]                          -0.6011      0.349     -1.720      0.085      -1.286       0.084
# savings[T.No savings]                           -0.8801      0.294     -2.997      0.003      -1.456      -0.305
# guarantees[T.Without guarantor]                  0.9853      0.490      2.010      0.044       0.025       1.946
# amount_credit[T.[4000.0, inf)]                   0.6026      0.282      2.140      0.032       0.051       1.154
# employment_old[T.between 1 and 4 years]          0.0150      0.255      0.059      0.953      -0.486       0.516
# employment_old[T.for at least 4 years]          -0.3710      0.261     -1.423      0.155      -0.882       0.140
# home_status[T.owner]                            -0.2409      0.262     -0.919      0.358      -0.755       0.273
# age[T.[25.0, inf)]                              -0.2550      0.288     -0.885      0.376      -0.820       0.310
# telephone[T.A192]                               -0.1345      0.210     -0.639      0.523      -0.547       0.278
# other_credits[T.No external credit]             -0.9529      0.531     -1.796      0.073      -1.993       0.087
# object_credit[T.Education]                      -0.1522      1.247     -0.122      0.903      -2.596       2.292
# object_credit[T.Interior]                        0.0559      0.373      0.150      0.881      -0.674       0.786
# object_credit[T.New car]                         0.4111      0.366      1.122      0.262      -0.307       1.129
# object_credit[T.Other]                          -0.7639      0.846     -0.903      0.367      -2.422       0.894
# object_credit[T.Studies]                         0.3349      0.507      0.660      0.509      -0.659       1.329
# object_credit[T.Used car]                       -0.7586      0.488     -1.555      0.120      -1.715       0.198
# object_credit[T.Video-HIFI]                     -0.0925      0.374     -0.247      0.805      -0.825       0.640
# duration_credit[T.[15.0, 36.0)]                  0.6550      0.422      1.553      0.121      -0.172       1.482
# duration_credit[T.[36.0, inf)]                   1.3331      0.881      1.513      0.130      -0.393       3.059
# family_status[T.Male divorced/separated]         0.5994      0.510      1.174      0.240      -0.401       1.600
# family_status[T.Male single/married/widowed]    -0.7260      0.468     -1.552      0.121      -1.643       0.191
# accounts[T.CC > 200 euros]                      -0.9729      0.777     -1.252      0.210      -2.496       0.550
# accounts[T.CC [0-200 euros]]                    -0.3405      0.384     -0.888      0.375      -1.092       0.411
# accounts[T.No account]                          -2.2329      1.278     -1.747      0.081      -4.738       0.272
# property[T.Non-property]                        -0.1775      0.350     -0.507      0.612      -0.864       0.509
# property[T.Not real estate]                      0.0711      0.369      0.193      0.847      -0.651       0.793
# property[T.Property]                            -0.2374      0.382     -0.622      0.534      -0.986       0.511
# predicted_prob                                  -0.9340      3.267     -0.286      0.775      -7.337       5.469
# effort_rate                                      0.2604      0.095      2.748      0.006       0.075       0.446
# nb_of_dependants                                 0.2547      0.273      0.934      0.350      -0.280       0.789
# nb_credits                                       0.0518      0.177      0.293      0.769      -0.294       0.398
# home_old                                         0.0020      0.095      0.021      0.983      -0.184       0.188
# ================================================================================================================
# AIC: 731.5376455724106, AUC: 0.8050
#
# Best model with 16 variables:
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:        presence_unpaid   No. Observations:                  700
# Model:                            GLM   Df Residuals:                      673
# Model Family:                Binomial   Df Model:                           26
# Link Function:                  Logit   Scale:                          1.0000
# Method:                          IRLS   Log-Likelihood:                -335.73
# Date:                Sun, 09 Feb 2025   Deviance:                       671.47
# Time:                        11:58:16   Pearson chi2:                     650.
# No. Iterations:                     5   Pseudo R-squ. (CS):             0.2271
# Covariance Type:            nonrobust
# ================================================================================================================
#                                                    coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------------------
# Intercept                                       -3.8431      0.939     -4.095      0.000      -5.683      -2.003
# savings[T.> 500 euros]                          -0.5969      0.346     -1.723      0.085      -1.276       0.082
# savings[T.No savings]                           -0.8613      0.292     -2.949      0.003      -1.434      -0.289
# guarantees[T.Without guarantor]                  0.9829      0.485      2.026      0.043       0.032       1.934
# amount_credit[T.[4000.0, inf)]                   0.6637      0.278      2.388      0.017       0.119       1.208
# employment_old[T.between 1 and 4 years]         -0.0511      0.251     -0.204      0.839      -0.543       0.440
# employment_old[T.for at least 4 years]          -0.4308      0.259     -1.666      0.096      -0.938       0.076
# home_status[T.owner]                            -0.2657      0.231     -1.149      0.250      -0.719       0.187
# age[T.[25.0, inf)]                              -0.2611      0.286     -0.914      0.361      -0.821       0.299
# telephone[T.A192]                               -0.1273      0.209     -0.608      0.543      -0.538       0.283
# other_credits[T.No external credit]             -0.1116      0.248     -0.450      0.653      -0.598       0.375
# object_credit[T.Education]                      -0.1852      1.220     -0.152      0.879      -2.577       2.206
# object_credit[T.Interior]                        0.0599      0.367      0.163      0.870      -0.660       0.780
# object_credit[T.New car]                         0.4373      0.364      1.202      0.229      -0.276       1.150
# object_credit[T.Other]                          -0.7841      0.838     -0.936      0.349      -2.426       0.858
# object_credit[T.Studies]                         0.4052      0.494      0.820      0.412      -0.563       1.374
# object_credit[T.Used car]                       -0.7462      0.484     -1.541      0.123      -1.695       0.203
# object_credit[T.Video-HIFI]                     -0.1244      0.370     -0.337      0.736      -0.849       0.600
# duration_credit[T.[15.0, 36.0)]                  0.0530      0.237      0.223      0.823      -0.412       0.518
# duration_credit[T.[36.0, inf)]                  -0.0904      0.363     -0.249      0.803      -0.802       0.621
# family_status[T.Male divorced/separated]         0.1028      0.436      0.236      0.814      -0.751       0.957
# family_status[T.Male single/married/widowed]     0.0015      0.233      0.006      0.995      -0.456       0.459
# predicted_prob                                   4.8371      0.673      7.189      0.000       3.518       6.156
# effort_rate                                      0.2753      0.094      2.943      0.003       0.092       0.459
# nb_of_dependants                                 0.2286      0.269      0.849      0.396      -0.299       0.756
# nb_credits                                       0.0353      0.174      0.203      0.839      -0.306       0.377
# home_old                                        -0.0027      0.095     -0.029      0.977      -0.188       0.182
# ================================================================================================================
# AIC: 725.4660612116995, AUC: 0.8026
#
# Best model with 14 variables:
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:        presence_unpaid   No. Observations:                  700
# Model:                            GLM   Df Residuals:                      677
# Model Family:                Binomial   Df Model:                           22
# Link Function:                  Logit   Scale:                          1.0000
# Method:                          IRLS   Log-Likelihood:                -335.89
# Date:                Sun, 09 Feb 2025   Deviance:                       671.78
# Time:                        11:58:16   Pearson chi2:                     651.
# No. Iterations:                     5   Pseudo R-squ. (CS):             0.2268
# Covariance Type:            nonrobust
# ===========================================================================================================
#                                               coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------------
# Intercept                                  -3.8145      0.925     -4.124      0.000      -5.627      -2.002
# savings[T.> 500 euros]                     -0.5933      0.346     -1.714      0.086      -1.271       0.085
# savings[T.No savings]                      -0.8645      0.291     -2.975      0.003      -1.434      -0.295
# guarantees[T.Without guarantor]             0.9987      0.484      2.064      0.039       0.050       1.947
# amount_credit[T.[4000.0, inf)]              0.6141      0.246      2.492      0.013       0.131       1.097
# employment_old[T.between 1 and 4 years]    -0.0619      0.248     -0.249      0.803      -0.549       0.425
# employment_old[T.for at least 4 years]     -0.4398      0.256     -1.716      0.086      -0.942       0.063
# home_status[T.owner]                       -0.2602      0.230     -1.129      0.259      -0.712       0.192
# age[T.[25.0, inf)]                         -0.2557      0.282     -0.907      0.364      -0.808       0.297
# telephone[T.A192]                          -0.1221      0.209     -0.584      0.559      -0.532       0.288
# other_credits[T.No external credit]        -0.1159      0.241     -0.480      0.631      -0.589       0.357
# object_credit[T.Education]                 -0.2012      1.214     -0.166      0.868      -2.580       2.177
# object_credit[T.Interior]                   0.0712      0.364      0.196      0.845      -0.642       0.785
# object_credit[T.New car]                    0.4330      0.358      1.210      0.226      -0.268       1.134
# object_credit[T.Other]                     -0.8005      0.839     -0.954      0.340      -2.446       0.845
# object_credit[T.Studies]                    0.3816      0.488      0.782      0.434      -0.575       1.339
# object_credit[T.Used car]                  -0.7489      0.483     -1.552      0.121      -1.695       0.197
# object_credit[T.Video-HIFI]                -0.1328      0.367     -0.362      0.717      -0.852       0.586
# predicted_prob                              4.8280      0.576      8.376      0.000       3.698       5.958
# effort_rate                                 0.2707      0.091      2.971      0.003       0.092       0.449
# nb_of_dependants                            0.2189      0.263      0.831      0.406      -0.297       0.735
# nb_credits                                  0.0410      0.174      0.236      0.814      -0.300       0.382
# home_old                                -9.881e-06      0.094     -0.000      1.000      -0.184       0.184
# ===========================================================================================================
# AIC: 717.7840675124862, AUC: 0.8017
#
# Best model with 12 variables:
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:        presence_unpaid   No. Observations:                  700
# Model:                            GLM   Df Residuals:                      685
# Model Family:                Binomial   Df Model:                           14
# Link Function:                  Logit   Scale:                          1.0000
# Method:                          IRLS   Log-Likelihood:                -341.56
# Date:                Sun, 09 Feb 2025   Deviance:                       683.11
# Time:                        11:58:16   Pearson chi2:                     653.
# No. Iterations:                     5   Pseudo R-squ. (CS):             0.2141
# Covariance Type:            nonrobust
# ===========================================================================================================
#                                               coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------------
# Intercept                                  -4.0461      0.814     -4.972      0.000      -5.641      -2.451
# savings[T.> 500 euros]                     -0.5960      0.341     -1.746      0.081      -1.265       0.073
# savings[T.No savings]                      -0.8681      0.286     -3.039      0.002      -1.428      -0.308
# guarantees[T.Without guarantor]             1.0950      0.477      2.297      0.022       0.161       2.029
# amount_credit[T.[4000.0, inf)]              0.4145      0.231      1.793      0.073      -0.039       0.868
# employment_old[T.between 1 and 4 years]    -0.0895      0.244     -0.366      0.714      -0.568       0.390
# employment_old[T.for at least 4 years]     -0.4741      0.246     -1.929      0.054      -0.956       0.008
# home_status[T.owner]                       -0.2200      0.212     -1.039      0.299      -0.635       0.195
# age[T.[25.0, inf)]                         -0.2310      0.274     -0.844      0.399      -0.767       0.305
# telephone[T.A192]                          -0.1360      0.203     -0.671      0.502      -0.533       0.261
# other_credits[T.No external credit]        -0.0500      0.235     -0.213      0.832      -0.511       0.411
# predicted_prob                              4.9015      0.568      8.623      0.000       3.787       6.016
# effort_rate                                 0.2656      0.089      2.977      0.003       0.091       0.441
# nb_of_dependants                            0.2830      0.261      1.082      0.279      -0.229       0.795
# nb_credits                                  0.0971      0.171      0.569      0.569      -0.237       0.432
# ===========================================================================================================
# AIC: 713.1134704680262, AUC: 0.7943
#
# Best model with 10 variables:
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:        presence_unpaid   No. Observations:                  700
# Model:                            GLM   Df Residuals:                      687
# Model Family:                Binomial   Df Model:                           12
# Link Function:                  Logit   Scale:                          1.0000
# Method:                          IRLS   Log-Likelihood:                -341.75
# Date:                Sun, 09 Feb 2025   Deviance:                       683.50
# Time:                        11:58:16   Pearson chi2:                     658.
# No. Iterations:                     5   Pseudo R-squ. (CS):             0.2137
# Covariance Type:            nonrobust
# ===========================================================================================================
#                                               coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------------
# Intercept                                  -3.9898      0.732     -5.449      0.000      -5.425      -2.555
# savings[T.> 500 euros]                     -0.5942      0.340     -1.745      0.081      -1.262       0.073
# savings[T.No savings]                      -0.8782      0.285     -3.083      0.002      -1.437      -0.320
# guarantees[T.Without guarantor]             1.0994      0.476      2.311      0.021       0.167       2.032
# amount_credit[T.[4000.0, inf)]              0.4222      0.230      1.833      0.067      -0.029       0.874
# employment_old[T.between 1 and 4 years]    -0.0873      0.244     -0.358      0.721      -0.566       0.391
# employment_old[T.for at least 4 years]     -0.4600      0.245     -1.881      0.060      -0.939       0.019
# home_status[T.owner]                       -0.2140      0.211     -1.015      0.310      -0.627       0.199
# age[T.[25.0, inf)]                         -0.2151      0.272     -0.790      0.429      -0.749       0.318
# telephone[T.A192]                          -0.1321      0.203     -0.652      0.514      -0.529       0.265
# predicted_prob                              4.9053      0.542      9.049      0.000       3.843       5.968
# effort_rate                                 0.2631      0.089      2.956      0.003       0.089       0.437
# nb_of_dependants                            0.2973      0.260      1.142      0.253      -0.213       0.807
# ===========================================================================================================
# AIC: 709.5012340556269, AUC: 0.7942
#
# Best model with 8 variables:
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:        presence_unpaid   No. Observations:                  700
# Model:                            GLM   Df Residuals:                      689
# Model Family:                Binomial   Df Model:                           10
# Link Function:                  Logit   Scale:                          1.0000
# Method:                          IRLS   Log-Likelihood:                -342.36
# Date:                Sun, 09 Feb 2025   Deviance:                       684.72
# Time:                        11:58:16   Pearson chi2:                     659.
# No. Iterations:                     5   Pseudo R-squ. (CS):             0.2123
# Covariance Type:            nonrobust
# ===========================================================================================================
#                                               coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------------
# Intercept                                  -4.1119      0.724     -5.682      0.000      -5.530      -2.693
# savings[T.> 500 euros]                     -0.5983      0.339     -1.765      0.077      -1.263       0.066
# savings[T.No savings]                      -0.9030      0.284     -3.177      0.001      -1.460      -0.346
# guarantees[T.Without guarantor]             1.0828      0.476      2.275      0.023       0.150       2.016
# amount_credit[T.[4000.0, inf)]              0.3748      0.225      1.666      0.096      -0.066       0.816
# employment_old[T.between 1 and 4 years]    -0.0860      0.244     -0.352      0.725      -0.564       0.392
# employment_old[T.for at least 4 years]     -0.4991      0.242     -2.064      0.039      -0.973      -0.025
# home_status[T.owner]                       -0.2452      0.205     -1.196      0.232      -0.647       0.157
# predicted_prob                              4.9282      0.540      9.121      0.000       3.869       5.987
# effort_rate                                 0.2567      0.089      2.894      0.004       0.083       0.431
# nb_of_dependants                            0.2722      0.257      1.057      0.290      -0.232       0.777
# ===========================================================================================================
# AIC: 706.7163066713007, AUC: 0.7928
#
# Best model with 6 variables:
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:        presence_unpaid   No. Observations:                  700
# Model:                            GLM   Df Residuals:                      691
# Model Family:                Binomial   Df Model:                            8
# Link Function:                  Logit   Scale:                          1.0000
# Method:                          IRLS   Log-Likelihood:                -343.62
# Date:                Sun, 09 Feb 2025   Deviance:                       687.24
# Time:                        11:58:17   Pearson chi2:                     663.
# No. Iterations:                     5   Pseudo R-squ. (CS):             0.2095
# Covariance Type:            nonrobust
# ===========================================================================================================
#                                               coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------------
# Intercept                                  -3.9462      0.621     -6.351      0.000      -5.164      -2.728
# savings[T.> 500 euros]                     -0.6123      0.338     -1.813      0.070      -1.274       0.050
# savings[T.No savings]                      -0.8980      0.283     -3.171      0.002      -1.453      -0.343
# guarantees[T.Without guarantor]             1.0816      0.472      2.293      0.022       0.157       2.006
# amount_credit[T.[4000.0, inf)]              0.3785      0.224      1.688      0.091      -0.061       0.818
# employment_old[T.between 1 and 4 years]    -0.0963      0.244     -0.395      0.693      -0.574       0.382
# employment_old[T.for at least 4 years]     -0.4839      0.241     -2.012      0.044      -0.955      -0.012
# predicted_prob                              4.9617      0.534      9.292      0.000       3.915       6.008
# effort_rate                                 0.2459      0.088      2.785      0.005       0.073       0.419
# ===========================================================================================================
# AIC: 705.2447804233516, AUC: 0.7901
# Reached the model with the smallest AIC. Stopping summary display.

# %% [markdown]
# We arrive at the following result, which shows that 'nb_credit' has also been excluded, so that the new model now contains only 8 variables.

# %%
from sklearn.metrics import roc_auc_score

selected_variables = ['accounts', 'duration_credit', 'family_status', 'other_credits','guarantees', 'savings', 'amount_credit', 'effort_rate']

X_train = train[selected_variables]
X_test = test[selected_variables]

train['predicted_prob'] = model.predict(X_train)
test['predicted_prob'] = model.predict(X_test)

auc_train = roc_auc_score(train['presence_unpaid'], train['predicted_prob'])
auc_test = roc_auc_score(test['presence_unpaid'], test['predicted_prob'])

print(f'AUC on the train sample : {auc_train}')
print(f'AUC on the test sample : {auc_test}')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# File /var/data/python/lib/python3.12/site-packages/patsy/compat.py:40, in call_and_wrap_exc(msg, origin, f, *args, **kwargs)
#      39 try:
# ---> 40     return f(*args, **kwargs)
#      41 except Exception as e:
#
# File /var/data/python/lib/python3.12/site-packages/patsy/eval.py:179, in EvalEnvironment.eval(self, expr, source_name, inner_namespace)
#     178 code = compile(expr, source_name, "eval", self.flags, False)
# --> 179 return eval(code, {}, VarLookupDict([inner_namespace] + self._namespaces))
#
# File <string>:1
#
# NameError: name 'predicted_prob' is not defined
#
# The above exception was the direct cause of the following exception:
#
# PatsyError                                Traceback (most recent call last)
# File /var/data/python/lib/python3.12/site-packages/statsmodels/base/model.py:1102, in Results._transform_predict_exog(self, exog, transform)
#    1101 try:
# -> 1102     exog = dmatrix(design_info, exog, return_type="dataframe")
#    1103 except Exception as exc:
#
# File /var/data/python/lib/python3.12/site-packages/patsy/highlevel.py:296, in dmatrix(formula_like, data, eval_env, NA_action, return_type)
#     295 eval_env = EvalEnvironment.capture(eval_env, reference=1)
# --> 296 (lhs, rhs) = _do_highlevel_design(
#     297     formula_like, data, eval_env, NA_action, return_type
#     298 )
#     299 if lhs.shape[1] != 0:
#
# File /var/data/python/lib/python3.12/site-packages/patsy/highlevel.py:168, in _do_highlevel_design(formula_like, data, eval_env, NA_action, return_type)
#     167 if design_infos is not None:
# --> 168     return build_design_matrices(
#     169         design_infos, data, NA_action=NA_action, return_type=return_type
#     170     )
#     171 else:
#     172     # No builders, but maybe we can still get matrices
#
# File /var/data/python/lib/python3.12/site-packages/patsy/build.py:954, in build_design_matrices(design_infos, data, NA_action, return_type, dtype)
#     953 if factor_info not in factor_info_to_values:
# --> 954     value, is_NA = _eval_factor(factor_info, data, NA_action)
#     955     factor_info_to_isNAs[factor_info] = is_NA
#
# File /var/data/python/lib/python3.12/site-packages/patsy/build.py:68, in _eval_factor(factor_info, data, NA_action)
#      67 factor = factor_info.factor
# ---> 68 result = factor.eval(factor_info.state, data)
#      69 # Returns either a 2d ndarray, or a DataFrame, plus is_NA mask
#
# File /var/data/python/lib/python3.12/site-packages/patsy/eval.py:599, in EvalFactor.eval(self, memorize_state, data)
#     598 def eval(self, memorize_state, data):
# --> 599     return self._eval(memorize_state["eval_code"], memorize_state, data)
#
# File /var/data/python/lib/python3.12/site-packages/patsy/eval.py:582, in EvalFactor._eval(self, code, memorize_state, data)
#     581 inner_namespace = VarLookupDict([data, memorize_state["transforms"]])
# --> 582 return call_and_wrap_exc(
#     583     "Error evaluating factor",
#     584     self,
#     585     memorize_state["eval_env"].eval,
#     586     code,
#     587     inner_namespace=inner_namespace,
#     588 )
#
# File /var/data/python/lib/python3.12/site-packages/patsy/compat.py:43, in call_and_wrap_exc(msg, origin, f, *args, **kwargs)
#      42 new_exc = PatsyError("%s: %s: %s" % (msg, e.__class__.__name__, e), origin)
# ---> 43 raise new_exc from e
#
# PatsyError: Error evaluating factor: NameError: name 'predicted_prob' is not defined
#     presence_unpaid ~ predicted_prob + savings + effort_rate + guarantees + amount_credit + employment_old
#                       ^^^^^^^^^^^^^^
#
# During handling of the above exception, another exception occurred:
#
# PatsyError                                Traceback (most recent call last)
# Cell In[11], line 8
#       5 X_train = train[selected_variables]
#       6 X_test = test[selected_variables]
# ----> 8 train['predicted_prob'] = model.predict(X_train)
#       9 test['predicted_prob'] = model.predict(X_test)
#      11 auc_train = roc_auc_score(train['presence_unpaid'], train['predicted_prob'])
#
# File /var/data/python/lib/python3.12/site-packages/statsmodels/base/model.py:1171, in Results.predict(self, exog, transform, *args, **kwargs)
#    1126 def predict(self, exog=None, transform=True, *args, **kwargs):
#    1127     """
#    1128     Call self.model.predict with self.params as the first argument.
#    1129
#    (...)
#    1169     returned prediction.
#    1170     """
# -> 1171     exog, exog_index = self._transform_predict_exog(exog,
#    1172                                                     transform=transform)
#    1174     predict_results = self.model.predict(self.params, exog, *args,
#    1175                                          **kwargs)
#    1177     if exog_index is not None and not hasattr(predict_results,
#    1178                                               'predicted_values'):
#
# File /var/data/python/lib/python3.12/site-packages/statsmodels/base/model.py:1109, in Results._transform_predict_exog(self, exog, transform)
#    1103 except Exception as exc:
#    1104     msg = ('predict requires that you use a DataFrame when '
#    1105            'predicting from a model\nthat was created using the '
#    1106            'formula api.'
#    1107            '\n\nThe original error message returned by patsy is:\n'
#    1108            '{}'.format(str(str(exc))))
# -> 1109     raise exc.__class__(msg)
#    1110 if orig_exog_len > len(exog) and not is_dict:
#    1111     if exog_index is None:
#
# PatsyError: predict requires that you use a DataFrame when predicting from a model
# that was created using the formula api.
#
# The original error message returned by patsy is:
# Error evaluating factor: NameError: name 'predicted_prob' is not defined
#     presence_unpaid ~ predicted_prob + savings + effort_rate + guarantees + amount_credit + employment_old
#                       ^^^^^^^^^^^^^^

# %% [markdown]
# Calculation of its area under the ROC gives a value equal to 0.786 in learning and 0.782 in testing. The fit of the learning sample model is therefore slightly inferior, as shown by the higher value of the AIC (714 versus 711), but it generalises not much better than the first model as seen xith eu AUC (0.786 versus 0.798)

# %% [markdown]
# ### Backward selection (trial)

# %%
import statsmodels.api as sm
import statsmodels.formula.api as smf
import pandas as pd
from sklearn.metrics import roc_auc_score


predictors_in_model = train.columns.difference(['presence_unpaid']).tolist()
best_aic = float('inf')
best_bic = float('inf')

best_models = {}

while len(predictors_in_model) > 0:
    changed = False
    worst_predictor = None
    best_aic_in_iteration = float('inf')
    best_bic_in_iteration = float('inf')
    
    for predictor in predictors_in_model:
        trial_predictors = [p for p in predictors_in_model if p != predictor]
        
        if not trial_predictors:
            continue  
        
        trial_formula = 'presence_unpaid ~ ' + ' + '.join(trial_predictors)
        trial_model = smf.glm(formula=trial_formula, data=train, family=sm.families.Binomial()).fit()
        trial_aic = trial_model.aic
        trial_bic = trial_model.bic_llf
        
        if trial_bic < best_bic_in_iteration:
            best_aic_in_iteration = trial_aic
            best_bic_in_iteration = trial_bic
            worst_predictor = predictor
            best_model = trial_model
            changed = True

    if changed and worst_predictor:
        predictors_in_model.remove(worst_predictor)
        best_aic = best_aic_in_iteration
        best_bic = best_bic_in_iteration
        
        y_pred_prob = best_model.predict(train)
        auc = roc_auc_score(train['presence_unpaid'], y_pred_prob)
        
        best_models[len(predictors_in_model)] = (best_aic, best_bic, auc, best_model)
    else:
        print("No further improvement in BIC. Stopping selection process.")
        break

min_bic_key = min(best_models, key=lambda k: best_models[k][1])

for num_vars in sorted(best_models.keys(), reverse=True):
    aic, bic, auc, model = best_models[num_vars]
    print(f"\nBest model with {num_vars} variables:")
    print(model.summary())
    print(f"AIC: {aic}, BIC: {bic}, AUC: {auc:.4f}")
    
    if num_vars == min_bic_key:
        print("Reached the model with the smallest BIC. Stopping summary display.")
        break
# Out:
# No further improvement in BIC. Stopping selection process.
#
# Best model with 19 variables:
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:        presence_unpaid   No. Observations:                  700
# Model:                            GLM   Df Residuals:                      667
# Model Family:                Binomial   Df Model:                           32
# Link Function:                  Logit   Scale:                          1.0000
# Method:                          IRLS   Log-Likelihood:                -331.15
# Date:                Sun, 09 Feb 2025   Deviance:                       662.31
# Time:                        11:58:31   Pearson chi2:                     658.
# No. Iterations:                     6   Pseudo R-squ. (CS):             0.2371
# Covariance Type:            nonrobust
# ================================================================================================================
#                                                    coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------------------
# Intercept                                        0.3310      2.344      0.141      0.888      -4.264       4.926
# accounts[T.CC > 200 euros]                      -1.1019      0.788     -1.397      0.162      -2.647       0.444
# accounts[T.CC [0-200 euros]]                    -0.4111      0.388     -1.061      0.289      -1.171       0.349
# accounts[T.No account]                          -2.5695      1.298     -1.980      0.048      -5.114      -0.025
# age[T.[25.0, inf)]                              -0.2468      0.290     -0.852      0.394      -0.815       0.321
# amount_credit[T.[4000.0, inf)]                   0.4060      0.284      1.430      0.153      -0.150       0.962
# duration_credit[T.[15.0, 36.0)]                  0.7081      0.426      1.662      0.097      -0.127       1.543
# duration_credit[T.[36.0, inf)]                   1.5430      0.895      1.724      0.085      -0.211       3.297
# employment_old[T.between 1 and 4 years]          0.0342      0.263      0.130      0.897      -0.482       0.550
# employment_old[T.for at least 4 years]          -0.3169      0.268     -1.181      0.237      -0.843       0.209
# family_status[T.Male divorced/separated]         0.8480      0.514      1.648      0.099      -0.160       1.856
# family_status[T.Male single/married/widowed]    -0.8674      0.473     -1.833      0.067      -1.795       0.060
# guarantees[T.Without guarantor]                  1.0452      0.483      2.165      0.030       0.099       1.991
# history_credit[T.A31]                           -0.0609      0.656     -0.093      0.926      -1.346       1.224
# history_credit[T.A32]                           -0.4869      0.547     -0.889      0.374      -1.560       0.586
# history_credit[T.A33]                           -0.8874      0.587     -1.512      0.131      -2.038       0.263
# history_credit[T.A34]                           -1.2769      0.547     -2.336      0.020      -2.348      -0.205
# home_status[T.owner]                            -0.1404      0.264     -0.532      0.595      -0.658       0.377
# job_type[T.A172]                                -0.4526      0.716     -0.632      0.527      -1.855       0.950
# job_type[T.A173]                                -0.4824      0.699     -0.690      0.490      -1.853       0.888
# job_type[T.A174]                                -0.2918      0.739     -0.395      0.693      -1.740       1.156
# other_credits[T.No external credit]             -0.9635      0.540     -1.785      0.074      -2.021       0.094
# property[T.Non-property]                        -0.2242      0.350     -0.640      0.522      -0.911       0.462
# property[T.Not real estate]                      0.1729      0.368      0.469      0.639      -0.549       0.895
# property[T.Property]                            -0.1797      0.380     -0.472      0.637      -0.925       0.566
# savings[T.> 500 euros]                          -0.6153      0.356     -1.728      0.084      -1.313       0.082
# savings[T.No savings]                           -0.9469      0.296     -3.197      0.001      -1.527      -0.366
# telephone[T.A192]                               -0.1874      0.222     -0.846      0.398      -0.622       0.247
# effort_rate                                      0.2646      0.095      2.788      0.005       0.079       0.451
# home_old                                         0.0428      0.096      0.447      0.655      -0.145       0.230
# nb_credits                                       0.4106      0.220      1.870      0.061      -0.020       0.841
# nb_of_dependants                                 0.2959      0.279      1.062      0.288      -0.250       0.842
# predicted_prob                                  -1.9508      3.307     -0.590      0.555      -8.433       4.532
# ================================================================================================================
# AIC: 728.3084482373456, BIC: 878.4940992937779, AUC: 0.8064
#
# Best model with 18 variables:
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:        presence_unpaid   No. Observations:                  700
# Model:                            GLM   Df Residuals:                      670
# Model Family:                Binomial   Df Model:                           29
# Link Function:                  Logit   Scale:                          1.0000
# Method:                          IRLS   Log-Likelihood:                -331.53
# Date:                Sun, 09 Feb 2025   Deviance:                       663.06
# Time:                        11:58:31   Pearson chi2:                     656.
# No. Iterations:                     6   Pseudo R-squ. (CS):             0.2363
# Covariance Type:            nonrobust
# ================================================================================================================
#                                                    coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------------------
# Intercept                                       -0.1186      2.238     -0.053      0.958      -4.504       4.267
# accounts[T.CC > 200 euros]                      -1.0787      0.785     -1.374      0.170      -2.618       0.460
# accounts[T.CC [0-200 euros]]                    -0.4040      0.387     -1.044      0.297      -1.162       0.354
# accounts[T.No account]                          -2.5722      1.296     -1.984      0.047      -5.113      -0.032
# age[T.[25.0, inf)]                              -0.2188      0.287     -0.763      0.446      -0.781       0.344
# amount_credit[T.[4000.0, inf)]                   0.4352      0.277      1.574      0.116      -0.107       0.977
# duration_credit[T.[15.0, 36.0)]                  0.6915      0.424      1.629      0.103      -0.140       1.523
# duration_credit[T.[36.0, inf)]                   1.5200      0.893      1.703      0.089      -0.229       3.269
# employment_old[T.between 1 and 4 years]         -0.0210      0.255     -0.082      0.934      -0.521       0.479
# employment_old[T.for at least 4 years]          -0.3695      0.260     -1.421      0.155      -0.879       0.140
# family_status[T.Male divorced/separated]         0.8364      0.513      1.629      0.103      -0.170       1.843
# family_status[T.Male single/married/widowed]    -0.8655      0.473     -1.831      0.067      -1.792       0.061
# guarantees[T.Without guarantor]                  1.0580      0.482      2.196      0.028       0.114       2.002
# history_credit[T.A31]                           -0.0163      0.653     -0.025      0.980      -1.296       1.264
# history_credit[T.A32]                           -0.4624      0.545     -0.848      0.397      -1.531       0.607
# history_credit[T.A33]                           -0.8682      0.584     -1.487      0.137      -2.012       0.276
# history_credit[T.A34]                           -1.2490      0.544     -2.296      0.022      -2.315      -0.183
# home_status[T.owner]                            -0.1465      0.262     -0.559      0.576      -0.660       0.367
# other_credits[T.No external credit]             -0.9563      0.539     -1.774      0.076      -2.013       0.100
# property[T.Non-property]                        -0.2455      0.348     -0.704      0.481      -0.928       0.437
# property[T.Not real estate]                      0.1311      0.364      0.360      0.719      -0.583       0.845
# property[T.Property]                            -0.2071      0.374     -0.553      0.580      -0.941       0.526
# savings[T.> 500 euros]                          -0.6298      0.355     -1.773      0.076      -1.326       0.066
# savings[T.No savings]                           -0.9357      0.294     -3.179      0.001      -1.512      -0.359
# telephone[T.A192]                               -0.1518      0.210     -0.724      0.469      -0.562       0.259
# effort_rate                                      0.2661      0.094      2.821      0.005       0.081       0.451
# home_old                                         0.0391      0.095      0.410      0.681      -0.148       0.226
# nb_credits                                       0.4243      0.218      1.951      0.051      -0.002       0.851
# nb_of_dependants                                 0.2900      0.274      1.057      0.290      -0.248       0.828
# predicted_prob                                  -1.9635      3.303     -0.594      0.552      -8.438       4.511
# ================================================================================================================
# AIC: 723.0618253889656, BIC: 859.5942354402678, AUC: 0.8054
#
# Best model with 17 variables:
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:        presence_unpaid   No. Observations:                  700
# Model:                            GLM   Df Residuals:                      673
# Model Family:                Binomial   Df Model:                           26
# Link Function:                  Logit   Scale:                          1.0000
# Method:                          IRLS   Log-Likelihood:                -332.82
# Date:                Sun, 09 Feb 2025   Deviance:                       665.64
# Time:                        11:58:31   Pearson chi2:                     659.
# No. Iterations:                     6   Pseudo R-squ. (CS):             0.2335
# Covariance Type:            nonrobust
# ================================================================================================================
#                                                    coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------------------
# Intercept                                       -0.1442      2.187     -0.066      0.947      -4.430       4.141
# accounts[T.CC > 200 euros]                      -1.1061      0.779     -1.420      0.156      -2.633       0.421
# accounts[T.CC [0-200 euros]]                    -0.4334      0.384     -1.129      0.259      -1.186       0.319
# accounts[T.No account]                          -2.5844      1.286     -2.009      0.045      -5.106      -0.063
# age[T.[25.0, inf)]                              -0.2189      0.280     -0.781      0.435      -0.768       0.331
# amount_credit[T.[4000.0, inf)]                   0.4629      0.271      1.706      0.088      -0.069       0.995
# duration_credit[T.[15.0, 36.0)]                  0.6665      0.419      1.592      0.111      -0.154       1.487
# duration_credit[T.[36.0, inf)]                   1.4759      0.886      1.666      0.096      -0.260       3.212
# employment_old[T.between 1 and 4 years]         -0.0802      0.251     -0.320      0.749      -0.572       0.411
# employment_old[T.for at least 4 years]          -0.3989      0.258     -1.547      0.122      -0.904       0.106
# family_status[T.Male divorced/separated]         0.8137      0.509      1.598      0.110      -0.184       1.812
# family_status[T.Male single/married/widowed]    -0.8536      0.467     -1.826      0.068      -1.770       0.062
# guarantees[T.Without guarantor]                  1.0160      0.474      2.143      0.032       0.087       1.945
# history_credit[T.A31]                           -0.0203      0.652     -0.031      0.975      -1.299       1.258
# history_credit[T.A32]                           -0.4562      0.546     -0.836      0.403      -1.526       0.614
# history_credit[T.A33]                           -0.8355      0.582     -1.436      0.151      -1.976       0.305
# history_credit[T.A34]                           -1.2344      0.543     -2.274      0.023      -2.298      -0.170
# home_status[T.owner]                            -0.1834      0.228     -0.806      0.420      -0.630       0.263
# other_credits[T.No external credit]             -0.9529      0.536     -1.776      0.076      -2.004       0.098
# savings[T.> 500 euros]                          -0.6413      0.354     -1.812      0.070      -1.335       0.052
# savings[T.No savings]                           -0.9009      0.292     -3.081      0.002      -1.474      -0.328
# telephone[T.A192]                               -0.1395      0.208     -0.672      0.502      -0.547       0.268
# effort_rate                                      0.2727      0.093      2.923      0.003       0.090       0.456
# home_old                                         0.0432      0.095      0.456      0.649      -0.143       0.229
# nb_credits                                       0.4181      0.218      1.914      0.056      -0.010       0.846
# nb_of_dependants                                 0.2834      0.273      1.040      0.299      -0.251       0.818
# predicted_prob                                  -1.9376      3.279     -0.591      0.555      -8.365       4.490
# ================================================================================================================
# AIC: 719.6427959865322, BIC: 842.5219650327041, AUC: 0.8039
#
# Best model with 16 variables:
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:        presence_unpaid   No. Observations:                  700
# Model:                            GLM   Df Residuals:                      677
# Model Family:                Binomial   Df Model:                           22
# Link Function:                  Logit   Scale:                          1.0000
# Method:                          IRLS   Log-Likelihood:                -338.91
# Date:                Sun, 09 Feb 2025   Deviance:                       677.82
# Time:                        11:58:31   Pearson chi2:                     661.
# No. Iterations:                     6   Pseudo R-squ. (CS):             0.2201
# Covariance Type:            nonrobust
# ================================================================================================================
#                                                    coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------------------
# Intercept                                       -0.6806      2.056     -0.331      0.741      -4.710       3.349
# accounts[T.CC > 200 euros]                      -0.9976      0.764     -1.305      0.192      -2.496       0.501
# accounts[T.CC [0-200 euros]]                    -0.3820      0.374     -1.020      0.308      -1.116       0.352
# accounts[T.No account]                          -2.3247      1.260     -1.845      0.065      -4.794       0.145
# age[T.[25.0, inf)]                              -0.2268      0.276     -0.822      0.411      -0.767       0.314
# amount_credit[T.[4000.0, inf)]                   0.4659      0.266      1.754      0.080      -0.055       0.987
# duration_credit[T.[15.0, 36.0)]                  0.5782      0.413      1.400      0.161      -0.231       1.387
# duration_credit[T.[36.0, inf)]                   1.2829      0.871      1.472      0.141      -0.425       2.991
# employment_old[T.between 1 and 4 years]         -0.0549      0.247     -0.222      0.825      -0.540       0.430
# employment_old[T.for at least 4 years]          -0.4150      0.254     -1.636      0.102      -0.912       0.082
# family_status[T.Male divorced/separated]         0.6355      0.501      1.269      0.205      -0.346       1.617
# family_status[T.Male single/married/widowed]    -0.7494      0.459     -1.634      0.102      -1.648       0.149
# guarantees[T.Without guarantor]                  1.0589      0.471      2.250      0.024       0.137       1.981
# home_status[T.owner]                            -0.2302      0.223     -1.031      0.302      -0.668       0.207
# other_credits[T.No external credit]             -0.9219      0.525     -1.755      0.079      -1.951       0.107
# savings[T.> 500 euros]                          -0.6128      0.344     -1.780      0.075      -1.288       0.062
# savings[T.No savings]                           -0.8559      0.288     -2.972      0.003      -1.420      -0.291
# telephone[T.A192]                               -0.1309      0.204     -0.641      0.522      -0.531       0.270
# effort_rate                                      0.2693      0.092      2.925      0.003       0.089       0.450
# home_old                                         0.0026      0.093      0.028      0.978      -0.180       0.185
# nb_credits                                       0.1018      0.173      0.590      0.555      -0.236       0.440
# nb_of_dependants                                 0.3000      0.270      1.112      0.266      -0.229       0.829
# predicted_prob                                  -0.9926      3.220     -0.308      0.758      -7.304       5.319
# ================================================================================================================
# AIC: 723.8197192494238, BIC: 828.4945669554221, AUC: 0.7950
#
# Best model with 15 variables:
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:        presence_unpaid   No. Observations:                  700
# Model:                            GLM   Df Residuals:                      680
# Model Family:                Binomial   Df Model:                           19
# Link Function:                  Logit   Scale:                          1.0000
# Method:                          IRLS   Log-Likelihood:                -341.33
# Date:                Sun, 09 Feb 2025   Deviance:                       682.65
# Time:                        11:58:31   Pearson chi2:                     652.
# No. Iterations:                     5   Pseudo R-squ. (CS):             0.2147
# Covariance Type:            nonrobust
# ================================================================================================================
#                                                    coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------------------
# Intercept                                       -4.0549      0.867     -4.678      0.000      -5.754      -2.356
# age[T.[25.0, inf)]                              -0.2344      0.278     -0.843      0.399      -0.779       0.311
# amount_credit[T.[4000.0, inf)]                   0.4949      0.266      1.858      0.063      -0.027       1.017
# duration_credit[T.[15.0, 36.0)]                 -0.0465      0.231     -0.201      0.840      -0.499       0.406
# duration_credit[T.[36.0, inf)]                  -0.1886      0.356     -0.529      0.597      -0.887       0.510
# employment_old[T.between 1 and 4 years]         -0.0737      0.247     -0.298      0.766      -0.558       0.411
# employment_old[T.for at least 4 years]          -0.4593      0.254     -1.811      0.070      -0.956       0.038
# family_status[T.Male divorced/separated]         0.1360      0.429      0.317      0.751      -0.706       0.977
# family_status[T.Male single/married/widowed]    -0.0065      0.229     -0.028      0.977      -0.456       0.443
# guarantees[T.Without guarantor]                  1.0766      0.478      2.255      0.024       0.141       2.013
# home_status[T.owner]                            -0.2285      0.223     -1.022      0.307      -0.666       0.210
# other_credits[T.No external credit]             -0.0472      0.243     -0.195      0.846      -0.523       0.428
# savings[T.> 500 euros]                          -0.5981      0.342     -1.747      0.081      -1.269       0.073
# savings[T.No savings]                           -0.8549      0.287     -2.974      0.003      -1.418      -0.291
# telephone[T.A192]                               -0.1353      0.204     -0.662      0.508      -0.536       0.265
# effort_rate                                      0.2775      0.092      3.031      0.002       0.098       0.457
# home_old                                        -0.0065      0.093     -0.070      0.944      -0.188       0.176
# nb_credits                                       0.0953      0.171      0.556      0.578      -0.240       0.431
# nb_of_dependants                                 0.2932      0.267      1.097      0.273      -0.231       0.817
# predicted_prob                                   4.9729      0.665      7.477      0.000       3.669       6.276
# ================================================================================================================
# AIC: 722.6520092955583, BIC: 813.6736159964264, AUC: 0.7947
#
# Best model with 14 variables:
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:        presence_unpaid   No. Observations:                  700
# Model:                            GLM   Df Residuals:                      682
# Model Family:                Binomial   Df Model:                           17
# Link Function:                  Logit   Scale:                          1.0000
# Method:                          IRLS   Log-Likelihood:                -341.38
# Date:                Sun, 09 Feb 2025   Deviance:                       682.77
# Time:                        11:58:31   Pearson chi2:                     651.
# No. Iterations:                     5   Pseudo R-squ. (CS):             0.2145
# Covariance Type:            nonrobust
# ===========================================================================================================
#                                               coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------------
# Intercept                                  -4.0769      0.857     -4.755      0.000      -5.757      -2.397
# age[T.[25.0, inf)]                         -0.2238      0.275     -0.814      0.416      -0.763       0.315
# amount_credit[T.[4000.0, inf)]              0.4920      0.266      1.851      0.064      -0.029       1.013
# duration_credit[T.[15.0, 36.0)]            -0.0519      0.230     -0.226      0.822      -0.503       0.399
# duration_credit[T.[36.0, inf)]             -0.2021      0.350     -0.577      0.564      -0.889       0.484
# employment_old[T.between 1 and 4 years]    -0.0721      0.246     -0.293      0.770      -0.555       0.411
# employment_old[T.for at least 4 years]     -0.4572      0.252     -1.812      0.070      -0.952       0.037
# guarantees[T.Without guarantor]             1.0900      0.476      2.291      0.022       0.157       2.022
# home_status[T.owner]                       -0.2271      0.223     -1.018      0.309      -0.664       0.210
# other_credits[T.No external credit]        -0.0363      0.237     -0.153      0.878      -0.501       0.428
# savings[T.> 500 euros]                     -0.5948      0.343     -1.736      0.083      -1.266       0.077
# savings[T.No savings]                      -0.8536      0.287     -2.974      0.003      -1.416      -0.291
# telephone[T.A192]                          -0.1331      0.204     -0.652      0.514      -0.533       0.267
# effort_rate                                 0.2742      0.091      3.029      0.002       0.097       0.452
# home_old                                   -0.0092      0.092     -0.099      0.921      -0.190       0.172
# nb_credits                                  0.0959      0.171      0.560      0.575      -0.240       0.431
# nb_of_dependants                            0.2879      0.262      1.099      0.272      -0.226       0.802
# predicted_prob                              5.0331      0.619      8.130      0.000       3.820       6.246
# ===========================================================================================================
# AIC: 718.7659512981915, BIC: 800.6853973289727, AUC: 0.7947
#
# Best model with 13 variables:
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:        presence_unpaid   No. Observations:                  700
# Model:                            GLM   Df Residuals:                      684
# Model Family:                Binomial   Df Model:                           15
# Link Function:                  Logit   Scale:                          1.0000
# Method:                          IRLS   Log-Likelihood:                -341.56
# Date:                Sun, 09 Feb 2025   Deviance:                       683.11
# Time:                        11:58:31   Pearson chi2:                     653.
# No. Iterations:                     5   Pseudo R-squ. (CS):             0.2141
# Covariance Type:            nonrobust
# ===========================================================================================================
#                                               coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------------
# Intercept                                  -4.0344      0.854     -4.726      0.000      -5.708      -2.361
# age[T.[25.0, inf)]                         -0.2319      0.274     -0.845      0.398      -0.770       0.306
# amount_credit[T.[4000.0, inf)]              0.4147      0.231      1.794      0.073      -0.038       0.868
# employment_old[T.between 1 and 4 years]    -0.0890      0.245     -0.364      0.716      -0.568       0.390
# employment_old[T.for at least 4 years]     -0.4718      0.251     -1.879      0.060      -0.964       0.020
# guarantees[T.Without guarantor]             1.0947      0.477      2.297      0.022       0.161       2.029
# home_status[T.owner]                       -0.2231      0.223     -1.002      0.317      -0.660       0.214
# other_credits[T.No external credit]        -0.0500      0.235     -0.213      0.832      -0.511       0.411
# savings[T.> 500 euros]                     -0.5955      0.342     -1.743      0.081      -1.265       0.074
# savings[T.No savings]                      -0.8674      0.286     -3.033      0.002      -1.428      -0.307
# telephone[T.A192]                          -0.1352      0.203     -0.665      0.506      -0.534       0.264
# effort_rate                                 0.2658      0.089      2.977      0.003       0.091       0.441
# home_old                                   -0.0042      0.092     -0.045      0.964      -0.184       0.176
# nb_credits                                  0.0976      0.171      0.571      0.568      -0.237       0.433
# nb_of_dependants                            0.2834      0.262      1.083      0.279      -0.229       0.796
# predicted_prob                              4.9017      0.568      8.623      0.000       3.788       6.016
# ===========================================================================================================
# AIC: 715.1114180381012, BIC: 787.9287033987956, AUC: 0.7945
#
# Best model with 12 variables:
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:        presence_unpaid   No. Observations:                  700
# Model:                            GLM   Df Residuals:                      686
# Model Family:                Binomial   Df Model:                           13
# Link Function:                  Logit   Scale:                          1.0000
# Method:                          IRLS   Log-Likelihood:                -343.70
# Date:                Sun, 09 Feb 2025   Deviance:                       687.40
# Time:                        11:58:31   Pearson chi2:                     655.
# No. Iterations:                     5   Pseudo R-squ. (CS):             0.2093
# Covariance Type:            nonrobust
# =======================================================================================================
#                                           coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------
# Intercept                              -3.9916      0.828     -4.823      0.000      -5.614      -2.369
# age[T.[25.0, inf)]                     -0.3249      0.270     -1.203      0.229      -0.854       0.204
# amount_credit[T.[4000.0, inf)]          0.4111      0.231      1.781      0.075      -0.041       0.863
# guarantees[T.Without guarantor]         1.1677      0.475      2.459      0.014       0.237       2.098
# home_status[T.owner]                   -0.2382      0.222     -1.073      0.283      -0.673       0.197
# other_credits[T.No external credit]    -0.0534      0.234     -0.228      0.820      -0.512       0.406
# savings[T.> 500 euros]                 -0.6115      0.338     -1.810      0.070      -1.274       0.051
# savings[T.No savings]                  -0.8898      0.285     -3.126      0.002      -1.448      -0.332
# telephone[T.A192]                      -0.1527      0.202     -0.755      0.450      -0.549       0.244
# effort_rate                             0.2508      0.089      2.820      0.005       0.077       0.425
# home_old                               -0.0464      0.089     -0.522      0.602      -0.221       0.128
# nb_credits                              0.0631      0.170      0.372      0.710      -0.270       0.396
# nb_of_dependants                        0.2590      0.261      0.991      0.322      -0.253       0.771
# predicted_prob                          4.9426      0.563      8.784      0.000       3.840       6.045
# =======================================================================================================
# AIC: 715.3977497299563, BIC: 779.112874420564, AUC: 0.7909
#
# Best model with 11 variables:
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:        presence_unpaid   No. Observations:                  700
# Model:                            GLM   Df Residuals:                      687
# Model Family:                Binomial   Df Model:                           12
# Link Function:                  Logit   Scale:                          1.0000
# Method:                          IRLS   Log-Likelihood:                -343.72
# Date:                Sun, 09 Feb 2025   Deviance:                       687.45
# Time:                        11:58:31   Pearson chi2:                     657.
# No. Iterations:                     5   Pseudo R-squ. (CS):             0.2093
# Covariance Type:            nonrobust
# ===================================================================================================
#                                       coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------
# Intercept                          -4.0554      0.779     -5.205      0.000      -5.583      -2.528
# age[T.[25.0, inf)]                 -0.3233      0.270     -1.198      0.231      -0.852       0.206
# amount_credit[T.[4000.0, inf)]      0.4087      0.231      1.772      0.076      -0.043       0.861
# guarantees[T.Without guarantor]     1.1651      0.475      2.455      0.014       0.235       2.095
# home_status[T.owner]               -0.2338      0.221     -1.057      0.291      -0.667       0.200
# savings[T.> 500 euros]             -0.6078      0.337     -1.803      0.071      -1.269       0.053
# savings[T.No savings]              -0.8880      0.284     -3.122      0.002      -1.445      -0.331
# telephone[T.A192]                  -0.1519      0.202     -0.751      0.453      -0.548       0.245
# effort_rate                         0.2510      0.089      2.822      0.005       0.077       0.425
# home_old                           -0.0464      0.089     -0.521      0.602      -0.221       0.128
# nb_credits                          0.0657      0.169      0.388      0.698      -0.266       0.398
# nb_of_dependants                    0.2621      0.261      1.004      0.315      -0.250       0.774
# predicted_prob                      4.9780      0.541      9.197      0.000       3.917       6.039
# ===================================================================================================
# AIC: 713.4495731070294, BIC: 772.6136174625937, AUC: 0.7906
#
# Best model with 10 variables:
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:        presence_unpaid   No. Observations:                  700
# Model:                            GLM   Df Residuals:                      688
# Model Family:                Binomial   Df Model:                           11
# Link Function:                  Logit   Scale:                          1.0000
# Method:                          IRLS   Log-Likelihood:                -343.80
# Date:                Sun, 09 Feb 2025   Deviance:                       687.60
# Time:                        11:58:31   Pearson chi2:                     659.
# No. Iterations:                     5   Pseudo R-squ. (CS):             0.2091
# Covariance Type:            nonrobust
# ===================================================================================================
#                                       coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------
# Intercept                          -3.9844      0.756     -5.267      0.000      -5.467      -2.502
# age[T.[25.0, inf)]                 -0.3121      0.268     -1.164      0.245      -0.838       0.214
# amount_credit[T.[4000.0, inf)]      0.4153      0.230      1.805      0.071      -0.036       0.866
# guarantees[T.Without guarantor]     1.1676      0.474      2.462      0.014       0.238       2.097
# home_status[T.owner]               -0.2305      0.221     -1.043      0.297      -0.664       0.203
# savings[T.> 500 euros]             -0.6094      0.337     -1.808      0.071      -1.270       0.051
# savings[T.No savings]              -0.8951      0.284     -3.153      0.002      -1.452      -0.339
# telephone[T.A192]                  -0.1498      0.202     -0.741      0.459      -0.546       0.247
# effort_rate                         0.2494      0.089      2.810      0.005       0.075       0.423
# home_old                           -0.0438      0.089     -0.495      0.621      -0.218       0.130
# nb_of_dependants                    0.2708      0.260      1.041      0.298      -0.239       0.780
# predicted_prob                      4.9571      0.538      9.213      0.000       3.903       6.012
# ===================================================================================================
# AIC: 711.5993217680419, BIC: 766.2122857885628, AUC: 0.7904
#
# Best model with 9 variables:
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:        presence_unpaid   No. Observations:                  700
# Model:                            GLM   Df Residuals:                      689
# Model Family:                Binomial   Df Model:                           10
# Link Function:                  Logit   Scale:                          1.0000
# Method:                          IRLS   Log-Likelihood:                -343.92
# Date:                Sun, 09 Feb 2025   Deviance:                       687.84
# Time:                        11:58:31   Pearson chi2:                     660.
# No. Iterations:                     5   Pseudo R-squ. (CS):             0.2088
# Covariance Type:            nonrobust
# ===================================================================================================
#                                       coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------
# Intercept                          -4.1189      0.707     -5.822      0.000      -5.505      -2.732
# age[T.[25.0, inf)]                 -0.3085      0.268     -1.150      0.250      -0.834       0.217
# amount_credit[T.[4000.0, inf)]      0.4127      0.230      1.794      0.073      -0.038       0.863
# guarantees[T.Without guarantor]     1.1730      0.475      2.472      0.013       0.243       2.103
# home_status[T.owner]               -0.1966      0.210     -0.936      0.349      -0.608       0.215
# savings[T.> 500 euros]             -0.6157      0.337     -1.829      0.067      -1.275       0.044
# savings[T.No savings]              -0.9031      0.283     -3.188      0.001      -1.458      -0.348
# telephone[T.A192]                  -0.1589      0.201     -0.789      0.430      -0.554       0.236
# effort_rate                         0.2468      0.089      2.785      0.005       0.073       0.421
# nb_of_dependants                    0.2643      0.260      1.018      0.309      -0.245       0.773
# predicted_prob                      4.9586      0.538      9.221      0.000       3.905       6.013
# ===================================================================================================
# AIC: 709.8440147710423, BIC: 759.9058984565198, AUC: 0.7895
#
# Best model with 8 variables:
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:        presence_unpaid   No. Observations:                  700
# Model:                            GLM   Df Residuals:                      690
# Model Family:                Binomial   Df Model:                            9
# Link Function:                  Logit   Scale:                          1.0000
# Method:                          IRLS   Log-Likelihood:                -344.24
# Date:                Sun, 09 Feb 2025   Deviance:                       688.47
# Time:                        11:58:31   Pearson chi2:                     658.
# No. Iterations:                     5   Pseudo R-squ. (CS):             0.2081
# Covariance Type:            nonrobust
# ===================================================================================================
#                                       coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------
# Intercept                          -4.1308      0.706     -5.849      0.000      -5.515      -2.747
# age[T.[25.0, inf)]                 -0.3415      0.265     -1.290      0.197      -0.861       0.177
# amount_credit[T.[4000.0, inf)]      0.3816      0.226      1.687      0.092      -0.062       0.825
# guarantees[T.Without guarantor]     1.1595      0.474      2.448      0.014       0.231       2.088
# home_status[T.owner]               -0.1852      0.209     -0.885      0.376      -0.596       0.225
# savings[T.> 500 euros]             -0.6321      0.336     -1.879      0.060      -1.291       0.027
# savings[T.No savings]              -0.9155      0.283     -3.236      0.001      -1.470      -0.361
# effort_rate                         0.2444      0.089      2.760      0.006       0.071       0.418
# nb_of_dependants                    0.2703      0.259      1.043      0.297      -0.238       0.778
# predicted_prob                      4.9440      0.537      9.215      0.000       3.892       5.996
# ===================================================================================================
# AIC: 708.4700124954995, BIC: 753.9808158459335, AUC: 0.7885
#
# Best model with 7 variables:
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:        presence_unpaid   No. Observations:                  700
# Model:                            GLM   Df Residuals:                      691
# Model Family:                Binomial   Df Model:                            8
# Link Function:                  Logit   Scale:                          1.0000
# Method:                          IRLS   Log-Likelihood:                -344.62
# Date:                Sun, 09 Feb 2025   Deviance:                       689.25
# Time:                        11:58:31   Pearson chi2:                     658.
# No. Iterations:                     5   Pseudo R-squ. (CS):             0.2072
# Covariance Type:            nonrobust
# ===================================================================================================
#                                       coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------
# Intercept                          -4.2368      0.694     -6.101      0.000      -5.598      -2.876
# age[T.[25.0, inf)]                 -0.3912      0.259     -1.512      0.131      -0.898       0.116
# amount_credit[T.[4000.0, inf)]      0.3922      0.226      1.738      0.082      -0.050       0.835
# guarantees[T.Without guarantor]     1.1603      0.471      2.466      0.014       0.238       2.083
# savings[T.> 500 euros]             -0.6447      0.336     -1.916      0.055      -1.304       0.015
# savings[T.No savings]              -0.9146      0.282     -3.238      0.001      -1.468      -0.361
# effort_rate                         0.2419      0.088      2.737      0.006       0.069       0.415
# nb_of_dependants                    0.2775      0.259      1.072      0.284      -0.230       0.785
# predicted_prob                      4.9889      0.534      9.335      0.000       3.941       6.036
# ===================================================================================================
# AIC: 707.2477240099811, BIC: 748.2074470253717, AUC: 0.7875
#
# Best model with 6 variables:
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:        presence_unpaid   No. Observations:                  700
# Model:                            GLM   Df Residuals:                      692
# Model Family:                Binomial   Df Model:                            7
# Link Function:                  Logit   Scale:                          1.0000
# Method:                          IRLS   Log-Likelihood:                -345.19
# Date:                Sun, 09 Feb 2025   Deviance:                       690.38
# Time:                        11:58:31   Pearson chi2:                     660.
# No. Iterations:                     5   Pseudo R-squ. (CS):             0.2059
# Covariance Type:            nonrobust
# ===================================================================================================
#                                       coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------
# Intercept                          -3.9122      0.622     -6.290      0.000      -5.131      -2.693
# age[T.[25.0, inf)]                 -0.3520      0.255     -1.379      0.168      -0.852       0.148
# amount_credit[T.[4000.0, inf)]      0.3845      0.225      1.707      0.088      -0.057       0.826
# guarantees[T.Without guarantor]     1.1568      0.470      2.460      0.014       0.235       2.078
# savings[T.> 500 euros]             -0.6436      0.336     -1.918      0.055      -1.301       0.014
# savings[T.No savings]              -0.9088      0.282     -3.222      0.001      -1.462      -0.356
# effort_rate                         0.2361      0.088      2.675      0.007       0.063       0.409
# predicted_prob                      4.9507      0.532      9.304      0.000       3.908       5.994
# ===================================================================================================
# AIC: 706.3805022555271, BIC: 742.7891449358743, AUC: 0.7863
#
# Best model with 5 variables:
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:        presence_unpaid   No. Observations:                  700
# Model:                            GLM   Df Residuals:                      693
# Model Family:                Binomial   Df Model:                            6
# Link Function:                  Logit   Scale:                          1.0000
# Method:                          IRLS   Log-Likelihood:                -346.13
# Date:                Sun, 09 Feb 2025   Deviance:                       692.26
# Time:                        11:58:31   Pearson chi2:                     661.
# No. Iterations:                     5   Pseudo R-squ. (CS):             0.2038
# Covariance Type:            nonrobust
# ===================================================================================================
#                                       coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------
# Intercept                          -4.2006      0.591     -7.113      0.000      -5.358      -3.043
# amount_credit[T.[4000.0, inf)]      0.3528      0.224      1.579      0.114      -0.085       0.791
# guarantees[T.Without guarantor]     1.1614      0.472      2.463      0.014       0.237       2.086
# savings[T.> 500 euros]             -0.6372      0.334     -1.909      0.056      -1.291       0.017
# savings[T.No savings]              -0.9344      0.282     -3.319      0.001      -1.486      -0.383
# effort_rate                         0.2268      0.088      2.581      0.010       0.055       0.399
# predicted_prob                      5.0312      0.529      9.502      0.000       3.993       6.069
# ===================================================================================================
# AIC: 706.2604127757505, BIC: 738.1179751210543, AUC: 0.7847
#
# Best model with 4 variables:
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:        presence_unpaid   No. Observations:                  700
# Model:                            GLM   Df Residuals:                      694
# Model Family:                Binomial   Df Model:                            5
# Link Function:                  Logit   Scale:                          1.0000
# Method:                          IRLS   Log-Likelihood:                -347.37
# Date:                Sun, 09 Feb 2025   Deviance:                       694.73
# Time:                        11:58:31   Pearson chi2:                     669.
# No. Iterations:                     5   Pseudo R-squ. (CS):             0.2010
# Covariance Type:            nonrobust
# ===================================================================================================
#                                       coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------
# Intercept                          -4.1027      0.583     -7.032      0.000      -5.246      -2.959
# guarantees[T.Without guarantor]     1.1943      0.470      2.543      0.011       0.274       2.115
# savings[T.> 500 euros]             -0.6427      0.334     -1.925      0.054      -1.297       0.012
# savings[T.No savings]              -0.8904      0.279     -3.187      0.001      -1.438      -0.343
# effort_rate                         0.1934      0.085      2.280      0.023       0.027       0.360
# predicted_prob                      5.1973      0.519     10.014      0.000       4.180       6.215
# ===================================================================================================
# AIC: 706.7310197620588, BIC: 734.0375017723193, AUC: 0.7826
#
# Best model with 3 variables:
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:        presence_unpaid   No. Observations:                  700
# Model:                            GLM   Df Residuals:                      695
# Model Family:                Binomial   Df Model:                            4
# Link Function:                  Logit   Scale:                          1.0000
# Method:                          IRLS   Log-Likelihood:                -350.02
# Date:                Sun, 09 Feb 2025   Deviance:                       700.04
# Time:                        11:58:31   Pearson chi2:                     666.
# No. Iterations:                     5   Pseudo R-squ. (CS):             0.1949
# Covariance Type:            nonrobust
# ===================================================================================================
#                                       coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------
# Intercept                          -3.5090      0.516     -6.797      0.000      -4.521      -2.497
# guarantees[T.Without guarantor]     1.2027      0.471      2.552      0.011       0.279       2.126
# savings[T.> 500 euros]             -0.6317      0.334     -1.894      0.058      -1.285       0.022
# savings[T.No savings]              -0.8654      0.277     -3.119      0.002      -1.409      -0.322
# predicted_prob                      5.1115      0.513      9.973      0.000       4.107       6.116
# ===================================================================================================
# AIC: 710.043995996226, BIC: 732.7993976714431, AUC: 0.7795
#
# Best model with 2 variables:
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:        presence_unpaid   No. Observations:                  700
# Model:                            GLM   Df Residuals:                      697
# Model Family:                Binomial   Df Model:                            2
# Link Function:                  Logit   Scale:                          1.0000
# Method:                          IRLS   Log-Likelihood:                -356.43
# Date:                Sun, 09 Feb 2025   Deviance:                       712.86
# Time:                        11:58:31   Pearson chi2:                     669.
# No. Iterations:                     5   Pseudo R-squ. (CS):             0.1800
# Covariance Type:            nonrobust
# ===================================================================================================
#                                       coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------
# Intercept                          -3.6259      0.515     -7.045      0.000      -4.635      -2.617
# guarantees[T.Without guarantor]     1.0453      0.469      2.228      0.026       0.126       1.965
# predicted_prob                      5.3187      0.504     10.547      0.000       4.330       6.307
# ===================================================================================================
# AIC: 718.8638309268842, BIC: 732.5170719320145, AUC: 0.7718
#
# Best model with 1 variables:
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:        presence_unpaid   No. Observations:                  700
# Model:                            GLM   Df Residuals:                      698
# Model Family:                Binomial   Df Model:                            1
# Link Function:                  Logit   Scale:                          1.0000
# Method:                          IRLS   Log-Likelihood:                -359.24
# Date:                Sun, 09 Feb 2025   Deviance:                       718.48
# Time:                        11:58:31   Pearson chi2:                     676.
# No. Iterations:                     4   Pseudo R-squ. (CS):             0.1734
# Covariance Type:            nonrobust
# ==================================================================================
#                      coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# Intercept         -2.5853      0.201    -12.835      0.000      -2.980      -2.191
# predicted_prob     5.1903      0.497     10.438      0.000       4.216       6.165
# ==================================================================================
# AIC: 722.4841127091526, BIC: 731.5862733792394, AUC: 0.7670
# Reached the model with the smallest BIC. Stopping summary display.

# %% [markdown]
# At each stage, the variable whose exclusion results in the greatest reduction in the BIC is removed. The model has one more variable than the forward selection.

# %%
from sklearn.metrics import roc_auc_score

selected_variables = ['accounts', 'duration_credit', 'other_credits','guarantees', 'savings']

X_train = train[selected_variables]
X_test = test[selected_variables]

train['predicted_prob'] = model.predict(X_train)
test['predicted_prob'] = model.predict(X_test)

auc_train = roc_auc_score(train['presence_unpaid'], train['predicted_prob'])
auc_test = roc_auc_score(test['presence_unpaid'], test['predicted_prob'])

print(f'AUC on the train sample : {auc_train}')
print(f'AUC on the test sample : {auc_test}')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# File /var/data/python/lib/python3.12/site-packages/patsy/compat.py:40, in call_and_wrap_exc(msg, origin, f, *args, **kwargs)
#      39 try:
# ---> 40     return f(*args, **kwargs)
#      41 except Exception as e:
#
# File /var/data/python/lib/python3.12/site-packages/patsy/eval.py:179, in EvalEnvironment.eval(self, expr, source_name, inner_namespace)
#     178 code = compile(expr, source_name, "eval", self.flags, False)
# --> 179 return eval(code, {}, VarLookupDict([inner_namespace] + self._namespaces))
#
# File <string>:1
#
# NameError: name 'predicted_prob' is not defined
#
# The above exception was the direct cause of the following exception:
#
# PatsyError                                Traceback (most recent call last)
# File /var/data/python/lib/python3.12/site-packages/statsmodels/base/model.py:1102, in Results._transform_predict_exog(self, exog, transform)
#    1101 try:
# -> 1102     exog = dmatrix(design_info, exog, return_type="dataframe")
#    1103 except Exception as exc:
#
# File /var/data/python/lib/python3.12/site-packages/patsy/highlevel.py:296, in dmatrix(formula_like, data, eval_env, NA_action, return_type)
#     295 eval_env = EvalEnvironment.capture(eval_env, reference=1)
# --> 296 (lhs, rhs) = _do_highlevel_design(
#     297     formula_like, data, eval_env, NA_action, return_type
#     298 )
#     299 if lhs.shape[1] != 0:
#
# File /var/data/python/lib/python3.12/site-packages/patsy/highlevel.py:168, in _do_highlevel_design(formula_like, data, eval_env, NA_action, return_type)
#     167 if design_infos is not None:
# --> 168     return build_design_matrices(
#     169         design_infos, data, NA_action=NA_action, return_type=return_type
#     170     )
#     171 else:
#     172     # No builders, but maybe we can still get matrices
#
# File /var/data/python/lib/python3.12/site-packages/patsy/build.py:954, in build_design_matrices(design_infos, data, NA_action, return_type, dtype)
#     953 if factor_info not in factor_info_to_values:
# --> 954     value, is_NA = _eval_factor(factor_info, data, NA_action)
#     955     factor_info_to_isNAs[factor_info] = is_NA
#
# File /var/data/python/lib/python3.12/site-packages/patsy/build.py:68, in _eval_factor(factor_info, data, NA_action)
#      67 factor = factor_info.factor
# ---> 68 result = factor.eval(factor_info.state, data)
#      69 # Returns either a 2d ndarray, or a DataFrame, plus is_NA mask
#
# File /var/data/python/lib/python3.12/site-packages/patsy/eval.py:599, in EvalFactor.eval(self, memorize_state, data)
#     598 def eval(self, memorize_state, data):
# --> 599     return self._eval(memorize_state["eval_code"], memorize_state, data)
#
# File /var/data/python/lib/python3.12/site-packages/patsy/eval.py:582, in EvalFactor._eval(self, code, memorize_state, data)
#     581 inner_namespace = VarLookupDict([data, memorize_state["transforms"]])
# --> 582 return call_and_wrap_exc(
#     583     "Error evaluating factor",
#     584     self,
#     585     memorize_state["eval_env"].eval,
#     586     code,
#     587     inner_namespace=inner_namespace,
#     588 )
#
# File /var/data/python/lib/python3.12/site-packages/patsy/compat.py:43, in call_and_wrap_exc(msg, origin, f, *args, **kwargs)
#      42 new_exc = PatsyError("%s: %s: %s" % (msg, e.__class__.__name__, e), origin)
# ---> 43 raise new_exc from e
#
# PatsyError: Error evaluating factor: NameError: name 'predicted_prob' is not defined
#     presence_unpaid ~ predicted_prob
#                       ^^^^^^^^^^^^^^
#
# During handling of the above exception, another exception occurred:
#
# PatsyError                                Traceback (most recent call last)
# Cell In[13], line 8
#       5 X_train = train[selected_variables]
#       6 X_test = test[selected_variables]
# ----> 8 train['predicted_prob'] = model.predict(X_train)
#       9 test['predicted_prob'] = model.predict(X_test)
#      11 auc_train = roc_auc_score(train['presence_unpaid'], train['predicted_prob'])
#
# File /var/data/python/lib/python3.12/site-packages/statsmodels/base/model.py:1171, in Results.predict(self, exog, transform, *args, **kwargs)
#    1126 def predict(self, exog=None, transform=True, *args, **kwargs):
#    1127     """
#    1128     Call self.model.predict with self.params as the first argument.
#    1129
#    (...)
#    1169     returned prediction.
#    1170     """
# -> 1171     exog, exog_index = self._transform_predict_exog(exog,
#    1172                                                     transform=transform)
#    1174     predict_results = self.model.predict(self.params, exog, *args,
#    1175                                          **kwargs)
#    1177     if exog_index is not None and not hasattr(predict_results,
#    1178                                               'predicted_values'):
#
# File /var/data/python/lib/python3.12/site-packages/statsmodels/base/model.py:1109, in Results._transform_predict_exog(self, exog, transform)
#    1103 except Exception as exc:
#    1104     msg = ('predict requires that you use a DataFrame when '
#    1105            'predicting from a model\nthat was created using the '
#    1106            'formula api.'
#    1107            '\n\nThe original error message returned by patsy is:\n'
#    1108            '{}'.format(str(str(exc))))
# -> 1109     raise exc.__class__(msg)
#    1110 if orig_exog_len > len(exog) and not is_dict:
#    1111     if exog_index is None:
#
# PatsyError: predict requires that you use a DataFrame when predicting from a model
# that was created using the formula api.
#
# The original error message returned by patsy is:
# Error evaluating factor: NameError: name 'predicted_prob' is not defined
#     presence_unpaid ~ predicted_prob
#                       ^^^^^^^^^^^^^^

# %% [markdown]
# This model is much more generalized than the first one with a Area Under Curve at 0.774 versus 0.739 in the test sample with the BIC criterion.

# %% [markdown]
# ## Logistic Regression with global variable selection

# %% [markdown]
# Step-by-step variable selection has a significant drawback: the optimal model with p+1 variables is often not achieved by simply adding a variable to the best model with pp variables. Specifically, the variable that is chosen first in a stepwise method, based on a particular statistical criterion, does not always end up being part of the best model when considering pp variables (p>1).
#
# To identify the best p-variable model, we would theoretically have to fit and evaluate all the possible p-variable models from the set of n available explanatory variables, i.e. a number of models as large as the number of combinations
#
# $$
# \Big( \begin{array}{c} n \\ p \end{array} \Big)
# $$
#
# We therefore make a global selection.
#
# An algorithm for optimised scanning of the set of possible models was invented by Furnival and Wilson, known as the ‘leaps and bounds’ algorithm.
#
# This algorithm gives itself a fitting criterion F(m) to be minimised in order to obtain the best model m, and defines the criterion F(M) for a set M of models as F(M) = F(ppcm(M)), where ppcm(M) is the smallest super-model of M : the model containing all the predictors that appear at least once in a model of M. If at any point in the search we obtain a model
#
# $$
# m \in M
# $$
#
# which has a criterion
#
# $$
# F(m) < F(M)
# $$
#
# then m will necessarily be greater than all the models of M, which do not need to be evaluated individually.
#
# This optimisation of the exploration of all possible cases means that calculation times remain acceptable, at least if
#
# $$
# p \leq 40
# $$
#
# This algorithm is generally implemented for linear regression, adjusted by the ordinary least squares method, with an F(m) adjustment criterion which can be the
#
# $$
# R^2
# $$
# ,
# the
# $$
# ajusted\,R^2
# $$
# ,
# the Mallows Cp, the BIC and so on.
#
# For each variable i for which the variable to be explained is $$ y_i $$ and the a posteriori probability provided by the logistic model is $$ p_i $$, we pose :
#
# $$
# Weight(i) = p_i(1-p_i)
# $$
#
# $$
# V(i) = log \Big(\frac{P_i}{1 - p_i}\Big) + \frac{y_i - p_i}{p_i(1-p_i)}
# $$
#
# The V-adjusted linear model provides the same maximum likelihood estimators for the coefficients of the explanatory variables as those provided by the Y-adjusted logistic model. Hosmer and Lemeshow suggest implementing this remarkable property by first fitting the logistic model to all the explanatory variables. they deduce the variables Weight and V, and run a linkage regression with Furnival and Wilson global selection.

# %%
# Ce code implémente une méthode de sélection de modèle pour la régression logistique en utilisant le critère d'information d'Akaike (AIC).
# Il utilise la bibliothèque statsmodels pour ajuster des modèles de régression logistique et sklearn pour calculer l'AUC (Area Under the Curve).

# On commence par importer les bibliothèques nécessaires : statsmodels pour la modélisation statistique, pandas pour la manipulation de données,
# itertools et random pour générer des combinaisons aléatoires de prédicteurs, et sklearn pour évaluer la performance du modèle.

import statsmodels.api as sm
import statsmodels.formula.api as smf
import pandas as pd
import itertools
import random
from sklearn.metrics import roc_auc_score  

# On définit les prédicteurs comme toutes les colonnes du jeu de données d'entraînement sauf 'presence_unpaid', qui est la variable cible.
predictors = train.columns.difference(['presence_unpaid']).tolist()

# On initialise les variables pour suivre le meilleur modèle selon l'AIC, ainsi que d'autres informations sur les modèles testés.
best_aic = float('inf')  # L'AIC du meilleur modèle trouvé, initialisé à l'infini pour garantir qu'un modèle sera sélectionné.
best_model = None  # Le meilleur modèle trouvé.
best_formula = ''  # La formule du meilleur modèle.
max_iterations = 100  # Le nombre maximum d'itérations pour essayer différentes combinaisons de prédicteurs.
model_info = []  # Une liste pour stocker les informations sur chaque modèle testé.

best_models = {}  # Un dictionnaire pour stocker le meilleur modèle pour chaque nombre de prédicteurs.

# On effectue une boucle pour un nombre défini d'itérations afin de tester différentes combinaisons de prédicteurs.
for iteration in range(max_iterations):
    # On choisit un nombre aléatoire de prédicteurs à inclure dans le modèle.
    k = random.randint(1, len(predictors))
    # On sélectionne aléatoirement k prédicteurs parmi la liste des prédicteurs.
    combo = random.sample(predictors, k)
    # On crée une formule de modèle de régression logistique avec les prédicteurs sélectionnés.
    trial_formula = 'presence_unpaid ~ ' + ' + '.join(combo)
    # On ajuste le modèle de régression logistique en utilisant la formule créée.
    trial_model = smf.glm(formula=trial_formula, 
                          data=train, 
                          family=sm.families.Binomial()).fit()

    # On prédit les probabilités sur le jeu de données de test.
    X_test = test[combo]  
    predicted_probabilities = trial_model.predict(X_test)
    # On calcule l'AUC pour évaluer la performance du modèle.
    auc = roc_auc_score(test['presence_unpaid'], predicted_probabilities)

    # On récupère l'AIC et le BIC du modèle ajusté.
    trial_aic = trial_model.aic
    trial_bic = trial_model.bic_llf  # Utilisation de bic_llf au lieu de bic

    # On stocke les informations sur le modèle testé.
    model_info.append({
        'Predictors': combo,
        'AIC': trial_aic,
        'BIC': trial_bic,
        'AUC': auc
    })

    # Si l'AIC du modèle testé est meilleur que le meilleur AIC trouvé jusqu'à présent, on met à jour le meilleur modèle.
    if trial_aic < best_aic:
        best_aic = trial_aic
        best_model = trial_model
        best_formula = trial_formula

    # On stocke le meilleur modèle pour chaque nombre de prédicteurs.
    if k not in best_models or trial_aic < best_models[k][0]:
        best_models[k] = (trial_aic, trial_bic, trial_model, trial_formula, auc)

# On crée un DataFrame pour afficher les informations sur tous les modèles testés.
df_model_info = pd.DataFrame(model_info)

# On affiche le résumé du meilleur modèle trouvé selon l'AIC.
print("Best global model according to the AIC:")
print(best_model.summary())
print(f"AIC: {best_aic}, BIC: {best_model.bic_llf}, AUC: {auc}")
# Out:
# Best global model according to the AIC:
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:        presence_unpaid   No. Observations:                  700
# Model:                            GLM   Df Residuals:                      667
# Model Family:                Binomial   Df Model:                           32
# Link Function:                  Logit   Scale:                          1.0000
# Method:                          IRLS   Log-Likelihood:                -327.76
# Date:                Fri, 14 Feb 2025   Deviance:                       655.51
# Time:                        22:30:16   Pearson chi2:                     658.
# No. Iterations:                     5   Pseudo R-squ. (CS):             0.2445
# Covariance Type:            nonrobust
# ================================================================================================================
#                                                    coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------------------
# Intercept                                       -0.6973      1.208     -0.577      0.564      -3.064       1.670
# family_status[T.Male divorced/separated]         0.6231      0.433      1.440      0.150      -0.225       1.471
# family_status[T.Male single/married/widowed]    -0.6190      0.225     -2.751      0.006      -1.060      -0.178
# guarantees[T.Without guarantor]                  0.9039      0.478      1.893      0.058      -0.032       1.840
# duration_credit[T.[15.0, 36.0)]                  0.6001      0.237      2.532      0.011       0.136       1.065
# duration_credit[T.[36.0, inf)]                   1.1164      0.337      3.312      0.001       0.456       1.777
# other_credits[T.No external credit]             -0.7231      0.245     -2.946      0.003      -1.204      -0.242
# telephone[T.A192]                               -0.2209      0.225     -0.980      0.327      -0.663       0.221
# history_credit[T.A31]                           -0.1040      0.663     -0.157      0.875      -1.404       1.196
# history_credit[T.A32]                           -0.5673      0.554     -1.024      0.306      -1.653       0.519
# history_credit[T.A33]                           -0.9805      0.589     -1.663      0.096      -2.136       0.175
# history_credit[T.A34]                           -1.4172      0.554     -2.558      0.011      -2.503      -0.331
# age[T.[25.0, inf)]                              -0.4069      0.281     -1.449      0.147      -0.957       0.144
# amount_credit[T.[4000.0, inf)]                   0.5923      0.289      2.048      0.041       0.025       1.159
# savings[T.> 500 euros]                          -0.6511      0.358     -1.818      0.069      -1.353       0.051
# savings[T.No savings]                           -0.9506      0.298     -3.194      0.001      -1.534      -0.367
# object_credit[T.Education]                      -0.3192      1.279     -0.250      0.803      -2.825       2.187
# object_credit[T.Interior]                        0.2970      0.386      0.770      0.442      -0.459       1.053
# object_credit[T.New car]                         0.6665      0.384      1.738      0.082      -0.085       1.418
# object_credit[T.Other]                          -0.7166      0.891     -0.805      0.421      -2.462       1.029
# object_credit[T.Studies]                         0.7812      0.511      1.530      0.126      -0.220       1.782
# object_credit[T.Used car]                       -0.4918      0.505     -0.974      0.330      -1.481       0.498
# object_credit[T.Video-HIFI]                      0.0369      0.390      0.094      0.925      -0.728       0.802
# job_type[T.A172]                                -0.5796      0.685     -0.846      0.397      -1.922       0.763
# job_type[T.A173]                                -0.6282      0.665     -0.944      0.345      -1.932       0.676
# job_type[T.A174]                                -0.3002      0.716     -0.419      0.675      -1.703       1.103
# accounts[T.CC > 200 euros]                      -0.7547      0.428     -1.763      0.078      -1.594       0.084
# accounts[T.CC [0-200 euros]]                    -0.2369      0.240     -0.986      0.324      -0.708       0.234
# accounts[T.No account]                          -1.7970      0.271     -6.637      0.000      -2.328      -1.266
# nb_of_dependants                                 0.2212      0.279      0.792      0.428      -0.326       0.769
# home_old                                         0.0366      0.089      0.410      0.682      -0.138       0.212
# effort_rate                                      0.2600      0.096      2.710      0.007       0.072       0.448
# nb_credits                                       0.3512      0.220      1.597      0.110      -0.080       0.782
# ================================================================================================================
# AIC: 721.5120774295463, BIC: 871.6977284859786, AUC: 0.790133779264214

# %% [markdown]
# The global model selects 17 variables based on AIC criterion

# %%
best_predictors = [info['Predictors'] for info in model_info if info['AIC'] == best_aic]

print("Selected variables in the best model according to AIC:")
print(best_predictors)
# Out:
# Selected variables in the best model according to AIC:
# [['family_status', 'guarantees', 'nb_of_dependants', 'duration_credit', 'other_credits', 'telephone', 'history_credit', 'age', 'home_old', 'amount_credit', 'savings', 'effort_rate', 'object_credit', 'nb_credits', 'job_type', 'accounts']]

# %% [markdown]
# As the Mallows' Cp is close to AIC, we will see if the selection of variables is the same.

# %% [markdown]
# Mallows' Cp is defined by:
# $$
# C_p​=\frac{RSS_p}{σ^2}​​−(n−2p)
# $$
#
# where:
#
# $$
# RSS_p
# $$
#
# is the sum of squared residuals for the model with pp predictors.
# $$
# σ^2
# $$
#
# is the variance of the residual errors estimated from a full model.
#
# $$
# n
# $$
# is the number of observations.
#
# $$
# p
# $$
# is the number of predictors in the model.

# %%
import matplotlib.pyplot as plt
import pandas as pd

model_info2 = []

full_model_formula = 'presence_unpaid ~ ' + ' + '.join(predictors)
full_model = smf.glm(formula=full_model_formula, data=train, family=sm.families.Binomial()).fit()
sigma_squared = sum(full_model.resid_response ** 2) / full_model.df_resid

n = len(train)

for info in model_info:
    k = len(info['Predictors'])  
    
    trial_formula = 'presence_unpaid ~ ' + ' + '.join(info['Predictors'])
    trial_model = smf.glm(formula=trial_formula, data=train, family=sm.families.Binomial()).fit()
    rss_p = sum(trial_model.resid_response ** 2)
    
    cp = (rss_p / sigma_squared) - (n - 2 * k)
    
    model_info2.append({
        'Model Size': k, 
        'Cp': cp
    })

df_model_info2 = pd.DataFrame(model_info2)

df_mean_cp = df_model_info2.groupby('Model Size', as_index=False).mean()

plt.figure(figsize=(10, 6))
plt.plot(df_mean_cp['Model Size'], df_mean_cp['Cp'], marker='o', linestyle='-', color='b')
plt.title('Mallows Cp according to Model Size')
plt.xlabel('Model size (number of predictors)')
plt.ylabel('Mallows Cp')
plt.grid(True)
plt.xticks(range(0, len(predictors) + 1, 5)) 
plt.show()

# %%
best_cp_model = df_mean_cp[df_mean_cp['Cp'] == df_mean_cp['Cp'].min()]
print(f"Best model by Cp:")
print(best_cp_model)
# Out:
# Best model by Cp:
#     Model Size   Cp
# 18          19 -1.0

# %% [markdown]
# The 'size' component gives the number of modalities (including the constant) in each model, while the 'Cp' component gives the value of its Mallows Cp, a criterion close to the AIC.
#
# This figure shows that the minimum Cp is reached for 19 explanatory variables (with the intercept), which is a high value. This is because the Cp is not the most penalising criterion for complexity: it is less so than the BIC.

# %%
min_cp_row = df_model_info2.loc[df_model_info2['Cp'].idxmin()]

min_cp_model_size = int(min_cp_row['Model Size'])

best_predictors_cp_list = [info['Predictors'] for info in model_info if len(info['Predictors']) == min_cp_model_size]

best_predictors_cp = best_predictors_cp_list[0] if best_predictors_cp_list else []

print("Selected variables in the best model according to Mallows Cp:")
print(best_predictors_cp)
# Out:
# Selected variables in the best model according to Mallows Cp:
# ['effort_rate', 'nb_credits', 'property', 'age', 'other_credits', 'nb_of_dependants', 'accounts', 'home_status', 'guarantees', 'object_credit', 'savings', 'amount_credit', 'home_old', 'duration_credit', 'family_status', 'employment_old']

# %% [markdown]
# We see in this selection based on Cp (18 modalities if we remove the intercept) that is the same selection than the AIC but with one additional variable :
#
# * 'object_credit'
#
# For the rest of our study, we will take this global selection of variables according to Cp.

# %%
min_cp_row = df_model_info2.loc[df_model_info2['Cp'].idxmin()]

min_cp_model_size = int(min_cp_row['Model Size'])

best_predictors_cp_list = [info['Predictors'] for info in model_info if len(info['Predictors']) == min_cp_model_size]

best_predictors_cp = best_predictors_cp_list[0] if best_predictors_cp_list else []

selected_variables_with_modalities = []

print("Selected variables and their modalities in the best model according to Mallows Cp:")

for predictor in best_predictors_cp:
    formula_component = f'presence_unpaid ~ {predictor}'
    trial_model = smf.glm(formula=formula_component, data=train, family=sm.families.Binomial()).fit()
    
    for param in trial_model.params.index:
        if param == 'Intercept':
            continue
        print(param)
# Out:
# Selected variables and their modalities in the best model according to Mallows Cp:
# effort_rate
# nb_credits
# property[T.Non-property]
# property[T.Not real estate]
# property[T.Property]
# age[T.[25.0, inf)]
# other_credits[T.No external credit]
# nb_of_dependants
# accounts[T.CC > 200 euros]
# accounts[T.CC [0-200 euros]]
# accounts[T.No account]
# home_status[T.owner]
# guarantees[T.Without guarantor]
# object_credit[T.Education]
# object_credit[T.Interior]
# object_credit[T.New car]
# object_credit[T.Other]
# object_credit[T.Studies]
# object_credit[T.Used car]
# object_credit[T.Video-HIFI]
# savings[T.> 500 euros]
# savings[T.No savings]
# amount_credit[T.[4000.0, inf)]
# home_old
# duration_credit[T.[15.0, 36.0)]
# duration_credit[T.[36.0, inf)]
# family_status[T.Male divorced/separated]
# family_status[T.Male single/married/widowed]
# employment_old[T.between 1 and 4 years]
# employment_old[T.for at least 4 years]

# %% [markdown]
# We run a global selection again with an iteration of 1000 and a max variable number of 16.

# %%
import statsmodels.api as sm
import statsmodels.formula.api as smf
import pandas as pd
import itertools
import random
from sklearn.metrics import roc_auc_score


predictors = train.columns.difference(['presence_unpaid']).tolist()
best_aic = float('inf')
best_bic = float('inf')
best_model = None
best_formula = ''
best_auc = 0
max_iterations = 1000 
max_predictors = 16  

best_models = {}

for iteration in range(max_iterations):
    k = random.randint(1, max_predictors)  
    combo = random.sample(predictors, k) 
    trial_formula = 'presence_unpaid ~ ' + ' + '.join(combo)
    trial_model = smf.glm(formula=trial_formula, data=train, family=sm.families.Binomial()).fit()
    trial_aic = trial_model.aic
    trial_bic = trial_model.bic_llf
    
    y_pred_prob = trial_model.predict(train)
    
    trial_auc = roc_auc_score(train['presence_unpaid'], y_pred_prob)
    
    if trial_aic < best_aic:
        best_aic = trial_aic
        best_bic = trial_bic
        best_model = trial_model
        best_formula = trial_formula
        best_auc = trial_auc

        best_models[k] = (best_aic, best_bic, best_auc, best_model, best_formula)


print(f"Best global model according to the AIC:")
print(best_model.summary())
print(f"AIC: {best_aic}, BIC: {best_bic}, AUC: {best_auc:.4f}")
# Out:
# Best global model according to the AIC:
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:        presence_unpaid   No. Observations:                  700
# Model:                            GLM   Df Residuals:                      676
# Model Family:                Binomial   Df Model:                           23
# Link Function:                  Logit   Scale:                          1.0000
# Method:                          IRLS   Log-Likelihood:                -335.00
# Date:                Fri, 14 Feb 2025   Deviance:                       670.00
# Time:                        22:31:20   Pearson chi2:                     664.
# No. Iterations:                     5   Pseudo R-squ. (CS):             0.2287
# Covariance Type:            nonrobust
# ================================================================================================================
#                                                    coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------------------
# Intercept                                       -0.5091      0.914     -0.557      0.578      -2.301       1.282
# guarantees[T.Without guarantor]                  1.0236      0.475      2.157      0.031       0.093       1.954
# history_credit[T.A31]                           -0.3818      0.620     -0.615      0.538      -1.598       0.834
# history_credit[T.A32]                           -0.7797      0.513     -1.521      0.128      -1.785       0.225
# history_credit[T.A33]                           -0.9329      0.573     -1.627      0.104      -2.057       0.191
# history_credit[T.A34]                           -1.2359      0.534     -2.314      0.021      -2.283      -0.189
# family_status[T.Male divorced/separated]         0.6047      0.421      1.438      0.151      -0.220       1.429
# family_status[T.Male single/married/widowed]    -0.6128      0.223     -2.742      0.006      -1.051      -0.175
# amount_credit[T.[4000.0, inf)]                   0.4441      0.268      1.655      0.098      -0.082       0.970
# accounts[T.CC > 200 euros]                      -0.7481      0.418     -1.791      0.073      -1.567       0.071
# accounts[T.CC [0-200 euros]]                    -0.2822      0.234     -1.208      0.227      -0.740       0.176
# accounts[T.No account]                          -1.8295      0.269     -6.814      0.000      -2.356      -1.303
# savings[T.> 500 euros]                          -0.6494      0.353     -1.838      0.066      -1.342       0.043
# savings[T.No savings]                           -0.9265      0.291     -3.183      0.001      -1.497      -0.356
# duration_credit[T.[15.0, 36.0)]                  0.4632      0.225      2.060      0.039       0.023       0.904
# duration_credit[T.[36.0, inf)]                   0.9640      0.325      2.962      0.003       0.326       1.602
# other_credits[T.No external credit]             -0.6915      0.237     -2.913      0.004      -1.157      -0.226
# employment_old[T.between 1 and 4 years]         -0.0762      0.251     -0.304      0.761      -0.567       0.415
# employment_old[T.for at least 4 years]          -0.3653      0.256     -1.425      0.154      -0.868       0.137
# age[T.[25.0, inf)]                              -0.2343      0.278     -0.844      0.399      -0.778       0.310
# home_status[T.owner]                            -0.1771      0.226     -0.784      0.433      -0.620       0.266
# nb_of_dependants                                 0.3314      0.271      1.225      0.220      -0.199       0.862
# home_old                                         0.0342      0.094      0.364      0.716      -0.150       0.218
# effort_rate                                      0.2669      0.093      2.882      0.004       0.085       0.448
# ================================================================================================================
# AIC: 718.0008752644151, BIC: 827.2268033054568, AUC: 0.8015

# %%
import matplotlib.pyplot as plt

num_predictors = list(best_models.keys())
aics = [best_models[k][0] for k in best_models]
bics = [best_models[k][1] for k in best_models]

sorted_indices = sorted(range(len(num_predictors)), key=lambda idx: num_predictors[idx])
num_predictors_sorted = [num_predictors[idx] for idx in sorted_indices]
aics_sorted = [aics[idx] for idx in sorted_indices]
bics_sorted = [bics[idx] for idx in sorted_indices]

# The chart for the AIC
plt.figure(figsize=(10, 6))
plt.plot(num_predictors_sorted, aics_sorted, marker='o', linestyle='-', color='b')
plt.title('AIC according to the number of predictors')
plt.xlabel('Number of predictors')
plt.ylabel('AIC')
plt.grid(True)
plt.show()

# The char for the BIC
plt.figure(figsize=(10, 6))
plt.plot(num_predictors_sorted, bics_sorted, marker='o', linestyle='-', color='r')
plt.title('BIC according to the number of predictors')
plt.xlabel('Number of predictors')
plt.ylabel('BIC')
plt.grid(True)
plt.show()

# %% [markdown]
# According to the AIC, the optimum number of predictors for this global selection is 15.

# %%
from sklearn.metrics import roc_auc_score

X_train = train[predictors]
X_test = test[predictors]

train['predicted_prob'] = best_model.predict(X_train)
test['predicted_prob'] = best_model.predict(X_test)

auc_train = roc_auc_score(train['presence_unpaid'], train['predicted_prob'])
auc_test = roc_auc_score(test['presence_unpaid'], test['predicted_prob'])

print(f'AUC on the train sample : {auc_train}')
print(f'AUC on the test sample : {auc_test}')
# Out:
# AUC on the train sample : 0.8015165728580363
# AUC on the test sample : 0.8118990384615385

# %% [markdown]
# The best models reach an Area Under the Curve ROC in test equal to 0.806 with 15 indicators, that is a little bit better than the 0.782 obtained with step-by-step forward selection, with a 8 numbers of indicators.

# %% [markdown]
# ## Search for predictors maximising the area under the ROC curve

# %% [markdown]
# A possible extension of global selection is to identify the predictors that lead to the best models in terms of area under the ROC curve. We have to relaunch a global selection in the order to have a dataframe with "size", "AUC" and "Cp" of all models.

# %%
import pandas as pd
import numpy as np
import statsmodels.api as sm
from sklearn.metrics import roc_auc_score
from mlxtend.feature_selection import SequentialFeatureSelector as SFS
from sklearn.linear_model import LogisticRegression

# Ensure all data is numeric
x = pd.get_dummies(train.drop(columns=['presence_unpaid']), drop_first=True).astype(float)
y = train['presence_unpaid']
z = pd.concat([x, y.rename('y')], axis=1)
xt = pd.get_dummies(test.drop(columns=['presence_unpaid']), drop_first=True).astype(float)

logreg = LogisticRegression(solver='liblinear')
sfs = SFS(logreg, 
          k_features='best', 
          forward=True, 
          floating=False, 
          scoring='neg_mean_squared_error', 
          cv=0, 
          n_jobs=-1)

sfs = sfs.fit(x, y)

selected_models = sfs.subsets_

nmodel = len(selected_models)
n_features = x.shape[1]
aucfw = np.full((nmodel, 3), np.nan)
models = np.full((nmodel, n_features + 1), np.nan)

for i, (key, value) in enumerate(selected_models.items()):
    best_features_idx = list(value['feature_idx'])
    best_model_columns = x.columns[best_features_idx]
    formula = "y ~ " + " + ".join(best_model_columns)
    
    logit_model = sm.Logit(z['y'], sm.add_constant(z[best_model_columns])).fit(disp=0)
    
    prob = logit_model.predict(sm.add_constant(xt[best_model_columns]))
    
    auc = roc_auc_score(test['presence_unpaid'], prob)
    
    aucfw[i, 0] = len(best_features_idx)
    aucfw[i, 1] = auc
    models[i, :n_features] = np.isin(np.arange(n_features), best_features_idx).astype(int)
    models[i, n_features] = auc
    aucfw[i, 2] = value['avg_score']  

aucfw_df = pd.DataFrame(aucfw, columns=["size", "AUC", "Cp"])
selglob = aucfw_df.sort_values(by="AUC", ascending=False)

print(selglob)
# Out:
#     size       AUC        Cp
# 23  24.0  0.830816 -0.212857
# 29  30.0  0.830764 -0.218571
# 24  25.0  0.830346 -0.208571
# 20  21.0  0.830189 -0.215714
# 30  31.0  0.830032 -0.218571
# 22  23.0  0.829980 -0.214286
# 21  22.0  0.829092 -0.214286
# 25  26.0  0.828987 -0.210000
# 28  29.0  0.828883 -0.215714
# 27  28.0  0.828308 -0.214286
# 33  34.0  0.827498 -0.222857
# 31  32.0  0.826688 -0.220000
# 26  27.0  0.826636 -0.211429
# 3    4.0  0.825486 -0.234286
# 1    2.0  0.825016 -0.240000
# 32  33.0  0.824833 -0.221429
# 2    3.0  0.824441 -0.235714
# 4    5.0  0.823552 -0.232857
# 38  39.0  0.822115 -0.230000
# 34  35.0  0.821593 -0.224286
# 35  36.0  0.821541 -0.224286
# 37  38.0  0.821332 -0.228571
# 6    7.0  0.820103 -0.230000
# 7    8.0  0.819947 -0.227143
# 14  15.0  0.819738 -0.220000
# 8    9.0  0.819738 -0.224286
# 36  37.0  0.819346 -0.225714
# 17  18.0  0.819267 -0.214286
# 15  16.0  0.819215 -0.218571
# 16  17.0  0.818902 -0.214286
# 18  19.0  0.818588 -0.214286
# 19  20.0  0.818274 -0.214286
# 9   10.0  0.817543 -0.222857
# 10  11.0  0.816602 -0.222857
# 5    6.0  0.815975 -0.232857
# 11  12.0  0.815975 -0.222857
# 12  13.0  0.815139 -0.221429
# 13  14.0  0.814878 -0.221429
# 0    1.0  0.811899 -0.245714

# %%
import matplotlib.pyplot as plt

feature_counts = np.sum(models[:, :n_features], axis=0)

feature_importance_df = pd.DataFrame({
    'Feature': x.columns,
    'Importance': feature_counts  
})

feature_importance_df = feature_importance_df.sort_values(by='Importance', ascending=False)

plt.figure(figsize=(10, 8))
plt.barh(feature_importance_df['Feature'], feature_importance_df['Importance'], color='skyblue')
plt.xlabel('Frequency of Selection')
plt.ylabel('Features')
plt.title('Very Important Features')
plt.gca().invert_yaxis()  
plt.show()

# %%
import matplotlib.pyplot as plt

auc_contributions = np.zeros(n_features)

for i in range(nmodel):
    selected_features = models[i, :n_features].astype(bool)
    auc_contributions[selected_features] += aucfw[i, 1]

feature_auc_mean = auc_contributions / np.sum(models[:, :n_features], axis=0)

feature_auc_df = pd.DataFrame({
    'Feature': x.columns,
    'AUC': feature_auc_mean
})

feature_auc_df = feature_auc_df.sort_values(by='AUC', ascending=False)

plt.figure(figsize=(10, 8))
plt.barh(feature_auc_df['Feature'], feature_auc_df['AUC'], color='skyblue')
plt.xlabel('Average AUC Contribution')
plt.ylabel('Features')
plt.title('Feature Importance in Terms of AUC')
plt.gca().invert_yaxis()  
plt.show()

# %%
import matplotlib.pyplot as plt

if 'size' in aucfw_df.columns and 'Cp' in aucfw_df.columns:
    
    plt.figure(figsize=(10, 6))
    plt.plot(aucfw_df['size'], aucfw_df['Cp'], marker='o', linestyle='-', color='b')
    plt.xlabel('Model size (number of features)')
    plt.ylabel('BIC (Bayes Information Criterion)')
    plt.title('BIC depending on model size')
    plt.grid(True)
    plt.show()
else:
    print("The 'size' and 'Cp' columns are missing from the DataFrame.")

# %% [markdown]
# ### Modelling with all possible combinations of variables

# %% [markdown]
# The construction of the discriminant model by global selection of variables proved tedious because we had to rework the values so that the codes rotated from one cell to another.
#
# So here we return to the approach taken by the author and his R code, who wants a more direct approach: fit models on all possible crossings of *p* variables from the set of *n* explanatory variables available, and evaluate them.
#
# This means ajusting
#
# $$
# \Big( \begin{array}{c} n \\ p \end{array} \Big)
# $$
#
# models, which is precisely what we wanted to avoid doing, by reverting to an optimised scanning algorithm.
#
# Using a limited sample size, we will show in this section that the direct approach is possible, and indeed quite straightforward.

# %%
from itertools import combinations
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import roc_auc_score
import pandas as pd
import numpy as np

def gini_coefficient(y_true, y_scores):
    """Calculating the Gini coefficient."""
    auc = roc_auc_score(y_true, y_scores)
    return 2 * auc - 1

def CombiRegR(apprent, validat, varY, varX, p):
    y = apprent[varY]  
    presence_unpaid = validat[varY]  
    combi = list(combinations(varX, p))  
    results = []  

    for s in combi:
        predicteurs = list(s)

        X_train = pd.get_dummies(apprent[predicteurs], drop_first=True)
        X_valid = pd.get_dummies(validat[predicteurs], drop_first=True)

        X_valid = X_valid.reindex(columns=X_train.columns, fill_value=0)

        logit = LogisticRegression(solver='liblinear')
        logit.fit(X_train, y)

        scores = logit.predict_proba(X_valid)[:, 1]
        auc = roc_auc_score(presence_unpaid, scores)
        gini = gini_coefficient(presence_unpaid, scores)

        result = {
            'auc': auc,
            'gini': gini,
            **{f'V{i+1}': pred for i, pred in enumerate(predicteurs)}
        }

        results.append(result)
    
    cr = pd.DataFrame(results)
    
    cr_sorted = cr.sort_values(by='gini', ascending=False).reset_index(drop=True)
    
    return cr_sorted


results_df = CombiRegR(apprent= train, validat=test, varY="presence_unpaid", varX=predictors, p=7)

results_df.head(20)
# Out:
#          auc      gini        V1             V2               V3  \
# 0   0.844638  0.689277  accounts            age    amount_credit
# 1   0.843959  0.687918  accounts  amount_credit      effort_rate
# 2   0.842783  0.685566  accounts  amount_credit      effort_rate
# 3   0.842156  0.684312  accounts  amount_credit      effort_rate
# 4   0.841398  0.682797  accounts  amount_credit      effort_rate
# 5   0.841346  0.682692  accounts  amount_credit      effort_rate
# 6   0.840588  0.681177  accounts  amount_credit      effort_rate
# 7   0.840249  0.680497  accounts            age    amount_credit
# 8   0.840223  0.680445  accounts  amount_credit      effort_rate
# 9   0.839491  0.678982  accounts            age    amount_credit
# 10  0.838890  0.677780  accounts            age    amount_credit
# 11  0.838786  0.677571  accounts  amount_credit      effort_rate
# 12  0.838786  0.677571  accounts  amount_credit      effort_rate
# 13  0.837897  0.675794  accounts            age    amount_credit
# 14  0.837714  0.675429  accounts  amount_credit      effort_rate
# 15  0.837531  0.675063  accounts  amount_credit      effort_rate
# 16  0.837035  0.674070  accounts  amount_credit  duration_credit
# 17  0.837009  0.674018  accounts            age    amount_credit
# 18  0.836486  0.672972  accounts  amount_credit      effort_rate
# 19  0.835990  0.671980  accounts  amount_credit      effort_rate
#
#                 V4              V5                V6             V7
# 0      effort_rate  employment_old    history_credit  object_credit
# 1   employment_old  history_credit     object_credit       property
# 2   employment_old  history_credit       home_status  object_credit
# 3   employment_old      guarantees    history_credit  object_credit
# 4   employment_old  history_credit     object_credit      telephone
# 5   employment_old  history_credit     object_credit        savings
# 6   history_credit     home_status     object_credit        savings
# 7      effort_rate  history_credit     object_credit        savings
# 8   employment_old  history_credit  nb_of_dependants  object_credit
# 9      effort_rate  history_credit       home_status  object_credit
# 10     effort_rate  history_credit     object_credit       property
# 11  employment_old  history_credit          job_type  object_credit
# 12  employment_old  history_credit          home_old  object_credit
# 13     effort_rate      guarantees    history_credit  object_credit
# 14      guarantees  history_credit       home_status  object_credit
# 15  history_credit     home_status     object_credit      telephone
# 16     effort_rate  employment_old    history_credit  object_credit
# 17     effort_rate  history_credit     object_credit      telephone
# 18  history_credit   object_credit          property      telephone
# 19  history_credit        home_old       home_status  object_credit

# %%
len(results_df)
# Out:
# 50388

# %% [markdown]
# By searching for all the combinations of 7 variables, the calculation takes around 30 minutes. More than 50,000 combinations have been found.
#
# We then put the results of the `cr` matrix into a dataframe, after transposing it so that the combinations are arranged in rows rather than columns. The columns show the area under the ROC curve and the list of variables in the combination.

# %% [markdown]
# > We note that it is posible to get a 7 variables model having an area under the curve on test equal to 0.844.
#
# These apparently highly discriminating models should be examined, as they are perhaps too complex, with insignificant coefficients, but this first result shows that a direct approach to global selection, testing all possible combinations of variables, is worth trying compared with the Furnival and Wilson method.

# %% [markdown]
# ### Final grouping of modalities

# %% [markdown]
# We return to the model obtained by stepwise forward selection, with the following 8 variables, and whose area under the ROC curve on the test sample is 0.782.
#
# > From there, we relanch the last forward selection code and its calculation of AUC

# %%
selected_variables
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 selected_variables
#
# NameError: name 'selected_variables' is not defined

# %% [markdown]
# Here are the groupings we have arrived at to solve the problem of the wide variety of modalities

# %%
import pandas as pd

credit2['accounts'] = credit2['accounts'].replace({
    'A14': 'No account',
    'A11': 'CC < 0',
    'A12': 'CC [0-200 euros[',
    'A13': 'CC > 200 euros'
})

credit2['history_credit'] = credit2['history_credit'].replace({
    'A30': 'Credits in arrears', 'A31': 'Credits in arrears',
    'A32': 'No credits or ongoing without delay', 'A33': 'No credits or ongoing without delay',
    'A34': 'Past credits without delay'
})

credit2['object_credit'] = credit2['object_credit'].replace({
    'A40': 'New car',
    'A41': 'Used car',
    'A42': 'Interior', 'A43': 'Interior', 'A45': 'Interior',
    'A46': 'Studies-business-Other', 'A48': 'Studies-business-Other', 'A410': 'Studies-business-Other',
    'A47': 'Vacations'
})

credit2['savings'] = credit2['savings'].replace({
    'A63': 'No savings or > 500 euros', 'A64': 'No savings or > 500 euros', 'A65': 'No savings or > 500 euros',
    'A61': '< 500 euros', 'A62': '< 500 euros'
})

credit2['employment_old'] = credit2['employment_old'].replace({
    'A71': 'Unemployed or < 1 year', 'A72': 'Unemployed or < 1 year',
    'A73': 'E [1-4[ years',
    'A74': 'E GE A years', 'A75': 'E GE A years'
})

credit2['family_status'] = credit2['family_status'].replace({
    'A91': 'Divorced/separated man',
    'A92': 'Divorced/separated/married woman',
    'A93': 'Single/married/widowed man', 'A94': 'Single/married/widowed man',
    'A95': 'Single woman'
})

credit2['guarantees'] = credit2['guarantees'].replace({'A103': 'With guarantor'})

credit2.loc[credit2['guarantees'] != 'With guarantor', 'guarantees'] = 'Without guarantor'

credit2['property'] = credit2['property'].replace({'A121': 'Real estate', 'A124': 'No assets'})

credit2.loc[~credit2['property'].isin(['Real estate', 'No assets']), 'property'] = 'Non-real estate'

credit2['other_credits'] = credit2['other_credits'].replace({'A143': 'No external credit'})

credit2.loc[credit2['other_credits'] != 'No external credit', 'other_credits'] = 'External credits'

credit2['home_status'] = credit2['home_status'].replace({'A152': 'Owner'})

credit2.loc[credit2['home_status'] != 'Owner', 'home_status'] = 'Non-owner'

# %% [markdown]
# Here the summary of the transformed base

# %%
import pandas as pd

print(credit2.describe())

for col in credit2.select_dtypes(include=['object', 'category']).columns:
    print(f"\nSummary of the column '{col}':")
    print(credit2[col].value_counts())
# Out:
#        effort_rate     home_old   nb_credits  nb_of_dependants  \
# count  1000.000000  1000.000000  1000.000000       1000.000000
# mean      2.973000     2.845000     1.407000          1.155000
# std       1.118715     1.103718     0.577654          0.362086
# min       1.000000     1.000000     1.000000          1.000000
# 25%       2.000000     2.000000     1.000000          1.000000
# 50%       3.000000     3.000000     1.000000          1.000000
# 75%       4.000000     4.000000     2.000000          1.000000
# max       4.000000     4.000000     4.000000          2.000000
#
#        presence_unpaid
# count      1000.000000
# mean          0.300000
# std           0.458487
# min           0.000000
# 25%           0.000000
# 50%           0.000000
# 75%           1.000000
# max           1.000000
#
# Summary of the column 'accounts':
# accounts
# No account          394
# CC < 0 euros        274
# CC [0-200 euros]    269
# CC > 200 euros       63
# Name: count, dtype: int64
#
# Summary of the column 'history_credit':
# history_credit
# No credits or ongoing without delay    618
# Past credits without delay             293
# Credits in arrears                      89
# Name: count, dtype: int64
#
# Summary of the column 'object_credit':
# object_credit
# Video-HIFI    280
# New car       234
# Interior      215
# Used car      103
# Business       97
# Studies        50
# Other          12
# Education       9
# Name: count, dtype: int64
#
# Summary of the column 'savings':
# savings
# < 500 euros    706
# No savings     183
# > 500 euros    111
# Name: count, dtype: int64
#
# Summary of the column 'employment_old':
# employment_old
# for at least 4 years      427
# between 1 and 4 years     339
# Unemployed or < 1 year    234
# Name: count, dtype: int64
#
# Summary of the column 'family_status':
# family_status
# Male single/married/widowed          640
# Female divorced/separated/married    310
# Male divorced/separated               50
# Name: count, dtype: int64
#
# Summary of the column 'guarantees':
# guarantees
# Without guarantor    948
# With guarantor        52
# Name: count, dtype: int64
#
# Summary of the column 'property':
# property
# Non-real estate    1000
# Name: count, dtype: int64
#
# Summary of the column 'other_credits':
# other_credits
# No external credit    814
# External credits      186
# Name: count, dtype: int64
#
# Summary of the column 'home_status':
# home_status
# Non-owner    1000
# Name: count, dtype: int64
#
# Summary of the column 'job_type':
# job_type
# A173    630
# A172    200
# A174    148
# A171     22
# Name: count, dtype: int64
#
# Summary of the column 'telephone':
# telephone
# A191    596
# A192    404
# Name: count, dtype: int64
#
# Summary of the column 'age':
# age
# [25.0, inf)    851
# [0.0, 25.0)    149
# Name: count, dtype: int64
#
# Summary of the column 'duration_credit':
# duration_credit
# [15.0, 36.0)    463
# [0.0, 15.0)     367
# [36.0, inf)     170
# Name: count, dtype: int64
#
# Summary of the column 'amount_credit':
# amount_credit
# [0.0, 4000.0)    754
# [4000.0, inf)    246
# Name: count, dtype: int64

# %% [markdown]
# And we create the train and test samples

# %%
# raw Python mode

import pandas as pd

test_size = 0.3

shuffled_data = credit2.sample(frac=1, random_state=42)

split_point = int(len(shuffled_data) * (1 - test_size))

train = shuffled_data.iloc[:split_point].reset_index(drop=True)
test = shuffled_data.iloc[split_point:].reset_index(drop=True)

# %%
train.head()
# Out:
#          accounts                       history_credit object_credit  \
# 0    CC < 0 euros  No credits or ongoing without delay    Video-HIFI
# 1    CC < 0 euros  No credits or ongoing without delay       New car
# 2    CC < 0 euros                   Credits in arrears       New car
# 3  CC > 200 euros  No credits or ongoing without delay    Video-HIFI
# 4      No account           Past credits without delay      Used car
#
#        savings         employment_old  effort_rate  \
# 0  < 500 euros  between 1 and 4 years            2
# 1  < 500 euros  between 1 and 4 years            3
# 2  < 500 euros   for at least 4 years            2
# 3  < 500 euros  between 1 and 4 years            3
# 4  < 500 euros   for at least 4 years            3
#
#                        family_status         guarantees  home_old  \
# 0  Female divorced/separated/married  Without guarantor         2
# 1        Male single/married/widowed  Without guarantor         4
# 2        Male single/married/widowed  Without guarantor         3
# 3        Male single/married/widowed  Without guarantor         4
# 4        Male single/married/widowed  Without guarantor         2
#
#           property       other_credits home_status  nb_credits job_type  \
# 0  Non-real estate  No external credit   Non-owner           1     A173
# 1  Non-real estate  No external credit   Non-owner           1     A172
# 2  Non-real estate    External credits   Non-owner           1     A173
# 3  Non-real estate  No external credit   Non-owner           1     A173
# 4  Non-real estate  No external credit   Non-owner           2     A174
#
#    nb_of_dependants telephone          age duration_credit  amount_credit  \
# 0                 1      A191  [0.0, 25.0)    [15.0, 36.0)  [0.0, 4000.0)
# 1                 2      A192  [25.0, inf)    [15.0, 36.0)  [4000.0, inf)
# 2                 1      A191  [25.0, inf)    [15.0, 36.0)  [0.0, 4000.0)
# 3                 1      A191  [0.0, 25.0)     [0.0, 15.0)  [0.0, 4000.0)
# 4                 1      A192  [25.0, inf)    [15.0, 36.0)  [4000.0, inf)
#
#    presence_unpaid
# 0                1
# 1                0
# 2                0
# 3                0
# 4                0

# %%
len(train)
# Out:
# 700

# %%
train["duration_credit"].unique()
# Out:
# array(['[15.0, 36.0)', '[0.0, 15.0)', '[36.0, inf)'], dtype=object)

# %% [markdown]
# ## Logit model chosen

# %% [markdown]
# Using the groupings from the previous section, we readjusted the logistic model and removed variables that did not contribute to increasing the discriminatory power of the test sample. 3 variables were excluded:
# effort_rate, home_status and credit_amount.
# Despite work on the purpose of the credit, this variable was not retained in the end because we were unable to obtain coefficients that were totally consistent with delinquency rates, and the exclusion of this variable did not reduce the area under the ROC curve. The logit model finally retained comprises 7 variables

# %%
import statsmodels.api as sm
import statsmodels.formula.api as smf

formula = 'presence_unpaid ~ accounts + history_credit + duration_credit + age + savings + guarantees + other_credits'
logit_model = smf.glm(formula=formula, data=train, family=sm.families.Binomial(link=sm.genmod.families.links.Logit())).fit()

print(logit_model.summary())

null_deviance = -2 * logit_model.llnull
residual_deviance = -2 * logit_model.llf

print("\nNull Deviance: {:.4f}".format(null_deviance))
print("Residual Deviance: {:.4f}".format(residual_deviance))
print("AIC: {:.4f}".format(logit_model.aic))
print("Number of Fisher Scoring iterations: {}".format(logit_model.fit_history['iteration']))
# Out:
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:        presence_unpaid   No. Observations:                  700
# Model:                            GLM   Df Residuals:                      687
# Model Family:                Binomial   Df Model:                           12
# Link Function:                  Logit   Scale:                          1.0000
# Method:                          IRLS   Log-Likelihood:                -347.46
# Date:                Fri, 14 Feb 2025   Deviance:                       694.92
# Time:                        22:45:31   Pearson chi2:                     666.
# No. Iterations:                     5   Pseudo R-squ. (CS):             0.2008
# Covariance Type:            nonrobust
# =========================================================================================================================
#                                                             coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------------------------
# Intercept                                                -0.1278      0.596     -0.214      0.830      -1.296       1.040
# accounts[T.CC > 200 euros]                               -0.7764      0.400     -1.943      0.052      -1.560       0.007
# accounts[T.CC [0-200 euros]]                             -0.3193      0.223     -1.430      0.153      -0.757       0.118
# accounts[T.No account]                                   -1.8582      0.259     -7.186      0.000      -2.365      -1.351
# history_credit[T.No credits or ongoing without delay]    -0.6827      0.317     -2.153      0.031      -1.304      -0.061
# history_credit[T.Past credits without delay]             -1.0631      0.351     -3.027      0.002      -1.752      -0.375
# duration_credit[T.[15.0, 36.0)]                           0.5553      0.214      2.597      0.009       0.136       0.974
# duration_credit[T.[36.0, inf)]                            1.1736      0.270      4.340      0.000       0.644       1.704
# age[T.[25.0, inf)]                                       -0.3531      0.252     -1.400      0.162      -0.848       0.141
# savings[T.> 500 euros]                                   -0.7045      0.344     -2.046      0.041      -1.380      -0.030
# savings[T.No savings]                                    -0.8988      0.283     -3.174      0.002      -1.454      -0.344
# guarantees[T.Without guarantor]                           1.2086      0.465      2.598      0.009       0.297       2.120
# other_credits[T.No external credit]                      -0.5657      0.229     -2.467      0.014      -1.015      -0.116
# =========================================================================================================================
#
# Null Deviance: 851.7936
# Residual Deviance: 694.9217
# AIC: 720.9217
# Number of Fisher Scoring iterations: 5

# %% [markdown]
# We notice the high p-value of the modality "accounts[T.CC [0-200 euros]]", but we can check thaht all p-values of this variable become lower at """" if we choose "accounts[T.No account]" as the reference modality.
#
# We notice also a high p-value of the modality "age[T.[25.0, inf)]".
#
# We apply then the model obtained to the test sample.

# %%
predicted_probabilities = logit_model.predict(test)
predicted_classes = (predicted_probabilities > 0.5).astype(int)

print(predicted_probabilities)
print(predicted_classes)
# Out:
# 0      0.582616
# 1      0.508634
# 2      0.064006
# 3      0.035398
# 4      0.173073
#          ...
# 295    0.360021
# 296    0.061661
# 297    0.051727
# 298    0.149459
# 299    0.116515
# Length: 300, dtype: float64
# 0      1
# 1      1
# 2      0
# 3      0
# 4      0
#       ..
# 295    0
# 296    0
# 297    0
# 298    0
# 299    0
# Length: 300, dtype: int64

# %% [markdown]
# We calcultate now the area under the curve ROC

# %%
from sklearn.metrics import roc_auc_score

y_test = test['presence_unpaid']

auc = roc_auc_score(y_test, predicted_probabilities)
auc
# Out:
# np.float64(0.8059939381270902)

# %% [markdown]
# This area is so higher than the best model obatined by forward selection, but with only 7 variables instead of 10. We are satisfied with this result.

# %%
import matplotlib.pyplot as plt
import numpy as np


def ecdf(data):
    """ Compute ECDF for a one-dimensional array of measurements."""
    n = len(data)

    x = np.sort(data)

    y = np.arange(1, n+1) / n

    return x, y

x_0, y_0 = ecdf(predicted_probabilities[test['presence_unpaid'] == 0])
x_1, y_1 = ecdf(predicted_probabilities[test['presence_unpaid'] == 1])

common_x = np.unique(np.concatenate((x_0, x_1)))
y_0_interp = np.interp(common_x, x_0, y_0)
y_1_interp = np.interp(common_x, x_1, y_1)

ks_stat = np.max(np.abs(y_0_interp - y_1_interp))
ks_x = common_x[np.argmax(np.abs(y_0_interp - y_1_interp))]

plt.figure(figsize=(8, 8))
plt.plot(x_0, y_0, marker='8', color='blue', linestyle='none', label='Score=0')
plt.plot(x_1, y_1, marker='^', color='red', linestyle='none', label='Score=1')

ks_index = np.argmax(np.abs(y_0_interp - y_1_interp))
ks_stat = np.abs(y_0_interp - y_1_interp)[ks_index]
ks_x = common_x[ks_index]

plt.plot([ks_x, ks_x], [y_0_interp[ks_index], y_1_interp[ks_index]], color='grey', linestyle='dotted')

plt.legend(['Score=0', 'Score=1'], loc='lower right')
plt.title('Score distribution function')
plt.xlabel('x - Score (logit)')
plt.ylabel('Fn(x)')

plt.show()

# %% [markdown]
# Another performance measure sometimes used for a binary predictive model is the Kolmogorov-Smirnov statistic (or distance). To define it, we need to look at the curve of the distribution function, the empirical cumulative distribution function, of the score (probability of non-payment) for good files, and consider the same thing for bad files.
#
# We obtain two S-curves hat are offset from each other, and the the Kolmogorov-Smirnov distance is equal to the greatest difference in ordinates between the two curves. The greater the difference between the two curves, higher the Kolmogorov-Smirnov distance is.
#
#
# Let's suppose that for a score threshold s, we have an ordinate equal to 20 % for the curve of bad files, and 70 % for the curve of good files.
#
# This means that 20 % of bad files have a score <= s and 70 % of good files have a score <= s.
#
# In other words, 80 % of bad cases have a base > s (sensitivity = 0.80) and 30 % of good cases have a base > s (1-specificity = 0.30).
#
# At this threshold of s of score, we have 80 % true positives and 30 % false positives. To find the KS distance, we look for the maximum difference between the true and false positive rates for all the thresholds. This results in the following Python code

# %%
from sklearn.metrics import roc_curve

fpr, tpr, thresholds = roc_curve(y_test, predicted_probabilities)

ks_statistic = max(tpr - fpr)
print("Kolmogorov-Smirnov Distance:", ks_statistic)
# Out:
# Kolmogorov-Smirnov Distance: 0.530309364548495

# %% [markdown]
# Here we get a statistic equal to 0.530.
#
# In other words, the distance to be maximised is :
#
# $$
# Prob(score < s / 0) - Prob(score < s / 1) = Prob(score < s / 0) + Prob(score \geq s / 1)
# $$
#
# In other words, the sum of specificity and sensitivity.
#
#
# This performance measure is interesting but we have to note that it is a local measure, less representative than the area under the curve ROC of the discriminating power of the global model. It is obtained for a particular value of the score threshold. This threshold is not necessarily a threshold used for the operational use of the score, such as an acceptance threshold.

# %%
from sklearn.metrics import roc_curve

fpr, tpr, thresholds = roc_curve(y_test, predicted_probabilities)
ks = tpr - fpr
max_ks_index = np.argmax(ks)
optimal_threshold = thresholds[max_ks_index]

print("Optimum threshold based on KS:", optimal_threshold)
# Out:
# Optimum threshold based on KS: 0.3395624689824106

# %% [markdown]
# Here the score threshold is 0.339
#
# Look at the segment in the "score distribtion function" plot representing the maximal gap between distribution functions of good and bad files.
#
# We can also represent density functions corresôpnding at the previous distribution functions, and add a vertrical line indicating the threshold maximising the separation of good and bad files.
#
# The density function does not return the empirical density function, but the convolution product of this empirical density with the probability density of a law which is by default the normal law (this is known as convolution with a Gaussian kernel).

# %%
# Calculate the Kolmogorov-Smirnov distance after interpolation
ks_stat = np.max(np.abs(y_0_interp - y_1_interp))
ks_x = common_x[np.argmax(np.abs(y_0_interp - y_1_interp))]
ks_x
# Out:
# np.float64(0.32488542051592756)

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import roc_curve

fpr, tpr, thresholds = roc_curve(y_test, predicted_probabilities)
ks = tpr - fpr
max_ks_index = np.argmax(ks)
optimal_threshold = thresholds[max_ks_index]

scores_good = predicted_probabilities[y_test == 0]
scores_bad = predicted_probabilities[y_test == 1]

plt.figure(figsize=(10, 6))
sns.kdeplot(scores_good, label='Good files (presence_unpaid=0)', fill=True)
sns.kdeplot(scores_bad, label='Bad files (presence_unpaid=1)', fill=True)

plt.axvline(optimal_threshold, color='green', linestyle='--', label=f'Optimum threshold: {optimal_threshold:.2f}')

plt.legend()
plt.title('Score density functions with optimal threshold')
plt.xlabel('Score (predicted probability)')
plt.ylabel('Density')

plt.show()

# %% [markdown]
# We can represent in a boxplot the score distribution in each of the two classes to be discriminated against, and see that the score separates well the good cases from the bad.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

test['predicted_score'] = predicted_probabilities

plt.figure(figsize=(8, 6))
sns.boxplot(x='presence_unpaid', y='predicted_score', data=test)

plt.title('The score in each of the classes to be discriminated')
plt.xlabel('Presence Unpaid')
plt.ylabel('logit (Predicted Score)')

plt.show()

# %% [markdown]
# ## Score grid

# %% [markdown]
# This logit model can be transformed into a score grid, assigning to each modality a number of points >= 0, the higher the modality corresponds to a riskier profile, and standardised so that each file has a total number of points between 0 (minimum risk) and 100 (maximum risk).
#
# The transcription of a model in the form of a "score grid" is common in *credit scoring*. In the case of a logistic regression on categorical or discretized variables, with consequently one coefficient per variable modality, it is sufficient to :
#
# * Substitute the logit (linear combination of the modality indicators) for the probability
#
# $$
# \frac{e^{logit}}{1+e^{logit}}
# $$
#
# as the score value,
#
# * Then normalise the logit so that it in the range 0 to 100 (we often choose 1000 to limit the effect of rounding)
#
# In this logit normalisation, the coefficients of the logistic regression are replaced by new coefficients, called "number of points", each associated with a modality.
#
# This number of points, between 0 and 100, is the person's score.

# %% [markdown]
# This calculation of the score as a sum of points can be described as follows.
#
# For each qualitative or discrete variable
#
# $$
# X_j
# $$,
#
# we note
#
# $$
# c_{jk}
# $$
#
# the coefficients of the model associated with modality
#
# $$
# k
# $$,
#
# and
#
# $$
# a_j
# $$
#
# and
#
# $$
# b_j
# $$
#
# its minimum and maximum coefficients in the logistic regression:
#
# $$
# a_j = min_k \: c_{jk}
# $$
#
# and
#
# $$
# b_j= max_k \: c_{jk}
# $$

# %% [markdown]
# The total weight of all the variables is then calculated:
#
# $$
# pt = \sum_{j}(b_j - a_j)
# $$
#
# At each
#
# $$
# k
# $$
#
# modality of
#
# $$
# X_j
# $$
#
# is associated a number of points equal to :
#
# $$
# 100 \times \frac{c_{jk} - a_j}{pt}
# $$

# %% [markdown]
# With quantitatives variables
#
# $$
# X_l
# $$
#
# the grid is more complex to set. Ethe total weight has to take the coefficient
#
# $$
# \beta_l
# $$
#
# the minimum
#
# $$
# m_l
# $$
#
# and the maximum
#
# $$
# M_l
# $$
#
# of each variable
#
# $$
# X_l
# $$
#
# :
#
# $$
# pt = \sum_{j}(b_j - a_j) + \sum_{l}|\beta_l|(M_l-m_l)
# $$

# %% [markdown]
# At $$x$$ value corresponds then to a number of points :
#
# $$
# 100 \times \frac{|\beta_l|(x - m_l)}{pt}
# $$
#
# The complexity comes from the fact the number of points is not directly given but has to be calculated.

# %% [markdown]
# Here we will create a dataframe containing one column for variables (factors), one for their modalities (levels) and one for their coefficients.

# %%
model_logitxlevels = ['accounts', 'history_credit', 'duration_credit', 'age', 'savings','guarantees', 'other_credits']

for var in model_logitxlevels:
    if var in credit2.columns:
        print(f"Level for {var}: {credit2[var].unique()}")
    else:
        print(f"{var} is not in the DataFrame")
# Out:
# Level for accounts: ['CC < 0 euros' 'CC [0-200 euros]' 'No account' 'CC > 200 euros']
# Level for history_credit: ['Past credits without delay' 'No credits or ongoing without delay'
#  'Credits in arrears']
# Level for duration_credit: ['[0.0, 15.0)' '[36.0, inf)' '[15.0, 36.0)']
# Level for age: ['[25.0, inf)' '[0.0, 25.0)']
# Level for savings: ['No savings' '< 500 euros' '> 500 euros']
# Level for guarantees: ['Without guarantor' 'With guarantor']
# Level for other_credits: ['No external credit' 'External credits']

# %%
coefficients = logit_model.params
print(coefficients)
# Out:
# Intercept                                               -0.127794
# accounts[T.CC > 200 euros]                              -0.776391
# accounts[T.CC [0-200 euros]]                            -0.319349
# accounts[T.No account]                                  -1.858242
# history_credit[T.No credits or ongoing without delay]   -0.682707
# history_credit[T.Past credits without delay]            -1.063142
# duration_credit[T.[15.0, 36.0)]                          0.555282
# duration_credit[T.[36.0, inf)]                           1.173611
# age[T.[25.0, inf)]                                      -0.353127
# savings[T.> 500 euros]                                  -0.704534
# savings[T.No savings]                                   -0.898756
# guarantees[T.Without guarantor]                          1.208609
# other_credits[T.No external credit]                     -0.565724
# dtype: float64

# %%
multiplier = 10

scores = {k: v * multiplier for k, v in coefficients.items() if k != 'Intercept'}

print("Scores attributed to each modality :", scores)

max_score = sum([abs(s) for s in scores.values()])  
normalized_scores = {k: (v / max_score) * 100 for k, v in scores.items()}

print("Standardised scores :", normalized_scores)
# Out:
# Scores attributed to each modality : {'accounts[T.CC > 200 euros]': -7.763914389738266, 'accounts[T.CC [0-200 euros]]': -3.1934887767417615, 'accounts[T.No account]': -18.58242307267496, 'history_credit[T.No credits or ongoing without delay]': -6.827068298117264, 'history_credit[T.Past credits without delay]': -10.63142071385737, 'duration_credit[T.[15.0, 36.0)]': 5.552816557362816, 'duration_credit[T.[36.0, inf)]': 11.736107254663533, 'age[T.[25.0, inf)]': -3.531265973981142, 'savings[T.> 500 euros]': -7.045337423313532, 'savings[T.No savings]': -8.987559369926402, 'guarantees[T.Without guarantor]': 12.086087456565222, 'other_credits[T.No external credit]': -5.657237277214034}
# Standardised scores : {'accounts[T.CC > 200 euros]': -7.642044673288641, 'accounts[T.CC [0-200 euros]]': -3.143360767573992, 'accounts[T.No account]': -18.29073584930641, 'history_credit[T.No credits or ongoing without delay]': -6.719904200742173, 'history_credit[T.Past credits without delay]': -10.464539916000176, 'duration_credit[T.[15.0, 36.0)]': 5.465654316079344, 'duration_credit[T.[36.0, inf)]': 11.551886255879895, 'age[T.[25.0, inf)]': -3.475835895627096, 'savings[T.> 500 euros]': -6.934747168067286, 'savings[T.No savings]': -8.846482168787398, 'guarantees[T.Without guarantor]': 11.896372838734843, 'other_credits[T.No external credit]': -5.568435949912747}

# %%
# Preparation and cleaning for the score grid

import pandas as pd

coefficients = logit_model.params

data = {
    'VARIABLE': [],
    'MODALITY': [],
    'COEFF': []
}

for var in coefficients.index:
    if 'T.' in var:
        var_name, modality = var.split('T.')
    else:
        var_name = var
        modality = 'N/A'
    
    var_name = var_name.strip('[]').strip() 
    modality = modality.strip('[]').strip()  
    
    data['VARIABLE'].append(var_name)
    data['MODALITY'].append(modality)
    data['COEFF'].append(coefficients[var])

param = pd.DataFrame(data)
param
# Out:
#            VARIABLE                             MODALITY     COEFF
# 0         Intercept                                  N/A -0.127794
# 1          accounts                       CC > 200 euros -0.776391
# 2          accounts                      CC [0-200 euros -0.319349
# 3          accounts                           No account -1.858242
# 4    history_credit  No credits or ongoing without delay -0.682707
# 5    history_credit           Past credits without delay -1.063142
# 6   duration_credit                          15.0, 36.0)  0.555282
# 7   duration_credit                           36.0, inf)  1.173611
# 8               age                           25.0, inf) -0.353127
# 9           savings                          > 500 euros -0.704534
# 10          savings                           No savings -0.898756
# 11       guarantees                    Without guarantor  1.208609
# 12    other_credits                   No external credit -0.565724

# %% [markdown]
# With a little effort, we have arrived at a dataframe containing results under the hoped shape, which will enable us to create a score grid.

# %% [markdown]
# We create then a dataframe which contains the minimim coefficient of each variable, and another which contains the maximum coefficient.

# %%
import pandas as pd

coefficients = logit_model.params

min_coeffs = pd.DataFrame(coefficients.groupby(coefficients.index.str.split('[').str[0]).min(), columns=['Min_Coefficient'])
max_coeffs = pd.DataFrame(coefficients.groupby(coefficients.index.str.split('[').str[0]).max(), columns=['Max_Coefficient'])

print(min_coeffs)
print(max_coeffs)
# Out:
#                  Min_Coefficient
# Intercept              -0.127794
# accounts               -1.858242
# age                    -0.353127
# duration_credit         0.555282
# guarantees              1.208609
# history_credit         -1.063142
# other_credits          -0.565724
# savings                -0.898756
#                  Max_Coefficient
# Intercept              -0.127794
# accounts               -0.319349
# age                    -0.353127
# duration_credit         1.173611
# guarantees              1.208609
# history_credit         -0.682707
# other_credits          -0.565724
# savings                -0.704534

# %% [markdown]
# We merge them and calculate the difference between maximum and minimum

# %%
total = min_coeffs.join(max_coeffs)

total.reset_index(inplace=True)
total.rename(columns={'index': 'VARIABLE'}, inplace=True)

total['Diff'] = total['Max_Coefficient'] - total['Min_Coefficient']

total
# Out:
#           VARIABLE  Min_Coefficient  Max_Coefficient      Diff
# 0        Intercept        -0.127794        -0.127794  0.000000
# 1         accounts        -1.858242        -0.319349  1.538893
# 2              age        -0.353127        -0.353127  0.000000
# 3  duration_credit         0.555282         1.173611  0.618329
# 4       guarantees         1.208609         1.208609  0.000000
# 5   history_credit        -1.063142        -0.682707  0.380435
# 6    other_credits        -0.565724        -0.565724  0.000000
# 7          savings        -0.898756        -0.704534  0.194222

# %% [markdown]
# THen we calculate the total weight which will serve to normalise the weight of each modality

# %%
total_weight = sum(total['Diff'] )
total_weight
# Out:
# 2.731879935558689

# %% [markdown]
# We merge then on the [VARIABLE] column the `param` dataframe with the `min_coeffs` dataframe to add in front of each modality the minimum coefficient of the variable of each modality.
#
# We calculate the difference between the coefficient of each modality and the minimum coefficient of the variable, which conduct at modality's weight after division by the total weight previously calculated and multiply by 100 and rounded (but we could multiply by 1000 for a more accurate scale).

# %%
grid = pd.merge(param, min_coeffs, left_on='VARIABLE', right_index=True)
grid['Modality_Weight'] = grid['COEFF'] - grid['Min_Coefficient']
grid['WEIGHT'] = ((grid['Modality_Weight'] *100) / total_weight) 
grid['WEIGHT'] = grid['WEIGHT'].round()

# %% [markdown]
# We finally display the grid, after removal of the Intercept row, and sorting rows by variables and modality names

# %%
# Final score grid
grid = grid[grid['VARIABLE'] != 'Intercept']
grid.sort_values(by=['VARIABLE', 'MODALITY'], inplace=True)
grid = grid[['VARIABLE', 'MODALITY', 'WEIGHT']]
grid
# Out:
#            VARIABLE                             MODALITY  WEIGHT
# 1          accounts                       CC > 200 euros    40.0
# 2          accounts                      CC [0-200 euros    56.0
# 3          accounts                           No account     0.0
# 8               age                           25.0, inf)     0.0
# 6   duration_credit                          15.0, 36.0)     0.0
# 7   duration_credit                           36.0, inf)    23.0
# 11       guarantees                    Without guarantor     0.0
# 4    history_credit  No credits or ongoing without delay    14.0
# 5    history_credit           Past credits without delay     0.0
# 12    other_credits                   No external credit     0.0
# 9           savings                          > 500 euros     7.0
# 10          savings                           No savings     0.0

# %% [markdown]
# The interest of this kind of grid is of course its readabilty. Credit analysts who are not statisticians could easily understand and comment this grid. This will make it easier for them to get to grips with the scoring tool, and they will be able to compare the number of points with their business intuition : suggest that this or that division is not appropriate, or that or this variable has too much weight.
#
# The statistician will then review his model and modelled data.
#
# In our grid, personal criterias (age) or external (credit in other establishments) have less weight. On the other hand, a current account in debit or the presence of unpaid are predominant risk factors, which is classic.
#
# > il semble avoir une petite erreur sur les modalités choisies

# %% [markdown]
# ## Determining score thresholds

# %% [markdown]
# Ther last stepin the construction of the scoring tool consists of slicing the number of points. In this kind of problematic, we make generally 2 or 3 slices of score. The 2 slices correspond to acceptance and refusal. The 3 slices are :
# * A less risky slice : all you need to do is carry out a few checks
# * An intermediate slice : examine carefully the file and carry out a standard risk analysis
# * A more risky slice : the asking of credit is, otherwise rejected, at least forwarded to the next level of management for an in-depth examination of the file

# %% [markdown]
# here's how to do it.
#
# First af all, we apply the model to all the data, then we cut the score in vingtiles (slices of 5%), then we calculate and we display non-payment rates for each of these vingtiles

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve

# Nettoyage des graphiques précédents
# plt.clf()  # Clear the current figure
# plt.close('all')  # Close all figures

credit2['logit'] = logit_model.predict(credit2)

q = np.quantile(credit2['logit'], np.arange(0, 1.05, 0.05))
credit2['qscore'] = pd.cut(credit2['logit'], q, include_lowest=True)

tab = pd.crosstab(credit2['qscore'], credit2['presence_unpaid'])
ti = tab.div(tab.sum(axis=1), axis=0)[1]

plt.figure(figsize=(10, 6))
bars = plt.bar(range(len(ti)), ti, color=plt.cm.gray(np.linspace(0, 1, len(ti))))

plt.title('Rate of non-payment by score vingtiles')
plt.xticks(range(len(ti)), labels=ti.index, rotation=90)
plt.ylabel('Rate of non-payment')
plt.ylim(0, 1)
plt.axvline(x=6.5, color='red', linestyle='-')
plt.axvline(x=14.5, color='red', linestyle='-')

plt.show()

# %%
import pandas as pd

bins = [float('-inf'), 0.143, 0.459, float('inf')]
labels = ['Low', 'Medium', 'High']

credit2['zscore'] = pd.cut(credit2['logit'], bins=bins, labels=labels)
zscore_counts = credit2['zscore'].value_counts()

print(zscore_counts)
# Out:
# zscore
# Medium    399
# Low       360
# High      241
# Name: count, dtype: int64

# %%
print("The percentage of low-risk files: ",(437 * 100) / 1000)
print("The percentage of middle-risk files: ",(323 * 100) / 1000)
print("The percentage of high-risk files: ",(240 * 100) / 1000)
# Out:
# The percentage of low-risk files:  43.7
# The percentage of middle-risk files:  32.3
# The percentage of high-risk files:  24.0

# %%
import pandas as pd

tab = pd.crosstab(credit2['zscore'], credit2['presence_unpaid'])

tab_prop = tab.div(tab.sum(axis=1), axis=0)

print(tab_prop)
# Out:
# presence_unpaid         0         1
# zscore
# Low              0.925000  0.075000
# Medium           0.694236  0.305764
# High             0.373444  0.626556

# %% [markdown]
# We can discern two fairly natural thresholds at 0.143 and 0.459, which we use as the limits of the score ranges.
# With these thresholds, we obtain :
# * a low-risk slice which includes 43.7 % of files and a non-payment rate of 6 %
# * a medium-risk slice which includes 32.3 % of files and a non-payment rate of 36 %
# * a high-risk slice which includes 24 % of files and a non-payment rate of 68 %

# %% [markdown]
# We see that the score is very discriminant, because the non-payment rate of the high-risk slice is more than 10 times higher than the less-risk slice.

# %% [markdown]
# We can also cut the score into 3 slices by using the automatic discretisation function we created in the part 2 of this project.

# %%
from discretisation_automatique import decoup 


credit2['logit_score'] = logit_model.predict(credit2)

decoup(credit2, 'logit_score', 'presence_unpaid', nbmod=3, h=1, k=0, pAUC=0.8, graphe=1)
# Out:
# ---------------------------------------------------------------------------
#
# Discretization of logit_score into 3 classes (algorithm Nelder-Mead)
#
# ---------------------------------------------------------------------------
#
# Result of cutting :
#
#
# Tresholds      % Negative  % Positive   # +   #   % #
#                         0          1    1    0     1
# logit_score
# (-inf, 0.139]   92.836676   7.163324   25  349  34.9
# (0.139, 0.395]  71.428571  28.571429   94  329  32.9
# (0.395, inf]    43.788820  56.211180  181  322  32.2
#
# Convergence indicator (0 = convergence optimisation)
# True
#
# Maximum (partial) AUC  :
# 0.5060208257000001
#
# Class homogeneity (0 <- low ... high -> 1) :
# 0.5972663490820712
#
# AUC before cutting :
# 0.7916928571428572
#
# AUC after cutting :
# 0.7594785714285714
#
# % Evolution AUC before/after cutting :
# -4.069038317529349

# %% [markdown]
# We see that the two tresholds gived by this automatic discretization (0.144 and 0.419) are pretty similar to 0.143 and 0.459 previsouly determined.
#
# Once again, this demonstrates the value of the automatic discretisation function.

# %% [markdown]
# ### ROC curve and Lift curve

# %% [markdown]
# Let's trace the curve ROC of the model, which represents the True Positive Rate (TPR) - the sensitivity - in relation to the False Positive Rate (FPR). We do it here to the logit model applied to the test sample.

# %%
from sklearn.metrics import roc_curve

y_true = test['presence_unpaid']
scores = predicted_probabilities

fpr, tpr, thresholds = roc_curve(y_true, scores, pos_label=1)

# %%
from sklearn.metrics import roc_curve, auc
import matplotlib.pyplot as plt

fpr, tpr, _ = roc_curve(y_true, scores)
roc_auc = auc(fpr, tpr)

plt.figure(figsize=(8, 6))
plt.plot(fpr, tpr, color='blue', lw=2, label=f'ROC curve (area = {roc_auc:.2f})')

plt.plot([0, 1], [0, 1], color='grey', lw=2, linestyle=':')

plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC curve for the logistic model')
plt.legend(loc="lower right")

plt.show()

# %% [markdown]
# We can also represent the True Positive Rate in relation to  the Rate of Positive Predictions (RPP), what is commonly known as the *Lift Curve*

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve


y_true_numeric = y_true.astype('int')
prop_positive = y_true_numeric.mean()

fpr, tpr, thresholds = roc_curve(y_true, scores)
rpp = fpr * (1 - prop_positive) + tpr * prop_positive  # RPP: Rate of Positive Predictions

plt.figure(figsize=(8, 6))
plt.plot(rpp, tpr, label='Lift curve')

plt.plot([0, prop_positive, 1], [0, 1, 1], color="grey", linestyle=":", label="Perfect model")

#plt.axhline(y=1, color='grey', linestyle=':', label='Random')
#plt.axvline(x=prop_positive, color='grey', linestyle='--', label='Proportion of positives')


plt.title('Lift curve for the logistic model')
plt.xlabel('Rate of Positive Predictions (RPP)')
plt.ylabel('True Positive Rate (TPR)')
plt.legend(loc='best')

plt.show()

# %% [markdown]
# This curve has a simple interpretation : the existence of an abscissa point 0.2 and ordinate 0.4 means that the 20 % of individuals who have the higher score contain 40 % of positives.
#
# In other words, the score owns a treshold beyond which there are 20 % of all individuals and 40 % of the positives.
#
# In marketing for example, we say that we reach 40 % of buyers by targeting 20 % of customers.

# %% [markdown]
# And here another Lift Curve, which has the same abscissa (Rate of Positive Predictions) and an ordinate which is the ratio :
#
# $$
# Lift = \frac{True \, Positive \, (TPR)}{Rate \, of \, Positive \, Predictions \, (RPP)}
# $$

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve


y_true_numeric = y_true.astype('int')
prop_positive = y_true_numeric.mean()

fpr, tpr, thresholds = roc_curve(y_true, scores)

rpp = fpr * (1 - prop_positive) + tpr * prop_positive

lift = tpr / rpp

plt.figure(figsize=(8, 6))
plt.plot(rpp, lift, label='Lift curve')

# plt.axhline(y=1, color='grey', linestyle=':', label='Random')

# plt.axvline(x=prop_positive, color='grey', linestyle='--', label='Proportion of positives')

plt.title('Lift curve for the logistic model')
plt.xlabel('Rate of Positive Predictions (RPP)')
plt.ylabel('Lift value')
plt.legend(loc='best')

plt.show()
# Out:
# /tmp/ipykernel_871/3740604507.py:13: RuntimeWarning: invalid value encountered in divide
#   lift = tpr / rpp

# %% [markdown]
# Let's take the following example to explain it : at abscissa x = 0.2 corresponds at approximately to y = 0.2.
#
# We have 20 % of individuals above the corresponding treshold of the score, and among these individuals are 40 % of positives, hence a lifr = 40/20 = 2, the ordinate value.
#
# For a marketing score, we say thaht whe have reached 40 % of buyers by targetring 20 % of individuals. We also say thaht whe have a lift of 2 to 20 %.

# %% [markdown]
# ### Precision and Recall

# %% [markdown]
# Finally, we will create the precision and the recall curves.
#
# Precision is a metric used to evaluate the performance of a binary classification model. It is defined as the ratio between the number of true positives (TP) and the total number of positive predictions (i.e. the sum of true positives and false positives (FP)).
#
# $$
# Precision = \frac{True\,Positive\,(TP)}{True\,Positive\,(TP) + False\,Positive\,(FP)}
# $$
#
# Precision answers the following question: of all the examples that the model has predicted as positive, how many are actually positive?
#
# High Precision means that when the model predicts a positive class, it is generally correct.

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import precision_recall_curve


precisions, recalls, pr_thresholds = precision_recall_curve(y_true, scores)

plt.figure(figsize=(8, 6))
plt.plot(pr_thresholds, precisions[:-1], label='Precision curve', color='blue')

plt.title('Precision vs Decision Threshold')
plt.xlabel('Decision Threshold')
plt.ylabel('Precision')
plt.legend(loc='best')
plt.grid(True)

plt.show()

# %% [markdown]
# Recall is defined as the proportion of true positives (TP) among all true positives (TP + FN).
#
# $$
# Recall = \frac{True \, Positive \, (TP)}{True \, Positive \, (TP) + False \, Negative \, (FN)}
# $$
#
# This measures the model's ability to correctly identify positive instances in the data.
#
# High recall indicates that the model is capturing most of the true positives, but this can be at the expense of precision if the model is also making a lot of false positive predictions.

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, precision_recall_curve

fpr, tpr, thresholds = roc_curve(y_true, scores)

precisions, recalls, pr_thresholds = precision_recall_curve(y_true, scores)

plt.figure(figsize=(8, 6))
plt.plot(pr_thresholds, recalls[:-1], label='Recall curve', color='green')

plt.title('Recall vs Decision Threshold')
plt.xlabel('Decision Threshold')
plt.ylabel('Recall (True Positive Rate)')
plt.legend(loc='best')
plt.grid(True)

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import precision_recall_curve, roc_curve


precisions, recalls, pr_thresholds = precision_recall_curve(y_true, scores)

fpr, tpr, thresholds = roc_curve(y_true, scores)

plt.figure(figsize=(8, 6))

plt.plot(pr_thresholds, precisions[:-1], label='Precision', color='blue')
plt.plot(pr_thresholds, recalls[:-1], label='Recall', color='green')

plt.title('Precision and Recall vs Decision Threshold')
plt.xlabel('Decision Threshold')
plt.ylabel('Score')
plt.legend(loc='best')
plt.grid(True)

plt.show()

# %% [markdown]
# And finally the confusion matrix which shows the number of true positives, true negatives, false positives and false negatives for a given threshold.

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import precision_recall_curve, confusion_matrix
import seaborn as sns


precisions, recalls, pr_thresholds = precision_recall_curve(y_true, scores)

chosen_threshold = 0.6  # choose your treshold here

precision_value = 1  
rounded_pr_thresholds = np.round(pr_thresholds, precision_value)
rounded_chosen_threshold = np.round(chosen_threshold, precision_value)

y_pred = (scores >= chosen_threshold).astype(int)

cm = confusion_matrix(y_true, y_pred)

plt.figure(figsize=(6, 4))
ax = sns.heatmap(cm, annot=False, fmt="d", cmap="coolwarm", cbar=False)

labels = np.array([['TN', 'FP'], ['FN', 'TP']])
for i in range(2):
    for j in range(2):
        ax.text(j + 0.5, i + 0.5, f'{labels[i, j]}\n{cm[i, j]}', 
                ha='center', va='center', color='white', fontsize=12)

plt.title(f'Confusion matrix (Threshold = {chosen_threshold})')
plt.xlabel('Prediction')
plt.ylabel('Real')
plt.show()

if rounded_chosen_threshold in rounded_pr_thresholds:
    index = np.where(rounded_pr_thresholds == rounded_chosen_threshold)[0][0]
    precision = precisions[index]
    recall = recalls[index]
    f1 = 2 * (precision * recall) / (precision + recall)
else:
    precision = "N/A"
    recall = "N/A"
    f1 = "N/A"
    print(f"The chosen threshold {rounded_chosen_threshold} does not exist in rounded pr_thresholds.")

print(f'Precision: {precision * 100}')
print(f'Recall: {recall * 100}')
print(f'F1 Score: {f1 * 100:.2f}')
# Out:
# Precision: 74.0
# Recall: 40.21739130434783
# F1 Score: 52.11

# %% [markdown]
# Precision and recall are gave for the selected threshold.
#
# The F1 score is the harmonic mean between precision and recall, allowing a balance to be struck between the two metrics :
#
# $$
# F1 = 2 \times \bigg(\frac{Precision \times Recall}{Precision + Recall} \bigg)
# $$

# %% [markdown]
# ### Probit Model

# %% [markdown]
# So far, we have tried to write the expectation of Y/X in the form :
#
# $$
# g(E(Y/X = x)) = \beta_0 + \sum_{i} \beta_i X_i
# $$
#
# with the logit function g
#
# $$
# g(\mu) = log(\frac{\mu}{1-\mu})
# $$
#
# The inverse of the logit is the function
#
# $$
# \frac{e^t}{1 + e^t} = \int^{t}_{-\infty} \frac{e^z}{(1 + e^z)^2}dz
# $$
#
# This gives the probit

# %%
import statsmodels.api as sm
import statsmodels.formula.api as smf

formula = 'presence_unpaid ~ accounts + history_credit + duration_credit + age + savings + guarantees + other_credits'

probit_model = smf.glm(formula=formula, data=train, family=sm.families.Binomial(link=sm.genmod.families.links.probit())).fit()

print(probit_model.summary())

null_deviance = -2 * probit_model.llnull
residual_deviance = -2 * probit_model.llf

print("\nNull Deviance: {:.4f}".format(null_deviance))
print("Residual Deviance: {:.4f}".format(residual_deviance))
print("AIC: {:.4f}".format(probit_model.aic))
print("Nombre d'itérations de Fisher Scoring: {}".format(probit_model.fit_history['iteration']))
# Out:
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:        presence_unpaid   No. Observations:                  700
# Model:                            GLM   Df Residuals:                      687
# Model Family:                Binomial   Df Model:                           12
# Link Function:                 probit   Scale:                          1.0000
# Method:                          IRLS   Log-Likelihood:                -346.66
# Date:                Fri, 14 Feb 2025   Deviance:                       693.32
# Time:                        22:47:31   Pearson chi2:                     671.
# No. Iterations:                     6   Pseudo R-squ. (CS):             0.2026
# Covariance Type:            nonrobust
# =========================================================================================================================
#                                                             coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------------------------
# Intercept                                                -0.0844      0.351     -0.241      0.810      -0.772       0.603
# accounts[T.CC > 200 euros]                               -0.4480      0.235     -1.906      0.057      -0.909       0.013
# accounts[T.CC [0-200 euros]]                             -0.1932      0.136     -1.424      0.154      -0.459       0.073
# accounts[T.No account]                                   -1.0945      0.146     -7.489      0.000      -1.381      -0.808
# history_credit[T.No credits or ongoing without delay]    -0.3998      0.191     -2.097      0.036      -0.773      -0.026
# history_credit[T.Past credits without delay]             -0.6224      0.209     -2.979      0.003      -1.032      -0.213
# duration_credit[T.[15.0, 36.0)]                           0.3212      0.125      2.577      0.010       0.077       0.566
# duration_credit[T.[36.0, inf)]                            0.7003      0.159      4.405      0.000       0.389       1.012
# age[T.[25.0, inf)]                                       -0.2159      0.151     -1.432      0.152      -0.511       0.080
# savings[T.> 500 euros]                                   -0.3896      0.192     -2.028      0.043      -0.766      -0.013
# savings[T.No savings]                                    -0.5322      0.161     -3.302      0.001      -0.848      -0.216
# guarantees[T.Without guarantor]                           0.7481      0.270      2.769      0.006       0.219       1.278
# other_credits[T.No external credit]                      -0.3656      0.136     -2.694      0.007      -0.632      -0.100
# =========================================================================================================================
#
# Null Deviance: 851.7936
# Residual Deviance: 693.3182
# AIC: 719.3182
# Nombre d'itérations de Fisher Scoring: 6

# %%
test['predicted_prob'] = probit_model.predict(test)
print(test[['predicted_prob']].head())
# Out:
#    predicted_prob
# 0        0.575160
# 1        0.501467
# 2        0.054162
# 3        0.025530
# 4        0.172523

# %%
from sklearn.metrics import roc_auc_score

test['predicted_prob'] = probit_model.predict(test)

auc = roc_auc_score(test['presence_unpaid'], test['predicted_prob'])
print("AUC: {:.4f}".format(auc))
# Out:
# AUC: 0.8063

# %% [markdown]
# If we apply the probit model to the test sample, we can see that the area under the curve ROC is almost the same as the logit (0.8053).
#
# Generally speaking, it is known thaht the probit leads almost at the same ranking thant the logit, because it provides coefficients roughly proportional to those of logit :
#
# $$
# coefficients (logit) \approx \frac{\pi}{\sqrt 3} coefficients (probit)
# $$
#
# This proportionality coefficient is equal to the ratio of the standard deviations of the logistic distribution with parameter 1 and the reduced-centred normal distribution.

# %%
coefficients_logit_model = logit_model.params
coefficients_probit_model = probit_model.params
coefficients_logit_model / coefficients_probit_model
# Out:
# Intercept                              0.838763
# accounts[T.CC > 200 euros]             1.735090
# accounts[T.CC [0-200 euros]]           1.616310
# accounts[T.No account]                 1.697188
# history_credit[T.A31]                  1.503834
# history_credit[T.A32]                  1.636045
# history_credit[T.A33]                  1.725905
# history_credit[T.A34]                  1.667838
# duration_credit[T.[15.0, 36.0)]        1.739173
# duration_credit[T.[36.0, inf)]         1.685720
# age[T.[25.0, inf)]                     1.614007
# savings[T.> 500 euros]                 1.823232
# savings[T.No savings]                  1.679066
# guarantees[T.Without guarantor]        1.624290
# other_credits[T.No external credit]    1.561994
# dtype: float64

# %% [markdown]
# Here is the expected report

# %%
from math import pi, sqrt

pi/sqrt(3)
# Out:
# 1.8137993642342178

# %% [markdown]
# ### Log-log Model

# %% [markdown]
# When the expression for the expectation of Y/X is in the form :
#
# $$
# g(E(Y/X = x)) = \beta_0 + \sum_{i} \beta_i X_i
# $$
#
# involves the link function
#
# $$
# g(\mu) = log [-log(1-\mu)]
# $$
#
# we are talking about log-log model. Used in survival analysis, particularly in epidemiology and toxicology, but little in scoring.

# %%
import statsmodels.api as sm
import statsmodels.formula.api as smf

formula = 'presence_unpaid ~ accounts + history_credit + duration_credit + age + savings + guarantees + other_credits'

loglog_model = smf.glm(formula=formula, data=train, family=sm.families.Binomial(link=sm.genmod.families.links.loglog())).fit()

print(loglog_model.summary())

null_deviance = -2 * loglog_model.llnull
residual_deviance = -2 * loglog_model.llf

print("\nNull Deviance: {:.4f}".format(null_deviance))
print("Residual Deviance: {:.4f}".format(residual_deviance))
print("AIC: {:.4f}".format(loglog_model.aic))
print("Nombre d'itérations de Fisher Scoring: {}".format(loglog_model.fit_history['iteration']))
# Out:
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:        presence_unpaid   No. Observations:                  700
# Model:                            GLM   Df Residuals:                      687
# Model Family:                Binomial   Df Model:                           12
# Link Function:                 loglog   Scale:                          1.0000
# Method:                          IRLS   Log-Likelihood:                -345.28
# Date:                Fri, 14 Feb 2025   Deviance:                       690.55
# Time:                        22:47:42   Pearson chi2:                     678.
# No. Iterations:                     8   Pseudo R-squ. (CS):             0.2057
# Covariance Type:            nonrobust
# =========================================================================================================================
#                                                             coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------------------------
# Intercept                                                 0.4107      0.353      1.164      0.244      -0.281       1.102
# accounts[T.CC > 200 euros]                               -0.4016      0.226     -1.776      0.076      -0.845       0.042
# accounts[T.CC [0-200 euros]]                             -0.1941      0.145     -1.339      0.181      -0.478       0.090
# accounts[T.No account]                                   -1.0413      0.139     -7.510      0.000      -1.313      -0.770
# history_credit[T.No credits or ongoing without delay]    -0.4601      0.219     -2.098      0.036      -0.890      -0.030
# history_credit[T.Past credits without delay]             -0.6738      0.230     -2.924      0.003      -1.125      -0.222
# duration_credit[T.[15.0, 36.0)]                           0.2977      0.117      2.538      0.011       0.068       0.528
# duration_credit[T.[36.0, inf)]                            0.6812      0.162      4.210      0.000       0.364       0.998
# age[T.[25.0, inf)]                                       -0.2426      0.155     -1.563      0.118      -0.547       0.062
# savings[T.> 500 euros]                                   -0.3055      0.168     -1.819      0.069      -0.635       0.024
# savings[T.No savings]                                    -0.5013      0.146     -3.440      0.001      -0.787      -0.216
# guarantees[T.Without guarantor]                           0.7775      0.247      3.151      0.002       0.294       1.261
# other_credits[T.No external credit]                      -0.4502      0.140     -3.225      0.001      -0.724      -0.177
# =========================================================================================================================
#
# Null Deviance: 851.7936
# Residual Deviance: 690.5527
# AIC: 716.5527
# Nombre d'itérations de Fisher Scoring: 8

# %%
test['predicted_prob'] = loglog_model.predict(test)
print(test[['predicted_prob']].head())
# Out:
#    predicted_prob
# 0        0.552616
# 1        0.488328
# 2        0.053111
# 3        0.012450
# 4        0.168786

# %%
from sklearn.metrics import roc_auc_score

test['predicted_prob'] = loglog_model.predict(test)

auc = roc_auc_score(test['presence_unpaid'], test['predicted_prob'])
print("AUC: {:.4f}".format(auc))
# Out:
# AUC: 0.8029

# %% [markdown]
# Its area under the curve ROC is almost the same as the logit (0.8053).

# %%
coefficients_loglog_model = loglog_model.params
coefficients_logit_model / coefficients_loglog_model
# Out:
# Intercept                              0.049214
# accounts[T.CC > 200 euros]             1.954019
# accounts[T.CC [0-200 euros]]           1.556763
# accounts[T.No account]                 1.783731
# history_credit[T.A31]                  2.097108
# history_credit[T.A32]                  1.534306
# history_credit[T.A33]                  1.787907
# history_credit[T.A34]                  1.632337
# duration_credit[T.[15.0, 36.0)]        1.901504
# duration_credit[T.[36.0, inf)]         1.741278
# age[T.[25.0, inf)]                     1.425404
# savings[T.> 500 euros]                 2.331902
# savings[T.No savings]                  1.787234
# guarantees[T.Without guarantor]        1.570748
# other_credits[T.No external credit]    1.301842
# dtype: float64

# %% [markdown]
# ## Comparison of the 3 models

# %% [markdown]
# We can also check the proximity between these 3 models by mesuring the coorelations

# %%
test['logit_pred'] = logit_model.predict(test)
test['probit_pred'] = probit_model.predict(test)
test['loglog_pred'] = loglog_model.predict(test)

cor_logit_probit = test['logit_pred'].corr(test['probit_pred'])
cor_logit_loglog = test['logit_pred'].corr(test['loglog_pred'])
cor_probit_loglog = test['probit_pred'].corr(test['loglog_pred'])

print("Correlation between Logit and Probit : {:.4f}".format(cor_logit_probit))
print("Correlation between Logit and Log-Log : {:.4f}".format(cor_logit_loglog))
print("Correlation between Probit and Log-Log : {:.4f}".format(cor_probit_loglog))
# Out:
# Correlation between Logit and Probit : 0.9994
# Correlation between Logit and Log-Log : 0.9918
# Correlation between Probit and Log-Log : 0.9952

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import logistic, norm

x = np.linspace(-5, 5, 100)

y_logit = logistic.cdf(x)

y_probit = norm.cdf(x)

y_loglog = 1 - np.exp(-np.exp(x))


plt.figure(figsize=(10, 6))
plt.plot(x, y_logit, marker='s', linestyle='-', label='Logit', color='blue')
plt.plot(x, y_loglog, marker='^', linestyle='-', label='Log-Log', color='green')
plt.plot(x, y_probit, marker='D', linestyle='-', label='Probit', color='red')

plt.grid(True, which='both', linestyle='--', linewidth=0.5)
plt.title('Logit, Probit and Log-Log Curves')
plt.xlabel('Explanatory variable X')
plt.ylabel('Predicted probability')
plt.legend()

plt.show()

# %% [markdown]
# If we compare logit and probit curves in S, we realise that the probit decreases more quickly towards probabilities close to 0, and increases more towards probabilities close to 1 : the probit is then not recommended when many cases have a high or low probability, i.e. when the tail of the distribution is large.
#
# We have to note the dissymetry of the log-log curved compared to 0, unlike the other two curves. This asymetry makes the log-log model interesting for modelling a very rare or very frequent event, with a dissymetry of occurence.

# %% [markdown]
# ## Mise en Prod (Deployment of the model)

# %% [markdown]
# We are now going to proceed with the "Mise en Prod" of this logit model. For this we will use Streamlit
#
# > pip install streamlit
# >
# > in your terminal

# %%
import statsmodels.api as sm
import statsmodels.formula.api as smf

formula = 'presence_unpaid ~ accounts + history_credit + duration_credit + age + savings + guarantees + other_credits'
logit_model = smf.glm(formula=formula, data=train, family=sm.families.Binomial(link=sm.genmod.families.links.Logit())).fit()

print(logit_model.summary())

null_deviance = -2 * logit_model.llnull
residual_deviance = -2 * logit_model.llf

print("\nNull Deviance: {:.4f}".format(null_deviance))
print("Residual Deviance: {:.4f}".format(residual_deviance))
print("AIC: {:.4f}".format(logit_model.aic))
print("Number of Fisher Scoring iterations: {}".format(logit_model.fit_history['iteration']))
# Out:
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:        presence_unpaid   No. Observations:                  700
# Model:                            GLM   Df Residuals:                      687
# Model Family:                Binomial   Df Model:                           12
# Link Function:                  logit   Scale:                          1.0000
# Method:                          IRLS   Log-Likelihood:                -347.46
# Date:                Sun, 25 Aug 2024   Deviance:                       694.92
# Time:                        09:58:52   Pearson chi2:                     666.
# No. Iterations:                     5   Pseudo R-squ. (CS):             0.2008
# Covariance Type:            nonrobust
# =========================================================================================================================
#                                                             coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------------------------
# Intercept                                                -0.1278      0.596     -0.214      0.830      -1.296       1.040
# accounts[T.CC > 200 euros]                               -0.7764      0.400     -1.943      0.052      -1.560       0.007
# accounts[T.CC [0-200 euros]]                             -0.3193      0.223     -1.430      0.153      -0.757       0.118
# accounts[T.No account]                                   -1.8582      0.259     -7.186      0.000      -2.365      -1.351
# history_credit[T.No credits or ongoing without delay]    -0.6827      0.317     -2.153      0.031      -1.304      -0.061
# history_credit[T.Past credits without delay]             -1.0631      0.351     -3.027      0.002      -1.752      -0.375
# duration_credit[T.[15.0, 36.0)]                           0.5553      0.214      2.597      0.009       0.136       0.974
# duration_credit[T.[36.0, inf)]                            1.1736      0.270      4.340      0.000       0.644       1.704
# age[T.[25.0, inf)]                                       -0.3531      0.252     -1.400      0.162      -0.848       0.141
# savings[T.> 500 euros]                                   -0.7045      0.344     -2.046      0.041      -1.380      -0.030
# savings[T.No savings]                                    -0.8988      0.283     -3.174      0.002      -1.454      -0.344
# guarantees[T.Without guarantor]                           1.2086      0.465      2.598      0.009       0.297       2.120
# other_credits[T.No external credit]                      -0.5657      0.229     -2.467      0.014      -1.015      -0.116
# =========================================================================================================================
#
# Null Deviance: 851.7936
# Residual Deviance: 694.9217
# AIC: 720.9217
# Number of Fisher Scoring iterations: 5
# c:\Users\DL\anaconda3\Lib\site-packages\statsmodels\genmod\families\links.py:13: FutureWarning: The logit link alias is deprecated. Use Logit instead. The logit link alias will be removed after the 0.15.0 release.
#   warnings.warn(

# %% [markdown]
# ### 1. Save the model

# %%
import joblib

joblib.dump(logit_model, 'logit_model.plk')
# Out:
# ['logit_model.plk']

# %% [markdown]
# ### 2. Create the Streamlit app

# %% [markdown]
# Now we will create the app with the web framework Streamlit. The following code can not be executed in Jupyter Notebook.

# %%
import streamlit as st
from streamlit_option_menu import option_menu         
import pandas as pd
import joblib
from sklearn.metrics import roc_auc_score
import statsmodels.api as sm
import statsmodels.formula.api as smf
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from sklearn.metrics import precision_recall_curve, roc_curve, confusion_matrix
import plotly.express as px
import plotly.graph_objs as go
from sklearn.metrics import roc_auc_score, roc_curve
import plotly.figure_factory as ff




model = joblib.load('c:/Users/DL/Documents/MEGA/100 cas de PYTHON/Data_science_from_scratch/modelisation predictive version Python/logit_model.plk')



################ Page configuration ##################################################################################################

st.set_page_config(
    page_title="Scoring Credit App",  # Titre de l'onglet
    page_icon="💳",  
    layout="centered",  
    initial_sidebar_state="auto",
)

# UX
with st.sidebar:
    selected = option_menu(
        menu_title="Main Menu",
        options=["Home", "Model Explanation", "Contact"],
        icons=["credit-card", "graph-up", "envelope"],
        menu_icon="cast",
        default_index=0,
    )


################ Home ##################################################################################################

if selected == "Home":

    st.title("💳 Credit Risk Prediction")
    st.write("This app predicts the probability of a customer's non-payment based on several factors")


    # inputs users
    accounts = st.selectbox("accounts", ["", "No account", "CC < 0 euros", "CC [0-200 euros]", "CC > 200 euros"], index=0)
    history_credit = st.selectbox("history_credit", ["", "No credits or ongoing without delay", "Credits in arrears", "Past credits without delay"], index=0)
    duration_credit_value = st.slider("Duration Credit (months)", min_value=6, max_value=72, step=1)
    age_value = st.number_input("Age", min_value=18, max_value=75, step=1)
    savings = st.selectbox("savings", ["", "No savings", "> 500 euros", "< 500 euros", "No savings", "> 500 euros"], index=0)
    guarantees = st.selectbox("guarantees", ["", "With guarantor", "Without guarantor"], index=0)
    other_credits = st.selectbox("other_credits", ["", "No external credit", "External credits"], index=0)


    def discretize_duration_credit(value):
        if value < 15:
            return "[0.0, 15.0)"
        elif value <= 36:
            return "[15.0, 36.0)"
        else:
            return "[36.0, inf)"

    def discretize_age(value):
        if value < 25:
            return "[0.0, 25.0)"
        else:
            return "[25.0, inf)"

    duration_credit = discretize_duration_credit(duration_credit_value)
    age = discretize_age(age_value)


    # The inputs are stocked in a dataframe 
    input_data = pd.DataFrame({
        'accounts': [accounts],
        'history_credit': [history_credit],
        'duration_credit': [duration_credit],
        'age': [age],
        'savings': [savings],
        'guarantees': [guarantees],
        'other_credits': [other_credits]
    })


    # the prediction is ready
    if st.button("Predict"):
        if "" in [accounts, history_credit, savings, guarantees, other_credits]:
            st.error("Please fill in all the options before predicting.")
        else:
            # Continue with prediction
            prediction = model.predict(input_data)
            st.write(f"The probability of non-payment is {prediction[0]:.2%}")

            if prediction[0] > 0.5:
                st.error("Warning: Customers are at high risk of non-payment.")
            else:
                st.success("Good: The customer is at low risk of non-payment.")



####################### Data Preparation ##################################################################################################

# Loading data table and data transformation
credit2 = pd.read_csv('c:/Users/DL/Documents/MEGA/100 cas de PYTHON/Data_science_from_scratch/modelisation predictive version Python/credit2.csv') 

credit2['accounts'] = credit2['accounts'].replace({
    'A14': 'No account',
    'A11': 'CC < 0',
    'A12': 'CC [0-200 euros[',
    'A13': 'CC > 200 euros'
})

credit2['history_credit'] = credit2['history_credit'].replace({
    'A30': 'Credits in arrears', 'A31': 'Credits in arrears',
    'A32': 'No credits or ongoing without delay', 'A33': 'No credits or ongoing without delay',
    'A34': 'Past credits without delay'
})

credit2['object_credit'] = credit2['object_credit'].replace({
    'A40': 'New car',
    'A41': 'Used car',
    'A42': 'Interior', 'A43': 'Interior', 'A45': 'Interior',
    'A46': 'Studies-business-Other', 'A48': 'Studies-business-Other', 'A410': 'Studies-business-Other',
    'A47': 'Vacations'
})

credit2['savings'] = credit2['savings'].replace({
    'A63': 'No savings or > 500 euros', 'A64': 'No savings or > 500 euros', 'A65': 'No savings or > 500 euros',
    'A61': '< 500 euros', 'A62': '< 500 euros'
})

credit2['employment_old'] = credit2['employment_old'].replace({
    'A71': 'Unemployed or < 1 year', 'A72': 'Unemployed or < 1 year',
    'A73': 'E [1-4[ years',
    'A74': 'E GE A years', 'A75': 'E GE A years'
})

credit2['family_status'] = credit2['family_status'].replace({
    'A91': 'Divorced/separated man',
    'A92': 'Divorced/separated/married woman',
    'A93': 'Single/married/widowed man', 'A94': 'Single/married/widowed man',
    'A95': 'Single woman'
})

credit2['guarantees'] = credit2['guarantees'].replace({'A103': 'With guarantor'})

credit2.loc[credit2['guarantees'] != 'With guarantor', 'guarantees'] = 'Without guarantor'

credit2['property'] = credit2['property'].replace({'A121': 'Real estate', 'A124': 'No assets'})

credit2.loc[~credit2['property'].isin(['Real estate', 'No assets']), 'property'] = 'Non-real estate'

credit2['other_credits'] = credit2['other_credits'].replace({'A143': 'No external credit'})

credit2.loc[credit2['other_credits'] != 'No external credit', 'other_credits'] = 'External credits'

credit2['home_status'] = credit2['home_status'].replace({'A152': 'Owner'})

credit2.loc[credit2['home_status'] != 'Owner', 'home_status'] = 'Non-owner' 


# splitting train and test 
test_size = 0.3

shuffled_data = credit2.sample(frac=1, random_state=42)

split_point = int(len(shuffled_data) * (1 - test_size))

train = shuffled_data.iloc[:split_point].reset_index(drop=True)
test = shuffled_data.iloc[split_point:].reset_index(drop=True)


####################### Model Explanation ##################################################################################################


if selected == "Model Explanation":

    # Get the summary
    st.header("How the Logit model is explained")
    st.subheader("Logit Model Summary")

    formula = 'presence_unpaid ~ accounts + history_credit + duration_credit + age + savings + guarantees + other_credits'
    logit_model = smf.glm(formula=formula, data=train, family=sm.families.Binomial(link=sm.genmod.families.links.Logit())).fit()

    st.text(logit_model.summary())


    # Get the metrics
    null_deviance = -2 * logit_model.llnull
    residual_deviance = -2 * logit_model.llf

    null_deviance_message = "Null Deviance: {:.4f}".format(null_deviance)
    residual_deviance_message = "Residual Deviance: {:.4f}".format(residual_deviance)
    aic_message =  "AIC: {:.4f}".format(logit_model.aic)
    fisher_message = "Number of Fisher Scoring iterations: {}".format(logit_model.fit_history['iteration'])

    st.write(null_deviance_message)
    st.write(residual_deviance_message)
    st.write(aic_message)
    st.write(fisher_message)

    predicted_probabilities = logit_model.predict(test)
    predicted_classes = (predicted_probabilities > 0.5).astype(int)

    y_test = test['presence_unpaid']

    auc = roc_auc_score(y_test, predicted_probabilities)
    auc_message = "Area Under The Curve ROC: {:.4f}".format(auc)
    st.write(auc_message)



    # Get Score Distribution Function
    st.header("How bad and good files are distributed")

    def ecdf(data):
        n = len(data)
        x = np.sort(data)
        y = np.arange(1, n+1) / n
        return x, y

    x_0, y_0 = ecdf(predicted_probabilities[test['presence_unpaid'] == 0])
    x_1, y_1 = ecdf(predicted_probabilities[test['presence_unpaid'] == 1])

    common_x = np.unique(np.concatenate((x_0, x_1)))
    y_0_interp = np.interp(common_x, x_0, y_0)
    y_1_interp = np.interp(common_x, x_1, y_1)

    ks_stat = np.max(np.abs(y_0_interp - y_1_interp))
    ks_x = common_x[np.argmax(np.abs(y_0_interp - y_1_interp))]

    fig = go.Figure()
    fig.add_trace(go.Scatter(x=x_0, y=y_0, mode='markers', name='Score=0',
                            marker=dict(symbol='8', color='blue')))
    
    fig.add_trace(go.Scatter(x=x_1, y=y_1, mode='markers', name='Score=1',
                            marker=dict(symbol='triangle-up', color='red')))
    
    fig.add_trace(go.Scatter(x=[ks_x, ks_x], y=[y_0_interp[np.argmax(np.abs(y_0_interp - y_1_interp))], y_1_interp[np.argmax(np.abs(y_0_interp - y_1_interp))]],
                            mode='lines', name='KS Statistic', line=dict(color='grey', dash='dot')))
    fig.update_layout(
        title='Score Distribution Function',
        xaxis_title='x - Score (logit)',
        yaxis_title='Fn(x)',
        legend=dict(orientation="h", yanchor="bottom", y=1.02, xanchor="right", x=1)
    )

    st.plotly_chart(fig)
  
    
    
    # Get Score Density Plot
    fpr, tpr, thresholds = roc_curve(y_test, predicted_probabilities)
    ks = tpr - fpr
    max_ks_index = np.argmax(ks)
    optimal_threshold = thresholds[max_ks_index]
    
    st.header("What is the density for bad and good files")

    scores_good = predicted_probabilities[y_test == 0]
    scores_bad = predicted_probabilities[y_test == 1]

    fig = go.Figure()

    fig.add_trace(go.Histogram(x=scores_good, nbinsx=50, name='Good files (presence_unpaid=0)', opacity=0.7, histnorm='probability density', marker=dict(color='blue')))

    fig.add_trace(go.Histogram(x=scores_bad, nbinsx=50, name='Bad files (presence_unpaid=1)', opacity=0.7, histnorm='probability density', marker=dict(color='red')))

    fig.add_shape(type="line",
                x0=optimal_threshold, y0=0, x1=optimal_threshold, y1=1,
                line=dict(color="Green", width=3, dash="dash"))

    fig.add_annotation(x=optimal_threshold, y=0.5,
                    text=f'Optimum threshold: {optimal_threshold:.2f}',
                    showarrow=True, arrowhead=1)

    fig.update_layout(
        title="Score Density Functions with Optimal Threshold",
        xaxis_title="Score (predicted probability)",
        yaxis_title="Density",
        barmode='overlay'
    )

    st.plotly_chart(fig)


    # Get the boxplots
    st.header("How the good and bad files are well discriminated")

    test['predicted_score'] = predicted_probabilities

    fig = px.box(
        test,
        x='presence_unpaid',
        y='predicted_score',
        title='The score in each of the classes to be discriminated',
        labels={
            'presence_unpaid': 'Presence Unpaid',
            'predicted_score': 'Logit (Predicted Score)'
        },

        points="all",  
        color = 'presence_unpaid'
    )

    st.plotly_chart(fig)


    # Get the score grid
    st.header("How to put a weight on each modality's variable to measure its importance")
    st.subheader("Final Score Grid")

    model_logitxlevels = ['accounts', 'history_credit', 'duration_credit', 'age', 'savings','guarantees', 'other_credits']

    for var in model_logitxlevels:
        if var in credit2.columns:
            print(f"Level for {var}: {credit2[var].unique()}")
        else:
            print(f"{var} is not in the DataFrame")

    coefficients = logit_model.params


    multiplier = 10

    scores = {k: v * multiplier for k, v in coefficients.items() if k != 'Intercept'}

    print("Scores attributed to each modality :", scores)

    max_score = sum([abs(s) for s in scores.values()])  
    normalized_scores = {k: (v / max_score) * 100 for k, v in scores.items()}

    coefficients = logit_model.params

    data = {
        'VARIABLE': [],
        'MODALITY': [],
        'COEFF': []
    }

    for var in coefficients.index:
        if 'T.' in var:
            var_name, modality = var.split('T.')
        else:
            var_name = var
            modality = 'N/A'
    
        var_name = var_name.strip('[]').strip() 
        modality = modality.strip('[]').strip()  
        
        data['VARIABLE'].append(var_name)
        data['MODALITY'].append(modality)
        data['COEFF'].append(coefficients[var])

    param = pd.DataFrame(data)

    coefficients = logit_model.params

    min_coeffs = pd.DataFrame(coefficients.groupby(coefficients.index.str.split('[').str[0]).min(), columns=['Min_Coefficient'])
    max_coeffs = pd.DataFrame(coefficients.groupby(coefficients.index.str.split('[').str[0]).max(), columns=['Max_Coefficient'])

    total = min_coeffs.join(max_coeffs)
    total.reset_index(inplace=True)
    total.rename(columns={'index': 'VARIABLE'}, inplace=True)
    total['Diff'] = total['Max_Coefficient'] - total['Min_Coefficient']
    total_weight = sum(total['Diff'] )

    grid = pd.merge(param, min_coeffs, left_on='VARIABLE', right_index=True)
    grid['Modality_Weight'] = grid['COEFF'] - grid['Min_Coefficient']
    grid['WEIGHT'] = ((grid['Modality_Weight'] *100) / total_weight) 
    grid['WEIGHT'] = grid['WEIGHT'].round().astype(int)
   
    grid = grid[grid['VARIABLE'] != 'Intercept']
    grid.sort_values(by=['VARIABLE', 'MODALITY'], inplace=True)
    grid = grid[['VARIABLE', 'MODALITY', 'WEIGHT']]

    st.table(grid)

  

    # Get the ROC Curve
    st.header("How the logit model is efficient 1")
    
    from sklearn.metrics import roc_curve, auc as calculate_auc

    y_true = test['presence_unpaid']
    scores = predicted_probabilities
    fpr, tpr, thresholds = roc_curve(y_true, scores, pos_label=1)
    fpr, tpr, _ = roc_curve(y_true, scores)
    roc_auc_value  = calculate_auc(fpr, tpr)

    fig = go.Figure()

    fig.add_trace(go.Scatter(x=fpr, y=tpr, mode='lines', 
                            name=f'ROC curve (area = {roc_auc_value :.2f})',
                            line=dict(color='blue', width=2)))

    fig.add_trace(go.Scatter(x=[0, 1], y=[0, 1], mode='lines',
                            name='Random', line=dict(color='grey', dash='dash')))

    fig.update_layout(
        title='ROC curve for the logistic model',
        xaxis_title='False Positive Rate',
        yaxis_title='True Positive Rate',
        xaxis=dict(range=[0.0, 1.0]),
        yaxis=dict(range=[0.0, 1.05]),
        showlegend=True
    )

    st.plotly_chart(fig)


    # Get Lift curve
    y_true = test['presence_unpaid']
    scores = predicted_probabilities

    fpr, tpr, thresholds = roc_curve(y_true, scores, pos_label=1)

    st.header("How the logit model is efficient 2")

    y_true_numeric = y_true.astype('int')
    prop_positive = y_true_numeric.mean()

    fpr, tpr, thresholds = roc_curve(y_true, scores)
    rpp = fpr * (1 - prop_positive) + tpr * prop_positive  

    fig = go.Figure()

    fig.add_trace(go.Scatter(x=rpp, y=tpr, mode='lines', 
                            name='Lift curve', line=dict(color='blue', width=2)))

    fig.add_trace(go.Scatter(x=[0, prop_positive, 1], y=[0, 1, 1], mode='lines',
                            name='Perfect model', line=dict(color='grey', dash='dash')))

    fig.update_layout(
        title='Lift curve for the logistic model',
        xaxis_title='Rate of Positive Predictions (RPP)',
        yaxis_title='True Positive Rate (TPR)',
        showlegend=True
    )

    st.plotly_chart(fig)


    # Get the second Lift curve
    st.header("How the logit model is efficient 3")

    y_true_numeric = y_true.astype('int')
    prop_positive = y_true_numeric.mean()

    fpr, tpr, thresholds = roc_curve(y_true, scores)

    rpp = fpr * (1 - prop_positive) + tpr * prop_positive
    lift = tpr / rpp

    fig = go.Figure()

    fig.add_trace(go.Scatter(x=rpp, y=lift, mode='lines', 
                            name='Lift curve',
                            line=dict(color='blue', width=2)))

    fig.add_trace(go.Scatter(x=[0, prop_positive, 1], y=[0, 1, 1], mode='lines',
                            name='Perfect model', line=dict(color='grey', dash='dash')))

    fig.update_layout(
        title='Lift curve for the logistic model',
        xaxis_title='Rate of Positive Predictions (RPP)',
        yaxis_title='Lift value',
        showlegend=True
    )

    st.plotly_chart(fig)




    # Get the Precision|Recall plot
    st.header("How to choose a threshold to maximise the performance of the model")

    precisions, recalls, pr_thresholds = precision_recall_curve(y_true, scores)
    fpr, tpr, thresholds = roc_curve(y_true, scores)

    fig = go.Figure()

    fig.add_trace(go.Scatter(
        x=pr_thresholds, 
        y=precisions[:-1], 
        mode='lines', 
        name='Precision', 
        line=dict(color='blue')
    ))

    fig.add_trace(go.Scatter(
        x=pr_thresholds, 
        y=recalls[:-1], 
        mode='lines', 
        name='Recall', 
        line=dict(color='green')
    ))

    fig.update_layout(
        title='Precision and Recall vs Decision Threshold',
        xaxis_title='Decision Threshold',
        yaxis_title='Score',
        legend=dict(x=0, y=1),
        margin=dict(l=0, r=0, t=40, b=20),
        template='plotly_white'
    )

    st.plotly_chart(fig)



    # Get the confusion matrix
    precisions, recalls, pr_thresholds = precision_recall_curve(y_true, scores)

    chosen_threshold = st.slider("Select Threshold", min_value=float(np.min(pr_thresholds)), 
                                max_value=float(np.max(pr_thresholds)), 
                                value=0.5, step=0.01)

    precision_value = 1  
    rounded_pr_thresholds = np.round(pr_thresholds, precision_value)
    rounded_chosen_threshold = np.round(chosen_threshold, precision_value)

    y_pred = (scores >= chosen_threshold).astype(int)

    cm = confusion_matrix(y_true, y_pred)

    fig = ff.create_annotated_heatmap(
        z=cm, 
        x=['Predicted Negative', 'Predicted Positive'], 
        y=['Actual Negative', 'Actual Positive'],
        annotation_text=[['TN: {}'.format(cm[0,0]), 'FP: {}'.format(cm[0,1])], 
                        ['FN: {}'.format(cm[1,0]), 'TP: {}'.format(cm[1,1])]],
        colorscale='Blues'
    )

    fig.update_layout(
        title=f'Confusion Matrix (Threshold = {chosen_threshold:.2f})',
        xaxis_title='Prediction',
        yaxis_title='Actual',
        margin=dict(l=50, r=50, t=50, b=50)
    )

    st.plotly_chart(fig)


    # Get precision, recall and F1-score metrics
    if rounded_chosen_threshold in rounded_pr_thresholds:
        index = np.where(rounded_pr_thresholds == rounded_chosen_threshold)[0][0]
        precision = precisions[index]
        recall = recalls[index]
        f1 = 2 * (precision * recall) / (precision + recall)
    else:
        precision = "N/A"
        recall = "N/A"
        f1 = "N/A"
        st.write(f"The chosen threshold {rounded_chosen_threshold} does not exist in rounded pr_thresholds.")

    st.write(f'**Precision:** {precision * 100:.2f}%')
    st.write(f'**Recall:** {recall * 100:.2f}%')
    st.write(f'**F1 Score:** {f1 * 100:.2f}%')

# %% [markdown]
# So after the code's construction, we paste it in a .py file

# %%
logit_app = "logit_app.py"

code = """
import streamlit as st
from streamlit_option_menu import option_menu         
import pandas as pd
import joblib
from sklearn.metrics import roc_auc_score
import statsmodels.api as sm
import statsmodels.formula.api as smf
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from sklearn.metrics import precision_recall_curve, roc_curve, confusion_matrix
import plotly.express as px
import plotly.graph_objs as go
from sklearn.metrics import roc_auc_score, roc_curve
import plotly.figure_factory as ff




model = joblib.load('c:/Users/DL/Documents/MEGA/100 cas de PYTHON/Data_science_from_scratch/modelisation predictive version Python/logit_model.plk')



################ Page configuration ##################################################################################################

st.set_page_config(
    page_title="Scoring Credit App",  # Titre de l'onglet
    page_icon="💳",  
    layout="centered",  
    initial_sidebar_state="auto",
)

# UX
with st.sidebar:
    selected = option_menu(
        menu_title="Main Menu",
        options=["Home", "Model Explanation", "Contact"],
        icons=["credit-card", "graph-up", "envelope"],
        menu_icon="cast",
        default_index=0,
    )


################ Home ##################################################################################################

if selected == "Home":

    st.title("💳 Credit Risk Prediction")
    st.write("This app predicts the probability of a customer's non-payment based on several factors")


    # inputs users
    accounts = st.selectbox("accounts", ["", "No account", "CC < 0 euros", "CC [0-200 euros]", "CC > 200 euros"], index=0)
    history_credit = st.selectbox("history_credit", ["", "No credits or ongoing without delay", "Credits in arrears", "Past credits without delay"], index=0)
    duration_credit_value = st.slider("Duration Credit (months)", min_value=6, max_value=72, step=1)
    age_value = st.number_input("Age", min_value=18, max_value=75, step=1)
    savings = st.selectbox("savings", ["", "No savings", "> 500 euros", "< 500 euros", "No savings", "> 500 euros"], index=0)
    guarantees = st.selectbox("guarantees", ["", "With guarantor", "Without guarantor"], index=0)
    other_credits = st.selectbox("other_credits", ["", "No external credit", "External credits"], index=0)


    def discretize_duration_credit(value):
        if value < 15:
            return "[0.0, 15.0)"
        elif value <= 36:
            return "[15.0, 36.0)"
        else:
            return "[36.0, inf)"

    def discretize_age(value):
        if value < 25:
            return "[0.0, 25.0)"
        else:
            return "[25.0, inf)"

    duration_credit = discretize_duration_credit(duration_credit_value)
    age = discretize_age(age_value)


    # The inputs are stocked in a dataframe 
    input_data = pd.DataFrame({
        'accounts': [accounts],
        'history_credit': [history_credit],
        'duration_credit': [duration_credit],
        'age': [age],
        'savings': [savings],
        'guarantees': [guarantees],
        'other_credits': [other_credits]
    })


    # the prediction is ready
    if st.button("Predict"):
        if "" in [accounts, history_credit, savings, guarantees, other_credits]:
            st.error("Please fill in all the options before predicting.")
        else:
            # Continue with prediction
            prediction = model.predict(input_data)
            st.write(f"The probability of non-payment is {prediction[0]:.2%}")

            if prediction[0] > 0.5:
                st.error("Warning: Customers are at high risk of non-payment.")
            else:
                st.success("Good: The customer is at low risk of non-payment.")



####################### Data Preparation ##################################################################################################

# Loading data table and data transformation
credit2 = pd.read_csv('c:/Users/DL/Documents/MEGA/100 cas de PYTHON/Data_science_from_scratch/modelisation predictive version Python/credit2.csv') 

credit2['accounts'] = credit2['accounts'].replace({
    'A14': 'No account',
    'A11': 'CC < 0',
    'A12': 'CC [0-200 euros[',
    'A13': 'CC > 200 euros'
})

credit2['history_credit'] = credit2['history_credit'].replace({
    'A30': 'Credits in arrears', 'A31': 'Credits in arrears',
    'A32': 'No credits or ongoing without delay', 'A33': 'No credits or ongoing without delay',
    'A34': 'Past credits without delay'
})

credit2['object_credit'] = credit2['object_credit'].replace({
    'A40': 'New car',
    'A41': 'Used car',
    'A42': 'Interior', 'A43': 'Interior', 'A45': 'Interior',
    'A46': 'Studies-business-Other', 'A48': 'Studies-business-Other', 'A410': 'Studies-business-Other',
    'A47': 'Vacations'
})

credit2['savings'] = credit2['savings'].replace({
    'A63': 'No savings or > 500 euros', 'A64': 'No savings or > 500 euros', 'A65': 'No savings or > 500 euros',
    'A61': '< 500 euros', 'A62': '< 500 euros'
})

credit2['employment_old'] = credit2['employment_old'].replace({
    'A71': 'Unemployed or < 1 year', 'A72': 'Unemployed or < 1 year',
    'A73': 'E [1-4[ years',
    'A74': 'E GE A years', 'A75': 'E GE A years'
})

credit2['family_status'] = credit2['family_status'].replace({
    'A91': 'Divorced/separated man',
    'A92': 'Divorced/separated/married woman',
    'A93': 'Single/married/widowed man', 'A94': 'Single/married/widowed man',
    'A95': 'Single woman'
})

credit2['guarantees'] = credit2['guarantees'].replace({'A103': 'With guarantor'})

credit2.loc[credit2['guarantees'] != 'With guarantor', 'guarantees'] = 'Without guarantor'

credit2['property'] = credit2['property'].replace({'A121': 'Real estate', 'A124': 'No assets'})

credit2.loc[~credit2['property'].isin(['Real estate', 'No assets']), 'property'] = 'Non-real estate'

credit2['other_credits'] = credit2['other_credits'].replace({'A143': 'No external credit'})

credit2.loc[credit2['other_credits'] != 'No external credit', 'other_credits'] = 'External credits'

credit2['home_status'] = credit2['home_status'].replace({'A152': 'Owner'})

credit2.loc[credit2['home_status'] != 'Owner', 'home_status'] = 'Non-owner' 


# splitting train and test 
test_size = 0.3

shuffled_data = credit2.sample(frac=1, random_state=42)

split_point = int(len(shuffled_data) * (1 - test_size))

train = shuffled_data.iloc[:split_point].reset_index(drop=True)
test = shuffled_data.iloc[split_point:].reset_index(drop=True)


####################### Model Explanation ##################################################################################################


if selected == "Model Explanation":

    # Get the summary
    st.header("How the Logit model is explained")
    st.subheader("Logit Model Summary")

    formula = 'presence_unpaid ~ accounts + history_credit + duration_credit + age + savings + guarantees + other_credits'
    logit_model = smf.glm(formula=formula, data=train, family=sm.families.Binomial(link=sm.genmod.families.links.Logit())).fit()

    st.text(logit_model.summary())


    # Get the metrics
    null_deviance = -2 * logit_model.llnull
    residual_deviance = -2 * logit_model.llf

    null_deviance_message = "Null Deviance: {:.4f}".format(null_deviance)
    residual_deviance_message = "Residual Deviance: {:.4f}".format(residual_deviance)
    aic_message =  "AIC: {:.4f}".format(logit_model.aic)
    fisher_message = "Number of Fisher Scoring iterations: {}".format(logit_model.fit_history['iteration'])

    st.write(null_deviance_message)
    st.write(residual_deviance_message)
    st.write(aic_message)
    st.write(fisher_message)

    predicted_probabilities = logit_model.predict(test)
    predicted_classes = (predicted_probabilities > 0.5).astype(int)

    y_test = test['presence_unpaid']

    auc = roc_auc_score(y_test, predicted_probabilities)
    auc_message = "Area Under The Curve ROC: {:.4f}".format(auc)
    st.write(auc_message)



    # Get Score Distribution Function
    st.header("How bad and good files are distributed")

    def ecdf(data):
        n = len(data)
        x = np.sort(data)
        y = np.arange(1, n+1) / n
        return x, y

    x_0, y_0 = ecdf(predicted_probabilities[test['presence_unpaid'] == 0])
    x_1, y_1 = ecdf(predicted_probabilities[test['presence_unpaid'] == 1])

    common_x = np.unique(np.concatenate((x_0, x_1)))
    y_0_interp = np.interp(common_x, x_0, y_0)
    y_1_interp = np.interp(common_x, x_1, y_1)

    ks_stat = np.max(np.abs(y_0_interp - y_1_interp))
    ks_x = common_x[np.argmax(np.abs(y_0_interp - y_1_interp))]

    fig = go.Figure()
    fig.add_trace(go.Scatter(x=x_0, y=y_0, mode='markers', name='Score=0',
                            marker=dict(symbol='8', color='blue')))
    
    fig.add_trace(go.Scatter(x=x_1, y=y_1, mode='markers', name='Score=1',
                            marker=dict(symbol='triangle-up', color='red')))
    
    fig.add_trace(go.Scatter(x=[ks_x, ks_x], y=[y_0_interp[np.argmax(np.abs(y_0_interp - y_1_interp))], y_1_interp[np.argmax(np.abs(y_0_interp - y_1_interp))]],
                            mode='lines', name='KS Statistic', line=dict(color='grey', dash='dot')))
    fig.update_layout(
        title='Score Distribution Function',
        xaxis_title='x - Score (logit)',
        yaxis_title='Fn(x)',
        legend=dict(orientation="h", yanchor="bottom", y=1.02, xanchor="right", x=1)
    )

    st.plotly_chart(fig)
  
    
    
    # Get Score Density Plot
    fpr, tpr, thresholds = roc_curve(y_test, predicted_probabilities)
    ks = tpr - fpr
    max_ks_index = np.argmax(ks)
    optimal_threshold = thresholds[max_ks_index]
    
    st.header("What is the density for bad and good files")

    scores_good = predicted_probabilities[y_test == 0]
    scores_bad = predicted_probabilities[y_test == 1]

    fig = go.Figure()

    fig.add_trace(go.Histogram(x=scores_good, nbinsx=50, name='Good files (presence_unpaid=0)', opacity=0.7, histnorm='probability density', marker=dict(color='blue')))

    fig.add_trace(go.Histogram(x=scores_bad, nbinsx=50, name='Bad files (presence_unpaid=1)', opacity=0.7, histnorm='probability density', marker=dict(color='red')))

    fig.add_shape(type="line",
                x0=optimal_threshold, y0=0, x1=optimal_threshold, y1=1,
                line=dict(color="Green", width=3, dash="dash"))

    fig.add_annotation(x=optimal_threshold, y=0.5,
                    text=f'Optimum threshold: {optimal_threshold:.2f}',
                    showarrow=True, arrowhead=1)

    fig.update_layout(
        title="Score Density Functions with Optimal Threshold",
        xaxis_title="Score (predicted probability)",
        yaxis_title="Density",
        barmode='overlay'
    )

    st.plotly_chart(fig)


    # Get the boxplots
    st.header("How the good and bad files are well discriminated")

    test['predicted_score'] = predicted_probabilities

    fig = px.box(
        test,
        x='presence_unpaid',
        y='predicted_score',
        title='The score in each of the classes to be discriminated',
        labels={
            'presence_unpaid': 'Presence Unpaid',
            'predicted_score': 'Logit (Predicted Score)'
        },

        points="all",  
        color = 'presence_unpaid'
    )

    st.plotly_chart(fig)


    # Get the score grid
    st.header("How to put a weight on each modality's variable to measure its importance")
    st.subheader("Final Score Grid")

    model_logitxlevels = ['accounts', 'history_credit', 'duration_credit', 'age', 'savings','guarantees', 'other_credits']

    for var in model_logitxlevels:
        if var in credit2.columns:
            print(f"Level for {var}: {credit2[var].unique()}")
        else:
            print(f"{var} is not in the DataFrame")

    coefficients = logit_model.params


    multiplier = 10

    scores = {k: v * multiplier for k, v in coefficients.items() if k != 'Intercept'}

    print("Scores attributed to each modality :", scores)

    max_score = sum([abs(s) for s in scores.values()])  
    normalized_scores = {k: (v / max_score) * 100 for k, v in scores.items()}

    coefficients = logit_model.params

    data = {
        'VARIABLE': [],
        'MODALITY': [],
        'COEFF': []
    }

    for var in coefficients.index:
        if 'T.' in var:
            var_name, modality = var.split('T.')
        else:
            var_name = var
            modality = 'N/A'
    
        var_name = var_name.strip('[]').strip() 
        modality = modality.strip('[]').strip()  
        
        data['VARIABLE'].append(var_name)
        data['MODALITY'].append(modality)
        data['COEFF'].append(coefficients[var])

    param = pd.DataFrame(data)

    coefficients = logit_model.params

    min_coeffs = pd.DataFrame(coefficients.groupby(coefficients.index.str.split('[').str[0]).min(), columns=['Min_Coefficient'])
    max_coeffs = pd.DataFrame(coefficients.groupby(coefficients.index.str.split('[').str[0]).max(), columns=['Max_Coefficient'])

    total = min_coeffs.join(max_coeffs)
    total.reset_index(inplace=True)
    total.rename(columns={'index': 'VARIABLE'}, inplace=True)
    total['Diff'] = total['Max_Coefficient'] - total['Min_Coefficient']
    total_weight = sum(total['Diff'] )

    grid = pd.merge(param, min_coeffs, left_on='VARIABLE', right_index=True)
    grid['Modality_Weight'] = grid['COEFF'] - grid['Min_Coefficient']
    grid['WEIGHT'] = ((grid['Modality_Weight'] *100) / total_weight) 
    grid['WEIGHT'] = grid['WEIGHT'].round().astype(int)
   
    grid = grid[grid['VARIABLE'] != 'Intercept']
    grid.sort_values(by=['VARIABLE', 'MODALITY'], inplace=True)
    grid = grid[['VARIABLE', 'MODALITY', 'WEIGHT']]

    st.table(grid)

  

    # Get the ROC Curve
    st.header("How the logit model is efficient 1")
    
    from sklearn.metrics import roc_curve, auc as calculate_auc

    y_true = test['presence_unpaid']
    scores = predicted_probabilities
    fpr, tpr, thresholds = roc_curve(y_true, scores, pos_label=1)
    fpr, tpr, _ = roc_curve(y_true, scores)
    roc_auc_value  = calculate_auc(fpr, tpr)

    fig = go.Figure()

    fig.add_trace(go.Scatter(x=fpr, y=tpr, mode='lines', 
                            name=f'ROC curve (area = {roc_auc_value :.2f})',
                            line=dict(color='blue', width=2)))

    fig.add_trace(go.Scatter(x=[0, 1], y=[0, 1], mode='lines',
                            name='Random', line=dict(color='grey', dash='dash')))

    fig.update_layout(
        title='ROC curve for the logistic model',
        xaxis_title='False Positive Rate',
        yaxis_title='True Positive Rate',
        xaxis=dict(range=[0.0, 1.0]),
        yaxis=dict(range=[0.0, 1.05]),
        showlegend=True
    )

    st.plotly_chart(fig)


    # Get Lift curve
    y_true = test['presence_unpaid']
    scores = predicted_probabilities

    fpr, tpr, thresholds = roc_curve(y_true, scores, pos_label=1)

    st.header("How the logit model is efficient 2")

    y_true_numeric = y_true.astype('int')
    prop_positive = y_true_numeric.mean()

    fpr, tpr, thresholds = roc_curve(y_true, scores)
    rpp = fpr * (1 - prop_positive) + tpr * prop_positive  

    fig = go.Figure()

    fig.add_trace(go.Scatter(x=rpp, y=tpr, mode='lines', 
                            name='Lift curve', line=dict(color='blue', width=2)))

    fig.add_trace(go.Scatter(x=[0, prop_positive, 1], y=[0, 1, 1], mode='lines',
                            name='Perfect model', line=dict(color='grey', dash='dash')))

    fig.update_layout(
        title='Lift curve for the logistic model',
        xaxis_title='Rate of Positive Predictions (RPP)',
        yaxis_title='True Positive Rate (TPR)',
        showlegend=True
    )

    st.plotly_chart(fig)


    # Get the second Lift curve
    st.header("How the logit model is efficient 3")

    y_true_numeric = y_true.astype('int')
    prop_positive = y_true_numeric.mean()

    fpr, tpr, thresholds = roc_curve(y_true, scores)

    rpp = fpr * (1 - prop_positive) + tpr * prop_positive
    lift = tpr / rpp

    fig = go.Figure()

    fig.add_trace(go.Scatter(x=rpp, y=lift, mode='lines', 
                            name='Lift curve',
                            line=dict(color='blue', width=2)))

    fig.add_trace(go.Scatter(x=[0, prop_positive, 1], y=[0, 1, 1], mode='lines',
                            name='Perfect model', line=dict(color='grey', dash='dash')))

    fig.update_layout(
        title='Lift curve for the logistic model',
        xaxis_title='Rate of Positive Predictions (RPP)',
        yaxis_title='Lift value',
        showlegend=True
    )

    st.plotly_chart(fig)




    # Get the Precision|Recall plot
    st.header("How to choose a threshold to maximise the performance of the model")

    precisions, recalls, pr_thresholds = precision_recall_curve(y_true, scores)
    fpr, tpr, thresholds = roc_curve(y_true, scores)

    fig = go.Figure()

    fig.add_trace(go.Scatter(
        x=pr_thresholds, 
        y=precisions[:-1], 
        mode='lines', 
        name='Precision', 
        line=dict(color='blue')
    ))

    fig.add_trace(go.Scatter(
        x=pr_thresholds, 
        y=recalls[:-1], 
        mode='lines', 
        name='Recall', 
        line=dict(color='green')
    ))

    fig.update_layout(
        title='Precision and Recall vs Decision Threshold',
        xaxis_title='Decision Threshold',
        yaxis_title='Score',
        legend=dict(x=0, y=1),
        margin=dict(l=0, r=0, t=40, b=20),
        template='plotly_white'
    )

    st.plotly_chart(fig)



    # Get the confusion matrix
    precisions, recalls, pr_thresholds = precision_recall_curve(y_true, scores)

    chosen_threshold = st.slider("Select Threshold", min_value=float(np.min(pr_thresholds)), 
                                max_value=float(np.max(pr_thresholds)), 
                                value=0.5, step=0.01)

    precision_value = 1  
    rounded_pr_thresholds = np.round(pr_thresholds, precision_value)
    rounded_chosen_threshold = np.round(chosen_threshold, precision_value)

    y_pred = (scores >= chosen_threshold).astype(int)

    cm = confusion_matrix(y_true, y_pred)

    fig = ff.create_annotated_heatmap(
        z=cm, 
        x=['Predicted Negative', 'Predicted Positive'], 
        y=['Actual Negative', 'Actual Positive'],
        annotation_text=[['TN: {}'.format(cm[0,0]), 'FP: {}'.format(cm[0,1])], 
                        ['FN: {}'.format(cm[1,0]), 'TP: {}'.format(cm[1,1])]],
        colorscale='Blues'
    )

    fig.update_layout(
        title=f'Confusion Matrix (Threshold = {chosen_threshold:.2f})',
        xaxis_title='Prediction',
        yaxis_title='Actual',
        margin=dict(l=50, r=50, t=50, b=50)
    )

    st.plotly_chart(fig)


    # Get precision, recall and F1-score metrics
    if rounded_chosen_threshold in rounded_pr_thresholds:
        index = np.where(rounded_pr_thresholds == rounded_chosen_threshold)[0][0]
        precision = precisions[index]
        recall = recalls[index]
        f1 = 2 * (precision * recall) / (precision + recall)
    else:
        precision = "N/A"
        recall = "N/A"
        f1 = "N/A"
        st.write(f"The chosen threshold {rounded_chosen_threshold} does not exist in rounded pr_thresholds.")

    st.write(f'**Precision:** {precision * 100:.2f}%')
    st.write(f'**Recall:** {recall * 100:.2f}%')
    st.write(f'**F1 Score:** {f1 * 100:.2f}%')




"""

with open(logit_app, "w") as file: 
    file.write(code)

print(f"The {logit_app} has been successfully created.")
# Out:
# The logit_app.py has been successfully created.

# %% [markdown]
# We open then the .py file and execute it. The batch will say us to run the following command :

# %%
streamlit run c:/your_path/logit_app.py

# %% [markdown]
# Just add quotes to the file path like this :

# %%
streamlit run "c:/your_path/logit_app.py/logit_app.py"

# %% [markdown]
# And now we can see the logit model performing in the app.

# %% [markdown]
# ### 3. Deployment

# %% [markdown]
# Once the Streamlit app is created, we will proceed to the deployment. For this purpose we will use Docker and Kubernetes.
#
# The first step is to create a Docker image for the logit model.

# %%
FROM python:3.8-slim  

WORKDIR /app 

COPY . /app 

RUN pip install --upgrade pip

RUN ls -l /app

RUN pip install --no-cache-dir -r requirements.txt 

EXPOSE 8501 

CMD ["streamlit", "run", "logit_app.py"]

# %% [markdown]
# Write file requirements.txt file

# %% [raw]
# streamlit
# streamlit-option-menu
# pandas
# joblib
# sklearn.metrics
# statsmodels.api
# statsmodels.formula.api
# matplotlib.pyplot
# seaborn
# numpy
# plotly.express
# plotly.graph_objs
# plotly.figure_factory

# %% [markdown]
# Build and push the Docker image of the logit app

# %%
docker build -t username/logit_app .

docker push username/logit_app

# %% [markdown]
# The second step is to create yaml files for Kubernetes.
#
# The deployment file :

# %% [markdown]
# ```yaml
#
# apiVersion: apps/v1
# kind: Deployment
# metadata:
#     logit-model-deployment
# spec:
#     replicas : 3
#     selector:
#         matchLabels:
#             app: logit-model
#     template:
#         metadata:
#         labels:
#             app: logit-model
#         spec:
#             containers:
#             - name: logit-model
#               image: username/logit_app:latest
#               ports:
#               - containerPort: 8501
#
# ```

# %% [markdown]
# And the service file with LoadBalancer mode :

# %% [markdown]
# ```yaml
#
# apiVersion: v1
# kind: Service
# metadata:
#     name: logit-model-service
# spec:
#     selector:
#         app: logit-model
#     ports:
#         - protocol: TCP
#           port: 80
#           targetPort: 8501
#     type: LoadBalancer
#
# ```

# %% [markdown]
# or NodePort mode :

# %% [markdown]
# ```yaml
#
# apiVersion: v1
# kind: Service
# metadata:
#     name: logit-model-service
# spec:
#     selector:
#         app: logit-model
#     ports:
#         - protocol: TCP
#           port: 80
#           targetPort: 8501
#           nodeport: 30001
#     type: NodePort

# %% [markdown]
# Now we apply tje deployement and the service in the batch :

# %%
kubectl apply -f deployement.yaml 

kubecttl apply -f service.yaml
# Out:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# Now the logit app is accessible.
#
# For the LoadBalancer mode, run :

# %%
kubectl get services logit-model-service

# %% [markdown]
# For the NodePort mode :
#
# http://the_IP_node:nodeport

# %% [markdown]
# ```yaml
#
#
# ```
